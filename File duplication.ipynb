# %% [markdown]
# ## File duplication

# %% [markdown]
# This notebook demonstrates how duplicate details for files are returned in Cancer Data Aggregator (CDA) query results.
#
# #### Function to call the CDA API
# Set up a function to call the CDA API directly with an SQL query

# %%
import requests
def runAPIQuery(querystring, limit=None):
    cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3'
    #Using a limit:
    if limit is not None:
        cdaURL = "{}?limit={}".format(cdaURL, str(limit))
        
    headers = {'accept' : 'application/json', 'Content-Type' : 'text/plain'}

    request = requests.post(cdaURL, headers = headers, data = querystring)

    if request.status_code == 200:
        return request.json()
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code,query))

# %% [markdown]
# #### Set up a query looking for patients with a tumor stage II in the TCGA-BRCA project.
# The query returns six results

# %%
querystring = ''' select * from gdc-bq-sample.cda_mvp.v3
where id in
(SELECT distinct p.id FROM gdc-bq-sample.cda_mvp.v3 AS p, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis 
WHERE (((_ResearchSubject.associated_project = 'TCGA-BRCA') 
AND (_Diagnosis.tumor_stage = 'stage ii')) 
) )'''

query = runAPIQuery(querystring)
print('Count of results:',format(len(query['result'])))
# Out:
# Count of results: 6

# %% [markdown]
# Define a function to list details of files which occur more than once in the results

# %%
def findFileDuplicates(result, minoccurs=2, maxoccurs=1000000):
    fileOccurrences = {}
    for res in result:
        for su in res['ResearchSubject']:
            for sp in su['Specimen']:
                for f in sp['File']:
                    fileID = f['id']
                    specimen_details= {'id':sp['id'], 
                    'subject':sp['derived_from_subject'],
                    'material':sp['source_material_type']
                     }
                    if fileID in fileOccurrences:
                        fileOccurrences[fileID]['occurences'] += 1
                        fileOccurrences[fileID]['specimens'].append(specimen_details)
                    else:
                        fileOccurrences[fileID] = {'occurences':1,
                                                   'file':f,
                                                   'specimens':[specimen_details]
                                                  }

    for fileId, details in fileOccurrences.items():
        if details['occurences'] >= minoccurs and details['occurences'] <= maxoccurs:
            print('file id: {}'.format(fileId))
            print('Occurrences in results: {}'.format(details['occurences']))
            print('data category: {}'.format(details['file']['data_category']))
            print('file label: {}'.format(details['file']['label']))
            print('Specimens in which this file occurs within results')
            for s in details['specimens']:
                print(s)
            print('_'*80)

# %%
findFileDuplicates(query['result'],minoccurs=2, maxoccurs=2)
# Out:
# file id: 11622ce5-c58e-4999-a5c4-7a04dc01c0d2
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 11622ce5-c58e-4999-a5c4-7a04dc01c0d2.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 15c363fd-7a70-4fe8-b8c4-3a383f169488
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.d9b9b065-fec4-4abf-b818-6f832d64ead4.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 2446145b-b353-4524-85a8-690d4a8880d6
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 2446145b-b353-4524-85a8-690d4a8880d6.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 3d98308d-40d3-454c-b080-26a331f23426
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 3d98308d-40d3-454c-b080-26a331f23426.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 43a60201-660c-4ec7-966b-feb7d7b1c230
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 43a60201-660c-4ec7-966b-feb7d7b1c230.vcf
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 557ba479-8087-4fe5-958e-7d18d70a8b86
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.d9b9b065-fec4-4abf-b818-6f832d64ead4.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 7a2a614f-1859-4520-bb9f-b1145b3c192e
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 7a2a614f-1859-4520-bb9f-b1145b3c192e.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: ecec98c8-2679-41af-a396-c44fafe0013b
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: ecec98c8-2679-41af-a396-c44fafe0013b.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: f57911e0-4ea7-4cd2-8cf3-8ea9405732fd
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: f57911e0-4ea7-4cd2-8cf3-8ea9405732fd.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: fabc3983-c898-4054-af8e-9be9ef71bc4f
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: fabc3983-c898-4054-af8e-9be9ef71bc4f.vcf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 20f958dc-76ef-4704-8014-1f9c3463ec0d
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.6631aa60-6bc2-4604-98ab-0c7d5187fc7f.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 4c0a713b-7491-4ea7-976e-1b2bcd1decbc
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 4c0a713b-7491-4ea7-976e-1b2bcd1decbc.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 6ae76fa0-c31f-4a32-a6a8-aa7bd0973e7e
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 6ae76fa0-c31f-4a32-a6a8-aa7bd0973e7e.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 76e4336d-aea7-4ef8-b792-d197f9cb3f42
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 76e4336d-aea7-4ef8-b792-d197f9cb3f42.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 797cac0a-573f-40a4-86e6-7694ae7b224c
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 797cac0a-573f-40a4-86e6-7694ae7b224c.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: b6033437-0d59-4cd3-ac89-89a8844b0c32
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.6631aa60-6bc2-4604-98ab-0c7d5187fc7f.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: c4475aa6-7cc5-4d98-b52c-e9b70b096230
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: c4475aa6-7cc5-4d98-b52c-e9b70b096230.vcf
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: e4c652c2-c165-42e9-ba62-c77c0cb19214
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: e4c652c2-c165-42e9-ba62-c77c0cb19214.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: f8563ba1-2649-4092-b966-098b046a0ab2
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: f8563ba1-2649-4092-b966-098b046a0ab2.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: fc792423-b114-41dc-bbb0-4c95b8a40e29
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: fc792423-b114-41dc-bbb0-4c95b8a40e29.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 0e66fb5e-f632-48bc-9dbb-dc10b27e0a26
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 0e66fb5e-f632-48bc-9dbb-dc10b27e0a26.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 637147d0-6098-4440-a90a-5e3b81d806f1
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 637147d0-6098-4440-a90a-5e3b81d806f1.vcf
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 64e416a9-a18e-482e-b0f9-ed9372fee88f
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 64e416a9-a18e-482e-b0f9-ed9372fee88f.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 834eb495-81f3-41f3-a92c-99d88b0e01aa
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 834eb495-81f3-41f3-a92c-99d88b0e01aa.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: a7618e68-d0a9-4f99-ac59-841376fe9201
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: a7618e68-d0a9-4f99-ac59-841376fe9201.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: ac3bc659-dd94-4d16-be37-0fbf7e0ffcda
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: ac3bc659-dd94-4d16-be37-0fbf7e0ffcda.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: b251da16-1863-4975-80c1-f76d6993f70d
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: b251da16-1863-4975-80c1-f76d6993f70d.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: bf8407e8-6d05-4559-8908-0616eb321634
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: bf8407e8-6d05-4559-8908-0616eb321634.vcf.gz
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: c21fb24a-fb8c-473a-af5d-d7dba23c744e
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.6a4af154-27d5-4a5d-9d88-1f4db2dc70d8.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: e8e53f81-ac72-49ad-bdbd-8ba9724e6e15
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.6a4af154-27d5-4a5d-9d88-1f4db2dc70d8.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 099727de-08fe-4d08-8df5-fa431f5693d5
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 099727de-08fe-4d08-8df5-fa431f5693d5.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 18a53856-27a7-4f52-b651-305866e45728
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.f9bccbe0-28c1-4d60-b656-432527eaf911.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 23212b43-2de6-4e40-ac03-4ad5bfd4423b
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 23212b43-2de6-4e40-ac03-4ad5bfd4423b.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 5417a3c8-de8c-4349-8a96-a901d3ba5392
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 5417a3c8-de8c-4349-8a96-a901d3ba5392.vcf
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 63623909-2997-4a93-ae5f-21c161d486a5
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 63623909-2997-4a93-ae5f-21c161d486a5.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: c8b0c02e-a0be-46c6-bbdc-e585d9c03413
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: c8b0c02e-a0be-46c6-bbdc-e585d9c03413.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: d30b6fab-fbd0-4e3d-a09d-2344c7dbaede
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.f9bccbe0-28c1-4d60-b656-432527eaf911.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: da3a2087-3c56-4983-8207-08302d5ff63e
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: da3a2087-3c56-4983-8207-08302d5ff63e.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: fd6bf51a-7541-48ad-841f-c6a27f524ec5
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: fd6bf51a-7541-48ad-841f-c6a27f524ec5.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: fe9d7bb1-4927-4ede-8515-3393e9603e8f
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: fe9d7bb1-4927-4ede-8515-3393e9603e8f.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 249ebb81-0397-4f7e-8778-d89937c64da8
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 249ebb81-0397-4f7e-8778-d89937c64da8.vcf
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 38e08a86-778b-4289-a724-c350e1b86322
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 38e08a86-778b-4289-a724-c350e1b86322.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 44705428-0847-4504-9ad4-5a5358274d67
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 44705428-0847-4504-9ad4-5a5358274d67.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 64e1142c-8803-4148-89e9-4db513d03907
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 64e1142c-8803-4148-89e9-4db513d03907.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 78491676-7bc4-4af4-8677-90442936edfb
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 78491676-7bc4-4af4-8677-90442936edfb.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: ab23658e-a181-4c3d-a2d7-0816d6e35a8f
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.8141d561-b148-446e-b500-566f1a2cd075.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: bb5cfbf6-760f-41a3-a5c4-1d0d0aab53b1
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: bb5cfbf6-760f-41a3-a5c4-1d0d0aab53b1.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: c92776bb-6f20-4c89-b2de-806cf2696890
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.8141d561-b148-446e-b500-566f1a2cd075.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: ceb0fdf3-fc51-4f19-994d-9d3a4bf80cd2
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: ceb0fdf3-fc51-4f19-994d-9d3a4bf80cd2.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: e99e14ad-dab2-418d-a791-5200c8139003
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: e99e14ad-dab2-418d-a791-5200c8139003.vcf.gz
# Specimens in which this file occurs within results
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 33224d95-5a9f-4095-add0-497fa21cc711
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 33224d95-5a9f-4095-add0-497fa21cc711.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 4bbca71e-e5b5-44e7-9486-742db07e359e
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 4bbca71e-e5b5-44e7-9486-742db07e359e.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 4e096fe9-f59e-4ae6-b31d-a65a8c327add
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 4e096fe9-f59e-4ae6-b31d-a65a8c327add.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 5548eab3-5364-487d-a74a-2653f5d9489c
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.27925a3c-9258-4c9e-9674-34c744a31eb3.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 68ddc271-2fc8-43b9-b124-3b4e6ad24ccb
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 68ddc271-2fc8-43b9-b124-3b4e6ad24ccb.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 834f7936-1997-48d3-aaac-4b00b0c5228b
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 834f7936-1997-48d3-aaac-4b00b0c5228b.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: d827fa64-2c9c-4b34-a180-421ae4cfac4e
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: d827fa64-2c9c-4b34-a180-421ae4cfac4e.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: e7b702a3-6758-412a-a0a8-8df23a0b3e55
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.27925a3c-9258-4c9e-9674-34c744a31eb3.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: fa4a9665-b26b-4f21-8bd0-4a4ca0c7d0a5
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: fa4a9665-b26b-4f21-8bd0-4a4ca0c7d0a5.vcf.gz
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: fb514bb2-61f9-4346-abae-b339ddf2a9e3
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: fb514bb2-61f9-4346-abae-b339ddf2a9e3.vcf
# Specimens in which this file occurs within results
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________

# %% [markdown]
# These files are derived from two specimens. Per the GDC documentation [the vcf describes a tumor-normal pair](https://docs.gdc.cancer.gov/Data/File_Formats/VCF_Format/)
#
# To maintain proper cardinality, and to avoid duplication, the file would be more properly associated with the ResearchSubject rather than the Specimen. (That applies to TCGA, but may not be true for other study designs. A more generally applicable model would be that the vcf would be associated with a Specimen Collection Group. A Specimen Collection Group is a group of specimens collected together at some defined point (e.g. tumor surgery). In a study with repeated biopsies, for example, a subject would have more than one Specimen Collection Group. Most accurately perhaps it could be said that the vcf primarily belongs with the tumor sample.
#
# It is correct that that provenance of each vcf file is that it derives from two specimens. However, that is different than the primary meaning of the file which provides data about the subject at that point in time.
#
# ### Files which repeat more than twice
# We can use the same function as before to list details of the  files which are repeated more than twice

# %%
findFileDuplicates(query['result'],minoccurs=3, maxoccurs=100000)
# Out:
# file id: 053f01ed-3154-4aea-9e7f-932c435034b3
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.mutect.053f01ed-3154-4aea-9e7f-932c435034b3.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 5a6c3396-8c49-4c25-8a86-7ae63a887c43
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.varscan.5a6c3396-8c49-4c25-8a86-7ae63a887c43.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 6c93f518-1956-4435-9806-37185266d248
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.varscan.6c93f518-1956-4435-9806-37185266d248.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 7dd592e3-5950-4438-96d5-3c718aca3f13
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.somaticsniper.7dd592e3-5950-4438-96d5-3c718aca3f13.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 995c0111-d90b-4140-bee7-3845436c3b42
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.mutect.995c0111-d90b-4140-bee7-3845436c3b42.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: 9afe6c9d-ed2f-402a-b043-77f042c4e7fc
# Occurrences in results: 6
# data category: Copy Number Variation
# file label: BRCA.focal_score_by_genes.txt
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: b8ca5856-9819-459c-87c5-94e91aca4032
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.muse.b8ca5856-9819-459c-87c5-94e91aca4032.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: cd0d1636-ae95-4141-94b3-8218eb3b8b25
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.muse.cd0d1636-ae95-4141-94b3-8218eb3b8b25.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________
# file id: f9ff49e9-31ce-4051-9157-4bf4b0c5859a
# Occurrences in results: 12
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.somaticsniper.f9ff49e9-31ce-4051-9157-4bf4b0c5859a.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '569dc2bf-8078-4330-afac-f3ff65903249', 'subject': 'TCGA-EW-A6SB', 'material': 'Primary Tumor'}
# {'id': 'a83c0976-6b61-41be-ba96-c37986e90b6d', 'subject': 'TCGA-EW-A6SB', 'material': 'Blood Derived Normal'}
# {'id': '680396b1-a19e-4acd-bef8-e1671b80aa31', 'subject': 'TCGA-EW-A6SA', 'material': 'Blood Derived Normal'}
# {'id': '5a1bb598-9a38-452a-9599-365501038a88', 'subject': 'TCGA-EW-A6SA', 'material': 'Primary Tumor'}
# {'id': '8fa798fe-f032-4d77-b362-06261db78e6d', 'subject': 'TCGA-BH-A202', 'material': 'Primary Tumor'}
# {'id': '6df53651-4c7a-4b9f-b85f-9cbd5de65a3f', 'subject': 'TCGA-BH-A202', 'material': 'Blood Derived Normal'}
# {'id': '5b94a116-7e70-41d4-8c6f-2bae44e591aa', 'subject': 'TCGA-B6-A0WZ', 'material': 'Primary Tumor'}
# {'id': 'ee31517a-b792-4a1a-9a53-8178fb035fc5', 'subject': 'TCGA-B6-A0WZ', 'material': 'Blood Derived Normal'}
# {'id': '5b55c210-049a-4835-ac3b-bba70c72973b', 'subject': 'TCGA-OK-A5Q2', 'material': 'Primary Tumor'}
# {'id': '6e4e74d1-2d47-441f-9c83-8ff9b46bc1de', 'subject': 'TCGA-OK-A5Q2', 'material': 'Blood Derived Normal'}
# {'id': '9ebe5223-7566-4026-83ae-812283a8aaeb', 'subject': 'TCGA-AR-A2LM', 'material': 'Primary Tumor'}
# {'id': '19384739-bc02-417c-b773-fc44feefb4c9', 'subject': 'TCGA-AR-A2LM', 'material': 'Blood Derived Normal'}
# ________________________________________________________________________________

# %% [markdown]
# Most of these files are repeated 12 times i.e. for both the tumor and normal specimens for each of the 6 Research Subjects within the results. The exception is the focal_score_by_genes file which is repeated 6 times. That file derives only from tumor sample from each subject.
#
# Again the the GDC documentation is helpful, describing for [the MAF format](https://docs.gdc.cancer.gov/Data/File_Formats/MAF_Format/) "One MAF file is produced per variant calling pipeline per GDC project". In other words there is one MAF file for 'TCGA-BRCA'.
#
# It is again correct that the existing relationship describes provenance, and that may be useful for some purposes. However, a user of the CDA would likely be better served by eliminating duplication of the files within the results. Associating the maf file with a project (and pipeline) gives a user a simpler view of the meaning of the file.
#
# Provenance for a file would be more simply provided from the other end of the relationship i.e. for the maf file to record which specimens (or vcfs) it derived from.
#
# ### CDA Python API
# To demonstrate - the same issue occurs when cdapython is used, as opposed to using the CDA API directly as above.

# %%
from cdapython import Q
import json

q1 = Q('ResearchSubject.Specimen.File.drs_uri = "drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056"')
r = q1.run() 
r.sql
print(r.count)
# Out:
# 1

# %%
findFileDuplicates(r)
# Out:
# file id: 053f01ed-3154-4aea-9e7f-932c435034b3
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.mutect.053f01ed-3154-4aea-9e7f-932c435034b3.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 097d9d39-5794-4ccf-abb4-915ed60ff8a2
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 097d9d39-5794-4ccf-abb4-915ed60ff8a2.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 1ee3e654-b508-4a6c-b854-41efdf88d7f5
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 1ee3e654-b508-4a6c-b854-41efdf88d7f5.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 4cf13ec0-c0d9-4a74-9437-668670ab7db0
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: 4cf13ec0-c0d9-4a74-9437-668670ab7db0.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 53c665e8-61b6-455e-bef9-954de078cc74
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.263be494-445c-469b-8b53-d27860d73f8d.gene_level_copy_number.tsv
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 5a6c3396-8c49-4c25-8a86-7ae63a887c43
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.varscan.5a6c3396-8c49-4c25-8a86-7ae63a887c43.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 6c93f518-1956-4435-9806-37185266d248
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.varscan.6c93f518-1956-4435-9806-37185266d248.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 7dd592e3-5950-4438-96d5-3c718aca3f13
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.somaticsniper.7dd592e3-5950-4438-96d5-3c718aca3f13.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: 995c0111-d90b-4140-bee7-3845436c3b42
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.mutect.995c0111-d90b-4140-bee7-3845436c3b42.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: acc481b0-162e-4f89-b5ac-d8d8e261283c
# Occurrences in results: 2
# data category: Copy Number Variation
# file label: TCGA-BRCA.263be494-445c-469b-8b53-d27860d73f8d.ascat2.allelic_specific.seg.txt
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: b68a22c3-110e-492f-866d-062518d296e5
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: b68a22c3-110e-492f-866d-062518d296e5.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: b8ca5856-9819-459c-87c5-94e91aca4032
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.muse.b8ca5856-9819-459c-87c5-94e91aca4032.DR-10.0.somatic.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: c29294b1-ce40-4eaa-88e0-ed10c1848834
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: c29294b1-ce40-4eaa-88e0-ed10c1848834.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: cd0d1636-ae95-4141-94b3-8218eb3b8b25
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.muse.cd0d1636-ae95-4141-94b3-8218eb3b8b25.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: cf28ecc8-7856-4c3b-89b1-ac34bd1fd662
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: cf28ecc8-7856-4c3b-89b1-ac34bd1fd662.vep.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: d1ef3b6c-cce1-408c-85e6-9ca60c93ae28
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: d1ef3b6c-cce1-408c-85e6-9ca60c93ae28.vcf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: f0382a48-0f82-494a-9224-7b41103d519b
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: f0382a48-0f82-494a-9224-7b41103d519b.vcf
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
# file id: f9ff49e9-31ce-4051-9157-4bf4b0c5859a
# Occurrences in results: 2
# data category: Simple Nucleotide Variation
# file label: TCGA.BRCA.somaticsniper.f9ff49e9-31ce-4051-9157-4bf4b0c5859a.DR-10.0.protected.maf.gz
# Specimens in which this file occurs within results
# {'id': '6ec8ccf0-4292-4add-9190-7339ffed7ffa', 'subject': 'TCGA-AR-A2LK', 'material': 'Blood Derived Normal'}
# {'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915', 'subject': 'TCGA-AR-A2LK', 'material': 'Primary Tumor'}
# ________________________________________________________________________________
