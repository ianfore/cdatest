# %% [markdown]
# ## Using SQL to explore CDA
# First a couple of cdapython queries to check some of its not immediately obvious aspects.

# %%
from cdapython import Q, columns, unique_terms
unique_terms("ResearchSubject.Diagnosis.tumor_stage")
# Out:
# SELECT DISTINCT(_Diagnosis.tumor_stage) FROM `gdc-bq-sample.cda_mvp.v3`, UNNEST(ResearchSubject) AS _ResearchSubject,UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis ORDER BY _Diagnosis.tumor_stage
# [None,
#  '',
#  '1B',
#  '2A',
#  '2B',
#  '3',
#  '4',
#  'Adverse',
#  'Favorable',
#  'FavorableOrIntermediate',
#  'I',
#  'I b',
#  'IA',
#  'IB',
#  'IC',
#  'II',
#  'II b',
#  'IIA',
#  'IIB',
#  'III',
#  'IIIA',
#  'IIIB',
#  'IIIC',
#  'IPI:0',
#  'IPI:1',
#  'IPI:12',
#  'IPI:13',
#  'IPI:14',
#  'IPI:15',
#  'IPI:2',
#  'IPI:23',
#  'IPI:24',
#  'IPI:25',
#  'IPI:3',
#  'IPI:34',
#  'IPI:35',
#  'IPI:4',
#  'IPI:45',
#  'IPI:5',
#  'IV',
#  'IVA',
#  'IVB',
#  'IVa',
#  'IVb',
#  'Intermediate',
#  'IntermediateOrAdverse',
#  'N/A',
#  'Normal',
#  'Not Performed',
#  'Not Reported',
#  'Not Reported/ Unknown',
#  'Not Reported/Unknown',
#  'PT4apN0',
#  'Stage 1B',
#  'Stage I',
#  'Stage IA',
#  'Stage IA3',
#  'Stage IB',
#  'Stage IC',
#  'Stage II',
#  'Stage IIA',
#  'Stage IIB',
#  'Stage III',
#  'Stage IIIA',
#  'Stage IIIB',
#  'Stage IIIC',
#  'Stage IV',
#  'Stage IVA',
#  'Stage IVB',
#  'Stage1',
#  'T1N0Mx',
#  'T1aN0M0',
#  'T2',
#  'TxNxM1',
#  'Unknown',
#  'i',
#  'i/ii nos',
#  'ii',
#  'ii/v',
#  'iii',
#  'iii/v',
#  'iiib',
#  'iiib/v',
#  'is',
#  'iv',
#  'iv/v',
#  'na',
#  'no resection',
#  'not reported',
#  'pT1',
#  'pT1a',
#  'pT1b',
#  'pT1pN0',
#  'pT1pNx',
#  'pT2 N0',
#  'pT2, pN2,  pM not applicable',
#  'pT2, pN2, pM not applicable',
#  'pT2N0',
#  'pT2N0Mx',
#  'pT2N1',
#  'pT2N2',
#  'pT2pN0',
#  'pT2pN2b',
#  'pT2pNx',
#  'pT3',
#  'pT3 N2 M(Not Applicable)',
#  'pT3a',
#  'pT3pN0',
#  'pT3pN2b',
#  'pT3pNx',
#  'pT4',
#  'pT4N0',
#  'pT4apN0',
#  'pT4apN2b',
#  'pT4apN2c',
#  'stage 0',
#  'stage 4',
#  'stage i',
#  'stage ia',
#  'stage ib',
#  'stage ii',
#  'stage iia',
#  'stage iib',
#  'stage iic',
#  'stage iii',
#  'stage iiia',
#  'stage iiib',
#  'stage iiic',
#  'stage iv',
#  'stage iva',
#  'stage ivb',
#  'stage ivc',
#  'stage x',
#  'u',
#  'unknown',
#  'v']

# %% [markdown]
# I asked if we can do unique terms for a project. Well it turns out we can do it for a 'system'.

# %%
unique_terms("ResearchSubject.Diagnosis.tumor_stage", system='PDC')
# Out:
# SELECT DISTINCT(_Diagnosis.tumor_stage) FROM `gdc-bq-sample.cda_mvp.v3`, UNNEST(ResearchSubject) AS _ResearchSubject,UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis,UNNEST(_ResearchSubject.identifier) AS _identifier WHERE _identifier.system="PDC" ORDER BY _Diagnosis.tumor_stage
# ['',
#  'IA',
#  'IB',
#  'IIA',
#  'IIB',
#  'IIIA',
#  'IIIB',
#  'IV',
#  'IVB',
#  'N/A',
#  'Not Performed',
#  'Not Reported',
#  'Not Reported/ Unknown',
#  'Not Reported/Unknown',
#  'Stage 1B',
#  'Stage I',
#  'Stage IA',
#  'Stage IA3',
#  'Stage IB',
#  'Stage IC',
#  'Stage II',
#  'Stage IIA',
#  'Stage IIB',
#  'Stage III',
#  'Stage IIIA',
#  'Stage IIIB',
#  'Stage IIIC',
#  'Stage IV',
#  'Stage IVA',
#  'Stage1',
#  'Unknown',
#  'no resection',
#  'pT1',
#  'pT1a',
#  'pT1b',
#  'pT2 N0',
#  'pT2, pN2, pM not applicable',
#  'pT2N1',
#  'pT2N2',
#  'pT3 N2 M(Not Applicable)',
#  'pT3a',
#  'pT4',
#  'stage iiic']

# %% [markdown]
# But to explore at a project level it looks like we must resort to SQL.
#
# ### Passing Direct SQL Queries
# It would be useful to pass some direct SQL queries. Swagger is possible, but not really scriptable. If I want to call the REST API directly from Python I'll probably end up writing a client. How does cdapython call the REST API? It a pre-existing client already exists - in the cda_client module. No need to write our own. Even better, it's already installed; as a cdapython dependency.
#
# First some set up.

# %%
import cda_client
host='https://cda.cda-dev.broadinstitute.org'
api_client = cda_client.ApiClient(configuration=cda_client.Configuration(host=host))
api_instance = cda_client.QueryApi(api_client)

# %% [markdown]
# Now we can run some SQL.
#
# One oddity is that version is a mandatory parameter to sql_query, but the version is actually specified as part of the table name. Currently you can pass anything to version. Not to say that will always be the case, and we should respect the intent of the interface and use a proper version number, (apart from the following, just to illustrate).

# %%
sql = '''SELECT DISTINCT(_Diagnosis.tumor_stage) 
FROM `gdc-bq-sample.cda_mvp.v2`, 
UNNEST(ResearchSubject) AS _ResearchSubject,
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis,
UNNEST(_ResearchSubject.identifier) AS _identifier 
WHERE _identifier.system="PDC" ORDER BY _Diagnosis.tumor_stage'''
api_response = api_instance.sql_query('anything_goes_in',sql)
print(api_response)
# Out:
# {'next_url': None,
#  'previous_url': None,
#  'query_sql': 'SELECT DISTINCT(_Diagnosis.tumor_stage) \n'
#               'FROM `gdc-bq-sample.cda_mvp.v2`, \n'
#               'UNNEST(ResearchSubject) AS _ResearchSubject,\n'
#               'UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis,\n'
#               'UNNEST(_ResearchSubject.identifier) AS _identifier \n'
#               'WHERE _identifier.system="PDC" ORDER BY _Diagnosis.tumor_stage',
#  'result': [{'tumor_stage': ''},
#             {'tumor_stage': 'IA'},
#             {'tumor_stage': 'IB'},
#             {'tumor_stage': 'IIA'},
#             {'tumor_stage': 'IIB'},
#             {'tumor_stage': 'IIIA'},
#             {'tumor_stage': 'IIIB'},
#             {'tumor_stage': 'IV'},
#             {'tumor_stage': 'IVB'},
#             {'tumor_stage': 'N/A'},
#             {'tumor_stage': 'Not Performed'},
#             {'tumor_stage': 'Not Reported'},
#             {'tumor_stage': 'Not Reported/ Unknown'},
#             {'tumor_stage': 'Not Reported/Unknown'},
#             {'tumor_stage': 'Stage 1B'},
#             {'tumor_stage': 'Stage I'},
#             {'tumor_stage': 'Stage IA'},
#             {'tumor_stage': 'Stage IA3'},
#             {'tumor_stage': 'Stage IB'},
#             {'tumor_stage': 'Stage IC'},
#             {'tumor_stage': 'Stage II'},
#             {'tumor_stage': 'Stage IIA'},
#             {'tumor_stage': 'Stage IIB'},
#             {'tumor_stage': 'Stage III'},
#             {'tumor_stage': 'Stage IIIA'},
#             {'tumor_stage': 'Stage IIIB'},
#             {'tumor_stage': 'Stage IIIC'},
#             {'tumor_stage': 'Stage IV'},
#             {'tumor_stage': 'Stage IVA'},
#             {'tumor_stage': 'Stage1'},
#             {'tumor_stage': 'Unknown'},
#             {'tumor_stage': 'no resection'},
#             {'tumor_stage': 'pT1'},
#             {'tumor_stage': 'pT1a'},
#             {'tumor_stage': 'pT1b'},
#             {'tumor_stage': 'pT2 N0'},
#             {'tumor_stage': 'pT2, pN2, pM not applicable'},
#             {'tumor_stage': 'pT2N1'},
#             {'tumor_stage': 'pT2N2'},
#             {'tumor_stage': 'pT3 N2 M(Not Applicable)'},
#             {'tumor_stage': 'pT3a'},
#             {'tumor_stage': 'pT4'},
#             {'tumor_stage': 'stage iiic'}]}

# %% [markdown]
# Now we can explore the use of tumor_stage across projects.

# %%
sql = '''SELECT _Diagnosis.tumor_stage, _ResearchSubject.associated_project , count(*) row_count
FROM `gdc-bq-sample.cda_mvp.v3`, 
UNNEST(ResearchSubject) AS _ResearchSubject,
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis 
WHERE _Diagnosis.tumor_stage in ('IIIC', 'Stage IIIC', 'stage iiic')
group BY _ResearchSubject.associated_project, _Diagnosis.tumor_stage
order BY _ResearchSubject.associated_project, _Diagnosis.tumor_stage '''

api_response = api_instance.sql_query('v3',sql)
print(api_response)
# Out:
# {'next_url': None,
#  'previous_url': None,
#  'query_sql': 'SELECT _Diagnosis.tumor_stage, '
#               '_ResearchSubject.associated_project , count(*) row_count\n'
#               'FROM `gdc-bq-sample.cda_mvp.v3`, \n'
#               'UNNEST(ResearchSubject) AS _ResearchSubject,\n'
#               'UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis \n'
#               "WHERE _Diagnosis.tumor_stage in ('IIIC', 'Stage IIIC', 'stage "
#               "iiic')\n"
#               'group BY _ResearchSubject.associated_project, '
#               '_Diagnosis.tumor_stage\n'
#               'order BY _ResearchSubject.associated_project, '
#               '_Diagnosis.tumor_stage ',
#  'result': [{'associated_project': 'CPTAC-2',
#              'row_count': 66,
#              'tumor_stage': 'IIIC'},
#             {'associated_project': 'CPTAC-2',
#              'row_count': 92,
#              'tumor_stage': 'Stage IIIC'},
#             {'associated_project': 'CPTAC-TCGA',
#              'row_count': 13,
#              'tumor_stage': 'Stage IIIC'},
#             {'associated_project': 'CPTAC-TCGA',
#              'row_count': 1,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-BRCA',
#              'row_count': 65,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-COAD',
#              'row_count': 41,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-ESCA',
#              'row_count': 7,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-LIHC',
#              'row_count': 9,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-READ',
#              'row_count': 14,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-SKCM',
#              'row_count': 68,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-STAD',
#              'row_count': 38,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-TGCT',
#              'row_count': 5,
#              'tumor_stage': 'stage iiic'},
#             {'associated_project': 'TCGA-UVM',
#              'row_count': 1,
#              'tumor_stage': 'stage iiic'}]}

# %% [markdown]
# It's hard to see what's going on when looking at json. A DataFrame is more compact and makes a visual scan easier. Fortunately the list of dicts returned by the client is tailor made for a DataFrame.

# %%
import pandas as pd
pd.DataFrame(api_response.result,  index=None)
# Out:
#    tumor_stage associated_project  row_count
# 0         IIIC            CPTAC-2         66
# 1   Stage IIIC            CPTAC-2         92
# 2   Stage IIIC         CPTAC-TCGA         13
# 3   stage iiic         CPTAC-TCGA          1
# 4   stage iiic          TCGA-BRCA         65
# 5   stage iiic          TCGA-COAD         41
# 6   stage iiic          TCGA-ESCA          7
# 7   stage iiic          TCGA-LIHC          9
# 8   stage iiic          TCGA-READ         14
# 9   stage iiic          TCGA-SKCM         68
# 10  stage iiic          TCGA-STAD         38
# 11  stage iiic          TCGA-TGCT          5
# 12  stage iiic           TCGA-UVM          1

# %% [markdown]
# ### Exploring the Subject 09CO022 example via SQL
# Start with the same SQL that was generated by cdapython

# %%
import json
query = '''SELECT * FROM gdc-bq-sample.cda_mvp.v3, 
UNNEST(ResearchSubject) AS _ResearchSubject 
WHERE (_ResearchSubject.id = 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d')'''
api_response = api_instance.sql_query('v3',query)
print(json.dumps(api_response.result,indent=3))
# Out:
# [
#    {
#       "days_to_birth": null,
#       "race": "black or african american",
#       "sex": "female",
#       "ethnicity": "not hispanic or latino",
#       "id": "c5421e34-e5c7-4ba5-aed9-146a5575fd8d",
#       "ResearchSubject": [
#          {
#             "Diagnosis": [
#                {
#                   "morphology": "8140/3",
#                   "tumor_stage": "Stage IIB",
#                   "tumor_grade": "Not Reported",
#                   "Treatment": [],
#                   "id": "7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb",
#                   "primary_diagnosis": "Adenocarcinoma, NOS",
#                   "age_at_diagnosis": null
#                }
#             ],
#             "Specimen": [
#                {
#                   "File": [
#                      {
#                         "label": "fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "00a9219e-109c-4013-89c8-3d01b39cd9bf"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 248056,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "e09e988c4969cf68fac8168fa622df9f",
#                         "id": "00a9219e-109c-4013-89c8-3d01b39cd9bf",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "18b4dd00-f22a-4904-92f8-11d03fc21e44"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 1611219,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "5eab6ca0fbbb67a3204e55266161dc55",
#                         "id": "18b4dd00-f22a-4904-92f8-11d03fc21e44",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "1fb29f83-87a5-416d-8af1-d94d749aeda9"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 7547974,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "2ab8ea64673f22be2fc3ae40ce3356eb",
#                         "id": "1fb29f83-87a5-416d-8af1-d94d749aeda9",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.star_splice_junctions.tsv.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:251c0ac2-9ba0-43ca-acc1-01e9638b1250",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "251c0ac2-9ba0-43ca-acc1-01e9638b1250"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 2472314,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "f81e25701c17eab29bdee4223c82cc56",
#                         "id": "251c0ac2-9ba0-43ca-acc1-01e9638b1250",
#                         "data_type": "Splice Junction Quantification"
#                      },
#                      {
#                         "label": "a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.genomic.gdc_realn.bam",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:38a714a2-ea50-487f-b184-fc3e2fbb8635",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "38a714a2-ea50-487f-b184-fc3e2fbb8635"
#                            }
#                         ],
#                         "data_category": "Sequencing Reads",
#                         "byte_size": 4414014860,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "46f5800fb243249938ddf09fc95ed416",
#                         "id": "38a714a2-ea50-487f-b184-fc3e2fbb8635",
#                         "data_type": "Aligned Reads"
#                      },
#                      {
#                         "label": "6cca2f97-024b-4d5f-a753-bf148725ec8c.htseq_counts.txt.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:502ada14-06bf-48ae-9f57-66646a9c8fa0",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "502ada14-06bf-48ae-9f57-66646a9c8fa0"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 238654,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "a15b1b8c641407a9c8fa3756fc86d7c6",
#                         "id": "502ada14-06bf-48ae-9f57-66646a9c8fa0",
#                         "data_type": "Gene Expression Quantification"
#                      },
#                      {
#                         "label": "dfecdd3f-a8eb-4e69-8713-85170b11fe2a.mirnaseq.mirnas.quantification.txt",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:527f7662-b314-44ba-998b-99d1dfc7ae33",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "527f7662-b314-44ba-998b-99d1dfc7ae33"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 49839,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "3540412c79caa600aef56f928fed04aa",
#                         "id": "527f7662-b314-44ba-998b-99d1dfc7ae33",
#                         "data_type": "miRNA Expression Quantification"
#                      },
#                      {
#                         "label": "0d8adcbf-13f0-48c3-83df-3fa205b79ae8_mirnaseq_gdc_realn.bam",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:5dd36db9-d94c-412a-8cc6-7cc2f43b890c",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "5dd36db9-d94c-412a-8cc6-7cc2f43b890c"
#                            }
#                         ],
#                         "data_category": "Sequencing Reads",
#                         "byte_size": 265126753,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "14982035c8909b3747d03a23924c5af0",
#                         "id": "5dd36db9-d94c-412a-8cc6-7cc2f43b890c",
#                         "data_type": "Aligned Reads"
#                      },
#                      {
#                         "label": "a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.star_gene_counts.tsv.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:5e0db211-7fa4-477d-b642-ec5082d99e88",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "5e0db211-7fa4-477d-b642-ec5082d99e88"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 369648,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "38e816e53699daac1474a27681ee315c",
#                         "id": "5e0db211-7fa4-477d-b642-ec5082d99e88",
#                         "data_type": "Gene Expression Quantification"
#                      },
#                      {
#                         "label": "17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "654ba668-6f5f-497b-acd4-c41bd8e18e9e"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 163494,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "fabcd676c20684a8df20be63e49756a4",
#                         "id": "654ba668-6f5f-497b-acd4-c41bd8e18e9e",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "65d6fa7c-d474-4466-9b7d-a21b245237f7"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 43887,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "cc174a5c968bd1dfc464c22fb1244f2b",
#                         "id": "65d6fa7c-d474-4466-9b7d-a21b245237f7",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "6bb0f620-8925-4cd4-89c2-f0477d334ee9"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 5005951,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "f1582d896290ad6c93f4ee97195fb5a9",
#                         "id": "6bb0f620-8925-4cd4-89c2-f0477d334ee9",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "dfecdd3f-a8eb-4e69-8713-85170b11fe2a.mirnaseq.isoforms.quantification.txt",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:6e56cf8c-acb9-4a34-a3d8-ec0060a19193",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "6e56cf8c-acb9-4a34-a3d8-ec0060a19193"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 425670,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "3d57646194512126325c59177b8e537b",
#                         "id": "6e56cf8c-acb9-4a34-a3d8-ec0060a19193",
#                         "data_type": "Isoform Expression Quantification"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "7247faf2-afb0-4a39-9a55-9d471de5c550"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 115646,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "0dd012d2a55bedca6921fad581fbbd27",
#                         "id": "7247faf2-afb0-4a39-9a55-9d471de5c550",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "9250d96e-1cdc-4d68-8a56-f7b186a6fab5_wxs_gdc_realn.bam",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:73e507f1-8e2f-400d-acd6-ee9a9ad338e9",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "73e507f1-8e2f-400d-acd6-ee9a9ad338e9"
#                            }
#                         ],
#                         "data_category": "Sequencing Reads",
#                         "byte_size": 59654562246,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "6e2a2dbfef2574f49c261d1e567316b3",
#                         "id": "73e507f1-8e2f-400d-acd6-ee9a9ad338e9",
#                         "data_type": "Aligned Reads"
#                      },
#                      {
#                         "label": "96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "77a179fc-a3bc-462e-8209-979b9a031e20"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 342713,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "35d6d356b65c552962845a5f963db28a",
#                         "id": "77a179fc-a3bc-462e-8209-979b9a031e20",
#                         "data_type": "Aggregated Somatic Mutation"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "849452d3-3a1c-4f3d-a7c2-3e0b7580efec"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 50325,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "5dab4cb237c6bdf9f26938510d9f6442",
#                         "id": "849452d3-3a1c-4f3d-a7c2-3e0b7580efec",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "6cca2f97-024b-4d5f-a753-bf148725ec8c.FPKM-UQ.txt.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:8bea647e-66d8-42af-ab06-7bd0629179c7",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "8bea647e-66d8-42af-ab06-7bd0629179c7"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 371625,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "7a0a86367f6f1129851e2d9152813c8c",
#                         "id": "8bea647e-66d8-42af-ab06-7bd0629179c7",
#                         "data_type": "Gene Expression Quantification"
#                      },
#                      {
#                         "label": "96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 53313,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "dc22add6654662c05c787407c20b4578",
#                         "id": "8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb",
#                         "data_type": "Masked Somatic Mutation"
#                      },
#                      {
#                         "label": "6cca2f97-024b-4d5f-a753-bf148725ec8c.FPKM.txt.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:8f4884a5-9726-4abc-8e3b-db4f1b603dfa",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "8f4884a5-9726-4abc-8e3b-db4f1b603dfa"
#                            }
#                         ],
#                         "data_category": "Transcriptome Profiling",
#                         "byte_size": 295185,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "a641a766218e0b4be0ffe05aa3229ac2",
#                         "id": "8f4884a5-9726-4abc-8e3b-db4f1b603dfa",
#                         "data_type": "Gene Expression Quantification"
#                      },
#                      {
#                         "label": "a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.transcriptome.gdc_realn.bam",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:91d7d870-2331-472f-bc74-19c1d9f4d6c7",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "91d7d870-2331-472f-bc74-19c1d9f4d6c7"
#                            }
#                         ],
#                         "data_category": "Sequencing Reads",
#                         "byte_size": 7602867805,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "ecce292cfbab62abf3e911a98579e5f3",
#                         "id": "91d7d870-2331-472f-bc74-19c1d9f4d6c7",
#                         "data_type": "Aligned Reads"
#                      },
#                      {
#                         "label": "ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "9c18aa38-5edd-40cf-8389-a03aea35a150"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 6167311,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "765119382d413e7051cedb1ad122d436",
#                         "id": "9c18aa38-5edd-40cf-8389-a03aea35a150",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 767641,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "641b13968bf9401223d29e9f3350804c",
#                         "id": "9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "9f27b7a7-7e18-42c8-a5bd-62461a567955"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 305442,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "ef18bf2c57161d8a48256f6f9fd3c441",
#                         "id": "9f27b7a7-7e18-42c8-a5bd-62461a567955",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.chimeric.gdc_realn.bam",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:a97b91db-1804-4f0a-8cdd-10e4cb30d458",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "a97b91db-1804-4f0a-8cdd-10e4cb30d458"
#                            }
#                         ],
#                         "data_category": "Sequencing Reads",
#                         "byte_size": 20460524,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "31b766f0f934513062f5213dc9740b94",
#                         "id": "a97b91db-1804-4f0a-8cdd-10e4cb30d458",
#                         "data_type": "Aligned Reads"
#                      },
#                      {
#                         "label": "0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "b8ecf468-dd33-4f43-8093-544d92d676f6"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 438051,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "52a6cc7af0c366fd93240a49998289ff",
#                         "id": "b8ecf468-dd33-4f43-8093-544d92d676f6",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "c411fd62-0198-4c47-ada8-0cffafb5a262"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 5936384,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "6d07c80d2683a58c9e656ee165570f35",
#                         "id": "c411fd62-0198-4c47-ada8-0cffafb5a262",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "d7b978a6-a601-4025-8408-ee1fdb391689"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 4001912,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "ec3a6c924c6f10268a0b3f5de77c2e4d",
#                         "id": "d7b978a6-a601-4025-8408-ee1fdb391689",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "d4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "dd6923a5-8fcc-4bc9-8912-14b20f387214"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 567540,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "da2b85a5ffd55a7884557784684ab45d",
#                         "id": "dd6923a5-8fcc-4bc9-8912-14b20f387214",
#                         "data_type": "Annotated Somatic Mutation"
#                      }
#                   ],
#                   "derived_from_specimen": "Initial sample",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "sample",
#                   "id": "4591a53d-5668-4a70-b44b-e08a3d59267e",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "4591a53d-5668-4a70-b44b-e08a3d59267e"
#                      }
#                   ]
#                },
#                {
#                   "File": [],
#                   "derived_from_specimen": "4591a53d-5668-4a70-b44b-e08a3d59267e",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "portion",
#                   "id": "c53c4d60-2ddb-5da8-932e-00a86fa2347f",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "c53c4d60-2ddb-5da8-932e-00a86fa2347f"
#                      }
#                   ]
#                },
#                {
#                   "File": [],
#                   "derived_from_specimen": "c53c4d60-2ddb-5da8-932e-00a86fa2347f",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "analyte",
#                   "id": "31075cfa-7aef-59f1-bf54-a1cddb5ee0fd",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "31075cfa-7aef-59f1-bf54-a1cddb5ee0fd"
#                      }
#                   ]
#                },
#                {
#                   "File": [],
#                   "derived_from_specimen": "31075cfa-7aef-59f1-bf54-a1cddb5ee0fd",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "aliquot",
#                   "id": "0d8adcbf-13f0-48c3-83df-3fa205b79ae8",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "0d8adcbf-13f0-48c3-83df-3fa205b79ae8"
#                      }
#                   ]
#                },
#                {
#                   "File": [],
#                   "derived_from_specimen": "4591a53d-5668-4a70-b44b-e08a3d59267e",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "portion",
#                   "id": "d085ebd9-7605-54a0-abb9-10867f5fa1b1",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "d085ebd9-7605-54a0-abb9-10867f5fa1b1"
#                      }
#                   ]
#                },
#                {
#                   "File": [],
#                   "derived_from_specimen": "d085ebd9-7605-54a0-abb9-10867f5fa1b1",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "analyte",
#                   "id": "a31724b6-e550-552b-bd61-41341c534e28",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "a31724b6-e550-552b-bd61-41341c534e28"
#                      }
#                   ]
#                },
#                {
#                   "File": [],
#                   "derived_from_specimen": "a31724b6-e550-552b-bd61-41341c534e28",
#                   "associated_project": "CPTAC-2",
#                   "age_at_collection": null,
#                   "anatomical_site": null,
#                   "source_material_type": "Primary Tumor",
#                   "derived_from_subject": "09CO022",
#                   "specimen_type": "aliquot",
#                   "id": "9250d96e-1cdc-4d68-8a56-f7b186a6fab5",
#                   "primary_disease_type": "Adenomas and Adenocarcinomas",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "9250d96e-1cdc-4d68-8a56-f7b186a6fab5"
#                      }
#                   ]
#                },
#                {
#                   "File": [
#                      {
#                         "label": "fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "00a9219e-109c-4013-89c8-3d01b39cd9bf"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 248056,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "e09e988c4969cf68fac8168fa622df9f",
#                         "id": "00a9219e-109c-4013-89c8-3d01b39cd9bf",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "18b4dd00-f22a-4904-92f8-11d03fc21e44"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 1611219,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "5eab6ca0fbbb67a3204e55266161dc55",
#                         "id": "18b4dd00-f22a-4904-92f8-11d03fc21e44",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "1fb29f83-87a5-416d-8af1-d94d749aeda9"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 7547974,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "2ab8ea64673f22be2fc3ae40ce3356eb",
#                         "id": "1fb29f83-87a5-416d-8af1-d94d749aeda9",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "654ba668-6f5f-497b-acd4-c41bd8e18e9e"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 163494,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "fabcd676c20684a8df20be63e49756a4",
#                         "id": "654ba668-6f5f-497b-acd4-c41bd8e18e9e",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "65d6fa7c-d474-4466-9b7d-a21b245237f7"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 43887,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "cc174a5c968bd1dfc464c22fb1244f2b",
#                         "id": "65d6fa7c-d474-4466-9b7d-a21b245237f7",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "6bb0f620-8925-4cd4-89c2-f0477d334ee9"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 5005951,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "f1582d896290ad6c93f4ee97195fb5a9",
#                         "id": "6bb0f620-8925-4cd4-89c2-f0477d334ee9",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "7247faf2-afb0-4a39-9a55-9d471de5c550"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 115646,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "0dd012d2a55bedca6921fad581fbbd27",
#                         "id": "7247faf2-afb0-4a39-9a55-9d471de5c550",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "77a179fc-a3bc-462e-8209-979b9a031e20"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 342713,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "35d6d356b65c552962845a5f963db28a",
#                         "id": "77a179fc-a3bc-462e-8209-979b9a031e20",
#                         "data_type": "Aggregated Somatic Mutation"
#                      },
#                      {
#                         "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "849452d3-3a1c-4f3d-a7c2-3e0b7580efec"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 50325,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "5dab4cb237c6bdf9f26938510d9f6442",
#                         "id": "849452d3-3a1c-4f3d-a7c2-3e0b7580efec",
#                         "data_type": "Raw Simple Somatic Mutation"
#                      },
#                      {
#                         "label": "96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 53313,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "dc22add6654662c05c787407c20b4578",
#                         "id": "8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb",
#                         "data_type": "Masked Somatic Mutation"
#                      },
#                      {
#                         "label": "ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "9c18aa38-5edd-40cf-8389-a03aea35a150"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 6167311,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "765119382d413e7051cedb1ad122d436",
#                         "id": "9c18aa38-5edd-40cf-8389-a03aea35a150",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
#                         "drs_uri": "drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1",
#                         "identifier": [
#                            {
#                               "system": "GDC",
#                               "value": "9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1"
#                            }
#                         ],
#                         "data_category": "Simple Nucleotide Variation",
#                         "byte_size": 767641,
#                         "type": null,
#                         "file_format": null,
#                         "checksum": "641b13968bf9401223d29e9f3350804c",
#                         "id": "9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1",
#                         "data_type": "Annotated Somatic Mutation"
#                      },
#                      {
#                         "label": "a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz",
#                         "associated_project": [
#                            "CPTAC-2"
#                         ],
# ...
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 163494,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "fabcd676c20684a8df20be63e49756a4",
#                   "id": "654ba668-6f5f-497b-acd4-c41bd8e18e9e",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "65d6fa7c-d474-4466-9b7d-a21b245237f7"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 43887,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "cc174a5c968bd1dfc464c22fb1244f2b",
#                   "id": "65d6fa7c-d474-4466-9b7d-a21b245237f7",
#                   "data_type": "Raw Simple Somatic Mutation"
#                },
#                {
#                   "label": "70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "6bb0f620-8925-4cd4-89c2-f0477d334ee9"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 5005951,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "f1582d896290ad6c93f4ee97195fb5a9",
#                   "id": "6bb0f620-8925-4cd4-89c2-f0477d334ee9",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "7247faf2-afb0-4a39-9a55-9d471de5c550"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 115646,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "0dd012d2a55bedca6921fad581fbbd27",
#                   "id": "7247faf2-afb0-4a39-9a55-9d471de5c550",
#                   "data_type": "Raw Simple Somatic Mutation"
#                },
#                {
#                   "label": "96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "77a179fc-a3bc-462e-8209-979b9a031e20"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 342713,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "35d6d356b65c552962845a5f963db28a",
#                   "id": "77a179fc-a3bc-462e-8209-979b9a031e20",
#                   "data_type": "Aggregated Somatic Mutation"
#                },
#                {
#                   "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "849452d3-3a1c-4f3d-a7c2-3e0b7580efec"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 50325,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "5dab4cb237c6bdf9f26938510d9f6442",
#                   "id": "849452d3-3a1c-4f3d-a7c2-3e0b7580efec",
#                   "data_type": "Raw Simple Somatic Mutation"
#                },
#                {
#                   "label": "96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 53313,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "dc22add6654662c05c787407c20b4578",
#                   "id": "8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb",
#                   "data_type": "Masked Somatic Mutation"
#                },
#                {
#                   "label": "ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "9c18aa38-5edd-40cf-8389-a03aea35a150"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 6167311,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "765119382d413e7051cedb1ad122d436",
#                   "id": "9c18aa38-5edd-40cf-8389-a03aea35a150",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 767641,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "641b13968bf9401223d29e9f3350804c",
#                   "id": "9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "9f27b7a7-7e18-42c8-a5bd-62461a567955"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 305442,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "ef18bf2c57161d8a48256f6f9fd3c441",
#                   "id": "9f27b7a7-7e18-42c8-a5bd-62461a567955",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "ce309009-9257-4c13-9241-83fc629c35a0_wxs_gdc_realn.bam",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:a35f18eb-3475-4433-a72f-4b8aa2cb6106",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "a35f18eb-3475-4433-a72f-4b8aa2cb6106"
#                      }
#                   ],
#                   "data_category": "Sequencing Reads",
#                   "byte_size": 69157605164,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "21f2140d9d3ef197422820a7e0bb8561",
#                   "id": "a35f18eb-3475-4433-a72f-4b8aa2cb6106",
#                   "data_type": "Aligned Reads"
#                },
#                {
#                   "label": "0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "b8ecf468-dd33-4f43-8093-544d92d676f6"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 438051,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "52a6cc7af0c366fd93240a49998289ff",
#                   "id": "b8ecf468-dd33-4f43-8093-544d92d676f6",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "c411fd62-0198-4c47-ada8-0cffafb5a262"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 5936384,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "6d07c80d2683a58c9e656ee165570f35",
#                   "id": "c411fd62-0198-4c47-ada8-0cffafb5a262",
#                   "data_type": "Raw Simple Somatic Mutation"
#                },
#                {
#                   "label": "b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "d7b978a6-a601-4025-8408-ee1fdb391689"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 4001912,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "ec3a6c924c6f10268a0b3f5de77c2e4d",
#                   "id": "d7b978a6-a601-4025-8408-ee1fdb391689",
#                   "data_type": "Annotated Somatic Mutation"
#                },
#                {
#                   "label": "d4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz",
#                   "associated_project": [
#                      "CPTAC-2"
#                   ],
#                   "drs_uri": "drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214",
#                   "identifier": [
#                      {
#                         "system": "GDC",
#                         "value": "dd6923a5-8fcc-4bc9-8912-14b20f387214"
#                      }
#                   ],
#                   "data_category": "Simple Nucleotide Variation",
#                   "byte_size": 567540,
#                   "type": null,
#                   "file_format": null,
#                   "checksum": "da2b85a5ffd55a7884557784684ab45d",
#                   "id": "dd6923a5-8fcc-4bc9-8912-14b20f387214",
#                   "data_type": "Annotated Somatic Mutation"
#                }
#             ],
#             "derived_from_specimen": "Initial sample",
#             "associated_project": "CPTAC-2",
#             "age_at_collection": null,
#             "anatomical_site": null,
#             "source_material_type": "Blood Derived Normal",
#             "derived_from_subject": "09CO022",
#             "specimen_type": "sample",
#             "id": "b12c257d-7409-4858-9384-c430929a075a",
#             "primary_disease_type": "Adenomas and Adenocarcinomas",
#             "identifier": [
#                {
#                   "system": "GDC",
#                   "value": "b12c257d-7409-4858-9384-c430929a075a"
#                }
#             ]
#          },
#          {
#             "File": [],
#             "derived_from_specimen": "b12c257d-7409-4858-9384-c430929a075a",
#             "associated_project": "CPTAC-2",
#             "age_at_collection": null,
#             "anatomical_site": null,
#             "source_material_type": "Blood Derived Normal",
#             "derived_from_subject": "09CO022",
#             "specimen_type": "portion",
#             "id": "702d7ba0-9558-5b2d-af4d-cd797485b8c1",
#             "primary_disease_type": "Adenomas and Adenocarcinomas",
#             "identifier": [
#                {
#                   "system": "GDC",
#                   "value": "702d7ba0-9558-5b2d-af4d-cd797485b8c1"
#                }
#             ]
#          },
#          {
#             "File": [],
#             "derived_from_specimen": "702d7ba0-9558-5b2d-af4d-cd797485b8c1",
#             "associated_project": "CPTAC-2",
#             "age_at_collection": null,
#             "anatomical_site": null,
#             "source_material_type": "Blood Derived Normal",
#             "derived_from_subject": "09CO022",
#             "specimen_type": "analyte",
#             "id": "f0003f0a-07ea-548e-b1f7-7e6d1b27d47a",
#             "primary_disease_type": "Adenomas and Adenocarcinomas",
#             "identifier": [
#                {
#                   "system": "GDC",
#                   "value": "f0003f0a-07ea-548e-b1f7-7e6d1b27d47a"
#                }
#             ]
#          },
#          {
#             "File": [],
#             "derived_from_specimen": "f0003f0a-07ea-548e-b1f7-7e6d1b27d47a",
#             "associated_project": "CPTAC-2",
#             "age_at_collection": null,
#             "anatomical_site": null,
#             "source_material_type": "Blood Derived Normal",
#             "derived_from_subject": "09CO022",
#             "specimen_type": "aliquot",
#             "id": "ce309009-9257-4c13-9241-83fc629c35a0",
#             "primary_disease_type": "Adenomas and Adenocarcinomas",
#             "identifier": [
#                {
#                   "system": "GDC",
#                   "value": "ce309009-9257-4c13-9241-83fc629c35a0"
#                }
#             ]
#          }
#       ],
#       "associated_project": "CPTAC-2",
#       "primary_disease_type": "Adenomas and Adenocarcinomas",
#       "identifier": [
#          {
#             "system": "GDC",
#             "value": "c5421e34-e5c7-4ba5-aed9-146a5575fd8d"
#          }
#       ],
#       "primary_disease_site": "Colon"
#    }
# ]

# %% [markdown]
# Two things of note from that. One strategic, and one more fine detailed, but with strategic implications.
#
# First, it brings home that the duplication referred to in the 09CO022 example is baked into the cda_mvp.v3 table, and is a product of the ETL. The key to data aggregation is how that mapping is done - specifically how are the mappings created, managed and used. Also the question of whether one mapping works for all. There is a follow on from that - namely the choice between ETL to a static store vs on the fly mapping as needed.
#
# Second, careful inspection of the result above shows that the for this subject at least the Stage was consistently used across both PDC and GDC. Historical knowledge suggests that the subject record in CPTAC-2 (the data in PDC) was copied across from TCGA (the data now in GDC).
#
# Besides visual review we can check the above programmatically

# %%
def printSubject(subject, indent=0):
    ident = subject['identifier'][0]
    print(('\t'*(indent+1)+'system:{} id:{}').format(ident['system'], ident['value']))
    diag = subject['Diagnosis'][0]
    print('\t'*(indent+1) + diag['tumor_stage'])

    print('\t'*(indent+1) + str(diag['age_at_diagnosis']))
    print()

    
for subject in api_response.result:
    printSubject(subject)
    for nestedSubject in subject['ResearchSubject']:
        printSubject(nestedSubject, indent=1)
# Out:
# 	system:GDC id:c5421e34-e5c7-4ba5-aed9-146a5575fd8d
# 	Stage IIB
# 	None
#
# 		system:GDC id:c5421e34-e5c7-4ba5-aed9-146a5575fd8d
# 		Stage IIB
# 		None
#
# 		system:PDC id:459e3b69-63d6-11e8-bcf1-0a2705229b82
# 		Stage IIB
# 		None

# %% [markdown]
# That said, we can see that 'IIIC' was also used for tumor_stage in CPTAC2. What if we look at those records.

# %%
sql = '''SELECT * FROM gdc-bq-sample.cda_mvp.v3, 
UNNEST(ResearchSubject) AS _ResearchSubject ,
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis 
WHERE _Diagnosis.tumor_stage ='IIIC'
'''

api_response = api_instance.sql_query('v3',sql)
for subject in api_response.result:
    printSubject(subject)
    for nestedSubject in subject['ResearchSubject']:
        printSubject(nestedSubject, indent=1)
# Out:
# 	system:GDC id:b295d458-952a-42af-9f7f-2c07e895990c
# 	IIIC
# 	None
#
# 		system:GDC id:b295d458-952a-42af-9f7f-2c07e895990c
# 		IIIC
# 		None
#
# 	system:GDC id:c3a430fe-641e-4b7b-884e-9735908692d6
# 	IIIC
# 	None
#
# 		system:GDC id:c3a430fe-641e-4b7b-884e-9735908692d6
# 		IIIC
# 		None
#
# 		system:PDC id:526a3f3c-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:dc8e3901-b845-4419-8f76-d31750eacf60
# 	IIIC
# 	None
#
# 		system:GDC id:dc8e3901-b845-4419-8f76-d31750eacf60
# 		IIIC
# 		None
#
# 		system:PDC id:526a3b90-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:6f493081-5bd6-4d07-9a36-b775eda105e1
# 	IIIC
# 	None
#
# 		system:GDC id:6f493081-5bd6-4d07-9a36-b775eda105e1
# 		IIIC
# 		None
#
# 		system:PDC id:526a3d60-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:9d33308f-f7cc-420e-9116-b9a95068d045
# 	IIIC
# 	None
#
# 		system:GDC id:9d33308f-f7cc-420e-9116-b9a95068d045
# 		IIIC
# 		None
#
# 		system:PDC id:33f2e3fb-63d7-11e8-bcf1-0a2705229b82
# 		Stage IIIC
# 		0
#
# 	system:GDC id:01026cf5-8582-4864-8e89-111c05660eb6
# 	IIIC
# 	None
#
# 		system:GDC id:01026cf5-8582-4864-8e89-111c05660eb6
# 		IIIC
# 		None
#
# 		system:PDC id:526aa37f-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:742033a6-ba74-4871-9046-14972d6676e4
# 	IIIC
# 	None
#
# 		system:GDC id:742033a6-ba74-4871-9046-14972d6676e4
# 		IIIC
# 		None
#
# 		system:PDC id:526a9fbc-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:fb3f8ed1-cc6f-406b-8b3d-a5eeff0b4196
# 	IIIC
# 	None
#
# 		system:GDC id:fb3f8ed1-cc6f-406b-8b3d-a5eeff0b4196
# 		IIIC
# 		None
#
# 		system:PDC id:526aa6dd-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:296336a2-8f88-4a26-8c34-7cdf22dd8f9c
# 	IIIC
# 	None
#
# 		system:GDC id:296336a2-8f88-4a26-8c34-7cdf22dd8f9c
# 		IIIC
# 		None
#
# 		system:PDC id:526a91cb-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:6223da27-571c-4ace-80d7-9245693382f3
# 	IIIC
# 	None
#
# 		system:GDC id:6223da27-571c-4ace-80d7-9245693382f3
# 		IIIC
# 		None
#
# 		system:PDC id:526a8712-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:29de0047-aca8-4b3d-b626-77e593977e30
# 	IIIC
# 	None
#
# 		system:GDC id:29de0047-aca8-4b3d-b626-77e593977e30
# 		IIIC
# 		None
#
# 		system:PDC id:526a79a5-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:35e72ed7-d7a0-4720-af25-ad4336fa7d89
# 	IIIC
# 	None
#
# 		system:GDC id:35e72ed7-d7a0-4720-af25-ad4336fa7d89
# 		IIIC
# 		None
#
# 		system:PDC id:526a548e-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:cee465f1-3162-49de-ba8c-29b2f989a7bb
# 	IIIC
# 	None
#
# 		system:GDC id:cee465f1-3162-49de-ba8c-29b2f989a7bb
# 		IIIC
# 		None
#
# 		system:PDC id:526a9cc6-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:82ba31a6-dd05-4f6f-88d9-8f961822d732
# 	IIIC
# 	None
#
# 		system:GDC id:82ba31a6-dd05-4f6f-88d9-8f961822d732
# 		IIIC
# 		None
#
# 		system:PDC id:526a662f-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:99d74447-9236-438c-8543-e876b4daa8bf
# 	IIIC
# 	None
#
# 		system:GDC id:99d74447-9236-438c-8543-e876b4daa8bf
# 		IIIC
# 		None
#
# 		system:PDC id:526a47af-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:2c8ff3ae-ef06-4e3c-b198-fb8f57ebbd61
# 	IIIC
# 	None
#
# 		system:GDC id:2c8ff3ae-ef06-4e3c-b198-fb8f57ebbd61
# 		IIIC
# 		None
#
# 		system:PDC id:526a8c5a-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:11ed8b7d-2483-4b5e-9893-3376d1d49672
# 	IIIC
# 	None
#
# 		system:GDC id:11ed8b7d-2483-4b5e-9893-3376d1d49672
# 		IIIC
# 		None
#
# 		system:PDC id:526a4d66-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:76d72a27-a410-45e9-954f-394bb32bac91
# 	IIIC
# 	None
#
# 		system:GDC id:76d72a27-a410-45e9-954f-394bb32bac91
# 		IIIC
# 		None
#
# 		system:PDC id:526a77f1-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:aa529cf5-9837-495d-9d5d-6c81460cbac1
# 	IIIC
# 	None
#
# 		system:GDC id:aa529cf5-9837-495d-9d5d-6c81460cbac1
# 		IIIC
# 		None
#
# 		system:PDC id:526a5c31-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:cbbd64b3-258c-4639-9462-d1b08f4ffc25
# 	IIIC
# 	None
#
# 		system:GDC id:cbbd64b3-258c-4639-9462-d1b08f4ffc25
# 		IIIC
# 		None
#
# 		system:PDC id:f9687f24-63d6-11e8-bcf1-0a2705229b82
# 		Stage IIIC
# 		0
#
# 	system:GDC id:a7deae0d-38d2-46e4-a90b-f79f57fd2808
# 	IIIC
# 	None
#
# 		system:GDC id:a7deae0d-38d2-46e4-a90b-f79f57fd2808
# 		IIIC
# 		None
#
# 		system:PDC id:526aad86-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:07ac108d-4f71-4049-832c-f800c3e6c047
# 	IIIC
# 	None
#
# 		system:GDC id:07ac108d-4f71-4049-832c-f800c3e6c047
# 		IIIC
# 		None
#
# 		system:PDC id:526a6457-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:0bb7be19-e7c9-46f2-b1b3-f83f3b213475
# 	IIIC
# 	None
#
# 		system:GDC id:0bb7be19-e7c9-46f2-b1b3-f83f3b213475
# 		IIIC
# 		None
#
# 		system:PDC id:526a8f0c-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:0ed2be8e-1d7b-4a08-9740-f642377d58c9
# 	IIIC
# 	None
#
# 		system:GDC id:0ed2be8e-1d7b-4a08-9740-f642377d58c9
# 		IIIC
# 		None
#
# 		system:PDC id:526a847d-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:9672bd02-c6f4-4884-9c3c-ec62abd2f0ea
# 	IIIC
# 	None
#
# 		system:GDC id:9672bd02-c6f4-4884-9c3c-ec62abd2f0ea
# 		IIIC
# 		None
#
# 		system:PDC id:526a6716-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:0f875052-cf76-45f2-9c76-021ee605479d
# 	IIIC
# 	None
#
# 		system:GDC id:0f875052-cf76-45f2-9c76-021ee605479d
# 		IIIC
# 		None
#
# 		system:PDC id:526a83a7-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:7d7fba6d-9bbb-44a6-b91c-ca97277e49b2
# 	IIIC
# 	None
#
# 		system:GDC id:7d7fba6d-9bbb-44a6-b91c-ca97277e49b2
# 		IIIC
# 		None
#
# 		system:PDC id:526a75e7-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:7e06a271-ede9-40dc-a5f1-6eebaa82de8b
# 	IIIC
# 	None
#
# 		system:GDC id:7e06a271-ede9-40dc-a5f1-6eebaa82de8b
# 		IIIC
# 		None
#
# 		system:PDC id:526a6a80-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:4f552cb7-0380-4918-82ea-1f38562406b9
# 	IIIC
# 	None
#
# 		system:GDC id:4f552cb7-0380-4918-82ea-1f38562406b9
# 		IIIC
# 		None
#
# 		system:PDC id:526a42f3-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:1c43fd26-93f7-4ac8-84fe-e861bca119d9
# 	IIIC
# 	None
#
# 		system:GDC id:1c43fd26-93f7-4ac8-84fe-e861bca119d9
# 		IIIC
# 		None
#
# 		system:PDC id:526a53ac-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:d90249dc-40e8-449e-a24a-6d461f29f632
# 	IIIC
# 	None
#
# 		system:GDC id:d90249dc-40e8-449e-a24a-6d461f29f632
# 		IIIC
# 		None
#
# 		system:PDC id:526aabd0-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:c17ddbe9-0957-4c3d-9c2e-846fc5a9aee0
# 	IIIC
# 	None
#
# 		system:GDC id:c17ddbe9-0957-4c3d-9c2e-846fc5a9aee0
# 		IIIC
# 		None
#
# 		system:PDC id:526a488e-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:718dff52-0d0b-48d6-89c1-cf594a6ab883
# 	IIIC
# 	None
#
# 		system:GDC id:718dff52-0d0b-48d6-89c1-cf594a6ab883
# 		IIIC
# 		None
#
# 		system:PDC id:526a5f28-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:1e8ca30b-0bd0-426f-b2fd-2a84f3c0df26
# 	IIIC
# 	None
#
# 		system:GDC id:1e8ca30b-0bd0-426f-b2fd-2a84f3c0df26
# 		IIIC
# 		None
#
# 		system:PDC id:526a78cd-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:1a114bb5-b3de-4e8e-8038-6436c70781ff
# 	IIIC
# 	None
#
# 		system:GDC id:1a114bb5-b3de-4e8e-8038-6436c70781ff
# 		IIIC
# 		None
#
# 		system:PDC id:526a751a-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:fc1c474a-93d1-4faf-9180-cb4136043ef9
# 	IIIC
# 	None
#
# 		system:GDC id:fc1c474a-93d1-4faf-9180-cb4136043ef9
# 		IIIC
# 		None
#
# 		system:PDC id:526a70a6-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:faf8cebd-72ad-4da2-b55e-73cddd8dafff
# 	IIIC
# 	None
#
# 		system:GDC id:faf8cebd-72ad-4da2-b55e-73cddd8dafff
# 		IIIC
# 		None
#
# 		system:PDC id:526a4a82-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:53c60788-10b1-4ba1-afdd-63376587b7cb
# 	IIIC
# 	None
#
# 		system:GDC id:53c60788-10b1-4ba1-afdd-63376587b7cb
# 		IIIC
# 		None
#
# 		system:PDC id:526a5d16-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:1fe09e41-2ce0-4e8f-a05b-868afa54247d
# 	IIIC
# 	None
#
# 		system:GDC id:1fe09e41-2ce0-4e8f-a05b-868afa54247d
# 		IIIC
# 		None
#
# 		system:PDC id:c2cf7e96-63d5-11e8-bcf1-0a2705229b82
# 		Stage IIIC
# 		0
#
# 	system:GDC id:52e4305e-1ff0-4a92-a38a-136696eb8968
# 	IIIC
# 	None
#
# 		system:GDC id:52e4305e-1ff0-4a92-a38a-136696eb8968
# 		IIIC
# 		None
#
# 		system:PDC id:c58bad65-63d5-11e8-bcf1-0a2705229b82
# 		Stage IIIC
# 		0
#
# 	system:GDC id:83a99225-3034-4db7-a171-f073dbb087ca
# 	IIIC
# 	None
#
# 		system:GDC id:83a99225-3034-4db7-a171-f073dbb087ca
# 		IIIC
# 		None
#
# 		system:PDC id:526a3949-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:244b7d18-3975-45e6-b159-63e634749a3b
# 	IIIC
# 	None
#
# 		system:GDC id:244b7d18-3975-45e6-b159-63e634749a3b
# 		IIIC
# 		None
#
# 		system:PDC id:526a6387-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:7cee15a6-0f80-42c8-9120-322226def3fc
# 	IIIC
# 	None
#
# 		system:GDC id:7cee15a6-0f80-42c8-9120-322226def3fc
# 		IIIC
# 		None
#
# 		system:PDC id:526a6002-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:485a9225-48b0-4f4e-a59a-299046e2e992
# 	IIIC
# 	None
#
# 		system:GDC id:485a9225-48b0-4f4e-a59a-299046e2e992
# 		IIIC
# 		None
#
# 		system:PDC id:526aab00-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:085fbb0b-0924-4c26-a240-94b13d1742b6
# 	IIIC
# 	None
#
# 		system:GDC id:085fbb0b-0924-4c26-a240-94b13d1742b6
# 		IIIC
# 		None
#
# 		system:PDC id:526aa0b0-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:426aede7-3fc5-4cf8-9d24-735da96402e9
# 	IIIC
# 	None
#
# 		system:GDC id:426aede7-3fc5-4cf8-9d24-735da96402e9
# 		IIIC
# 		None
#
# 		system:PDC id:526a5774-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:d7e3db60-1891-494b-81cb-5412cab99f5d
# 	IIIC
# 	None
#
# 		system:GDC id:d7e3db60-1891-494b-81cb-5412cab99f5d
# 		IIIC
# 		None
#
# 		system:PDC id:526a514c-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:a89f79e5-b2b4-4a90-acb4-5d1365146532
# 	IIIC
# 	None
#
# 		system:GDC id:a89f79e5-b2b4-4a90-acb4-5d1365146532
# 		IIIC
# 		None
#
# 		system:PDC id:526a7bd7-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:f502e00b-e025-481b-9593-a6f7b363b63b
# 	IIIC
# 	None
#
# 		system:GDC id:f502e00b-e025-481b-9593-a6f7b363b63b
# 		IIIC
# 		None
#
# 		system:PDC id:526a82cb-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:611615b2-e6d8-4b3c-8e0c-c115aa97c9d1
# 	IIIC
# 	None
#
# 		system:GDC id:611615b2-e6d8-4b3c-8e0c-c115aa97c9d1
# 		IIIC
# 		None
#
# 		system:PDC id:526a69a7-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:2e174f9b-290f-444f-b16e-530085416b13
# 	IIIC
# 	None
#
# 		system:GDC id:2e174f9b-290f-444f-b16e-530085416b13
# 		IIIC
# 		None
#
# 		system:PDC id:526a45be-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:e7e2597f-c6a3-4bdc-9daa-d17fc8ab9f76
# 	IIIC
# 	None
#
# 		system:GDC id:e7e2597f-c6a3-4bdc-9daa-d17fc8ab9f76
# 		IIIC
# 		None
#
# 		system:PDC id:526a5065-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:efc15407-78da-4c08-9fbf-2b02c17894b4
# 	IIIC
# 	None
#
# 		system:GDC id:efc15407-78da-4c08-9fbf-2b02c17894b4
# 		IIIC
# 		None
#
# 		system:PDC id:526a5ae9-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:de970d08-9907-464c-8175-47f6d2be62e0
# 	IIIC
# 	None
#
# 		system:GDC id:de970d08-9907-464c-8175-47f6d2be62e0
# 		IIIC
# 		None
#
# 		system:PDC id:526a8b79-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:b5327171-0105-403e-9b91-125eecb02389
# 	IIIC
# 	None
#
# 		system:GDC id:b5327171-0105-403e-9b91-125eecb02389
# 		IIIC
# 		None
#
# 		system:PDC id:c1ef8404-63d6-11e8-bcf1-0a2705229b82
# 		Stage IIIC
# 		0
#
# 	system:GDC id:68f99d2b-5a98-4cd8-8192-5f36fab4221b
# 	IIIC
# 	None
#
# 		system:GDC id:68f99d2b-5a98-4cd8-8192-5f36fab4221b
# 		IIIC
# 		None
#
# 		system:PDC id:32b6f61f-63d7-11e8-bcf1-0a2705229b82
# 		Stage IIIC
# 		0
#
# 	system:GDC id:14cca285-5fbb-45c8-bbd3-3a901154a1e3
# 	IIIC
# 	None
#
# 		system:GDC id:14cca285-5fbb-45c8-bbd3-3a901154a1e3
# 		IIIC
# 		None
#
# 		system:PDC id:526a3c86-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:39df45ff-87f7-4781-90b7-e1ea2f15a9d3
# 	IIIC
# 	None
#
# 		system:GDC id:39df45ff-87f7-4781-90b7-e1ea2f15a9d3
# 		IIIC
# 		None
#
# 		system:PDC id:526a7cfe-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:8beaf23a-9e0e-4fc1-b604-5de8c857fbd9
# 	IIIC
# 	None
#
# 		system:GDC id:8beaf23a-9e0e-4fc1-b604-5de8c857fbd9
# 		IIIC
# 		None
#
# 		system:PDC id:526a587e-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:4df205bf-ad0a-408e-bbfe-2f807fad2e3e
# 	IIIC
# 	None
#
# 		system:GDC id:4df205bf-ad0a-408e-bbfe-2f807fad2e3e
# 		IIIC
# 		None
#
# 		system:PDC id:526a6d21-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:9c6f433a-ca9e-4590-8a7b-6ddb69cc1398
# 	IIIC
# 	None
#
# 		system:GDC id:9c6f433a-ca9e-4590-8a7b-6ddb69cc1398
# 		IIIC
# 		None
#
# 		system:PDC id:526a67e6-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:8b87e1ea-7386-4da7-9df7-8e16e6113f37
# 	IIIC
# 	None
#
# 		system:GDC id:8b87e1ea-7386-4da7-9df7-8e16e6113f37
# 		IIIC
# 		None
#
# 		system:PDC id:526a3812-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:1521ff7d-3781-439d-a4af-3acd83734b3b
# 	IIIC
# 	None
#
# 		system:GDC id:1521ff7d-3781-439d-a4af-3acd83734b3b
# 		IIIC
# 		None
#
# 		system:PDC id:526a9d9d-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:848d4e80-9658-4f99-bcdb-e3f7275bb72d
# 	IIIC
# 	None
#
# 		system:GDC id:848d4e80-9658-4f99-bcdb-e3f7275bb72d
# 		IIIC
# 		None
#
# 		system:PDC id:526aa956-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:df907ef8-3c26-4c50-8a87-ee8290296117
# 	IIIC
# 	None
#
# 		system:GDC id:df907ef8-3c26-4c50-8a87-ee8290296117
# 		IIIC
# 		None
#
# 		system:PDC id:526aaf30-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0
#
# 	system:GDC id:857845ca-096c-40ed-8edc-ab4572688280
# 	IIIC
# 	None
#
# 		system:GDC id:857845ca-096c-40ed-8edc-ab4572688280
# 		IIIC
# 		None
#
# 		system:PDC id:526a4022-0881-11eb-bc0e-0aad30af8a83
# 		Stage IIIC
# 		0

# %%
def printSubject2(subject, indent=0):
    ident = subject['identifier'][0]
    print(('\t'*(indent+1)+'system:{} id:{}').format(ident['system'], ident['value']))
    print(subject['Diagnosis'][0])
    print()

for subject in api_response.result:
    printSubject2(subject)
    for nestedSubject in subject['ResearchSubject']:
        printSubject2(nestedSubject, indent=1)
# Out:
# 	system:GDC id:b295d458-952a-42af-9f7f-2c07e895990c
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '69bccafb-3215-4e8d-b392-447e4f8696cd', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:b295d458-952a-42af-9f7f-2c07e895990c
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '69bccafb-3215-4e8d-b392-447e4f8696cd', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 	system:GDC id:c3a430fe-641e-4b7b-884e-9735908692d6
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'e1a040fa-d089-46c3-b20d-cf0ea981df4b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:c3a430fe-641e-4b7b-884e-9735908692d6
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'e1a040fa-d089-46c3-b20d-cf0ea981df4b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a3f3c-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bfc0d-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:dc8e3901-b845-4419-8f76-d31750eacf60
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'd89e3e50-d40e-405f-a944-0cdeddfc03ea', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:dc8e3901-b845-4419-8f76-d31750eacf60
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'd89e3e50-d40e-405f-a944-0cdeddfc03ea', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a3b90-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bf792-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:6f493081-5bd6-4d07-9a36-b775eda105e1
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '045c42af-1c23-4fae-a3e1-136e0260dbc9', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:6f493081-5bd6-4d07-9a36-b775eda105e1
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '045c42af-1c23-4fae-a3e1-136e0260dbc9', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a3d60-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bfa50-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:9d33308f-f7cc-420e-9116-b9a95068d045
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '41848858-a1d3-4a40-8c3a-cf4cb5fb8900', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:9d33308f-f7cc-420e-9116-b9a95068d045
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '41848858-a1d3-4a40-8c3a-cf4cb5fb8900', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:33f2e3fb-63d7-11e8-bcf1-0a2705229b82
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ff3158c8-70ca-11e8-bcf1-0a2705229b82', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:01026cf5-8582-4864-8e89-111c05660eb6
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '036a0eab-a46e-4b8b-b293-7cf9884d798a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:01026cf5-8582-4864-8e89-111c05660eb6
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '036a0eab-a46e-4b8b-b293-7cf9884d798a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aa37f-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c6b78-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:742033a6-ba74-4871-9046-14972d6676e4
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '4696aedc-5dc8-4b11-808f-2bc3ff7367a7', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:742033a6-ba74-4871-9046-14972d6676e4
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '4696aedc-5dc8-4b11-808f-2bc3ff7367a7', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a9fbc-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c6581-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:fb3f8ed1-cc6f-406b-8b3d-a5eeff0b4196
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f61626a8-bc79-4f99-bcfd-a4aab0925e27', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:fb3f8ed1-cc6f-406b-8b3d-a5eeff0b4196
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f61626a8-bc79-4f99-bcfd-a4aab0925e27', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aa6dd-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c70bd-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:296336a2-8f88-4a26-8c34-7cdf22dd8f9c
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '93fa5273-916d-4cc6-acd2-ff815768450e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:296336a2-8f88-4a26-8c34-7cdf22dd8f9c
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '93fa5273-916d-4cc6-acd2-ff815768450e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a91cb-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c5784-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:6223da27-571c-4ace-80d7-9245693382f3
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '1c48a371-cdd3-484b-bbc9-32fd3d07f59d', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:6223da27-571c-4ace-80d7-9245693382f3
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '1c48a371-cdd3-484b-bbc9-32fd3d07f59d', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a8712-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c4c35-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:29de0047-aca8-4b3d-b626-77e593977e30
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '5f60f611-4af9-47d0-b584-eb8e47becc59', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:29de0047-aca8-4b3d-b626-77e593977e30
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '5f60f611-4af9-47d0-b584-eb8e47becc59', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a79a5-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c3c64-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:35e72ed7-d7a0-4720-af25-ad4336fa7d89
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'c862682e-27a1-43aa-8f54-23817a38f019', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:35e72ed7-d7a0-4720-af25-ad4336fa7d89
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'c862682e-27a1-43aa-8f54-23817a38f019', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a548e-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c1191-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:cee465f1-3162-49de-ba8c-29b2f989a7bb
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '3b2f4eb0-737d-4673-a5e7-a639a80566dc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:cee465f1-3162-49de-ba8c-29b2f989a7bb
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '3b2f4eb0-737d-4673-a5e7-a639a80566dc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a9cc6-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c62a3-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:82ba31a6-dd05-4f6f-88d9-8f961822d732
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ccfa0242-99d1-4069-89d0-2566c3c208ef', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:82ba31a6-dd05-4f6f-88d9-8f961822d732
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ccfa0242-99d1-4069-89d0-2566c3c208ef', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a662f-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c22e2-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:99d74447-9236-438c-8543-e876b4daa8bf
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '5e3b5c99-2b45-499e-b106-4e5ccd15b5a7', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:99d74447-9236-438c-8543-e876b4daa8bf
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '5e3b5c99-2b45-499e-b106-4e5ccd15b5a7', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a47af-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c04ca-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:2c8ff3ae-ef06-4e3c-b198-fb8f57ebbd61
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '31a7e0d0-4545-4807-8a7d-93c996683a07', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:2c8ff3ae-ef06-4e3c-b198-fb8f57ebbd61
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '31a7e0d0-4545-4807-8a7d-93c996683a07', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a8c5a-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c5198-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:11ed8b7d-2483-4b5e-9893-3376d1d49672
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '4235e102-792b-4d58-9311-799da3d3049c', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:11ed8b7d-2483-4b5e-9893-3376d1d49672
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '4235e102-792b-4d58-9311-799da3d3049c', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a4d66-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c0ab2-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:76d72a27-a410-45e9-954f-394bb32bac91
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '969872bf-0b1a-424f-b826-6d23c6a2e6f9', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:76d72a27-a410-45e9-954f-394bb32bac91
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '969872bf-0b1a-424f-b826-6d23c6a2e6f9', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a77f1-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c3951-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:aa529cf5-9837-495d-9d5d-6c81460cbac1
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '892996cc-45ce-43c9-8b01-873d007f786a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:aa529cf5-9837-495d-9d5d-6c81460cbac1
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '892996cc-45ce-43c9-8b01-873d007f786a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a5c31-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c178c-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:cbbd64b3-258c-4639-9462-d1b08f4ffc25
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '87cc36de-7515-4b0d-bd8b-851110f77f4a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:cbbd64b3-258c-4639-9462-d1b08f4ffc25
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '87cc36de-7515-4b0d-bd8b-851110f77f4a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:f9687f24-63d6-11e8-bcf1-0a2705229b82
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ff312360-70ca-11e8-bcf1-0a2705229b82', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:a7deae0d-38d2-46e4-a90b-f79f57fd2808
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '4fae861c-b1d1-411a-872f-80a8d3894197', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:a7deae0d-38d2-46e4-a90b-f79f57fd2808
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '4fae861c-b1d1-411a-872f-80a8d3894197', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aad86-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c7952-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:07ac108d-4f71-4049-832c-f800c3e6c047
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'aec31ece-1b93-47f3-8801-ecfb29582abb', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:07ac108d-4f71-4049-832c-f800c3e6c047
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'aec31ece-1b93-47f3-8801-ecfb29582abb', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a6457-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c21c6-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:0bb7be19-e7c9-46f2-b1b3-f83f3b213475
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'a79ce39f-b385-4882-ad22-160582359502', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:0bb7be19-e7c9-46f2-b1b3-f83f3b213475
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'a79ce39f-b385-4882-ad22-160582359502', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a8f0c-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c54ca-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:0ed2be8e-1d7b-4a08-9740-f642377d58c9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '7668274c-72bc-47ec-a461-b093c32d0c6e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:0ed2be8e-1d7b-4a08-9740-f642377d58c9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '7668274c-72bc-47ec-a461-b093c32d0c6e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a847d-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c4908-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:9672bd02-c6f4-4884-9c3c-ec62abd2f0ea
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '7267c9ad-f9b5-4f0c-8c33-c285e2c52edc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:9672bd02-c6f4-4884-9c3c-ec62abd2f0ea
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '7267c9ad-f9b5-4f0c-8c33-c285e2c52edc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a6716-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c248c-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:0f875052-cf76-45f2-9c76-021ee605479d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f1c0e90d-70ea-49f5-b57a-8c854405abef', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:0f875052-cf76-45f2-9c76-021ee605479d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f1c0e90d-70ea-49f5-b57a-8c854405abef', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a83a7-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c47c6-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:7d7fba6d-9bbb-44a6-b91c-ca97277e49b2
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ec27559a-08ef-42f4-9265-5070b2ff5f96', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:7d7fba6d-9bbb-44a6-b91c-ca97277e49b2
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ec27559a-08ef-42f4-9265-5070b2ff5f96', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a75e7-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c378d-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:7e06a271-ede9-40dc-a5f1-6eebaa82de8b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2f19150b-4a7a-43d5-b948-dcff52f7c2cc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:7e06a271-ede9-40dc-a5f1-6eebaa82de8b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2f19150b-4a7a-43d5-b948-dcff52f7c2cc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a6a80-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c28c1-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:4f552cb7-0380-4918-82ea-1f38562406b9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '57e49977-c262-442c-be51-a755bc198f40', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:4f552cb7-0380-4918-82ea-1f38562406b9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '57e49977-c262-442c-be51-a755bc198f40', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a42f3-0881-11eb-bc0e-0aad30af8a83
# {'morphology': 'Not Reported', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c0044-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:1c43fd26-93f7-4ac8-84fe-e861bca119d9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'da70ea84-0b24-4b10-b8d3-2fad9a7a217f', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:1c43fd26-93f7-4ac8-84fe-e861bca119d9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'da70ea84-0b24-4b10-b8d3-2fad9a7a217f', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a53ac-0881-11eb-bc0e-0aad30af8a83
# {'morphology': 'Not Reported', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c107e-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:d90249dc-40e8-449e-a24a-6d461f29f632
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '9d587b59-8c48-4cf1-92be-4c433326c301', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:d90249dc-40e8-449e-a24a-6d461f29f632
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '9d587b59-8c48-4cf1-92be-4c433326c301', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aabd0-0881-11eb-bc0e-0aad30af8a83
# {'morphology': 'Not Reported', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c77f1-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:c17ddbe9-0957-4c3d-9c2e-846fc5a9aee0
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '5f5b829e-8d72-4ace-96be-51812bd230a6', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:c17ddbe9-0957-4c3d-9c2e-846fc5a9aee0
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '5f5b829e-8d72-4ace-96be-51812bd230a6', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a488e-0881-11eb-bc0e-0aad30af8a83
# {'morphology': 'Not Reported', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c064c-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:718dff52-0d0b-48d6-89c1-cf594a6ab883
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '1a87235e-d6f8-4440-9929-ef062611d750', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:718dff52-0d0b-48d6-89c1-cf594a6ab883
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '1a87235e-d6f8-4440-9929-ef062611d750', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a5f28-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c1a44-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:1e8ca30b-0bd0-426f-b2fd-2a84f3c0df26
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '92c82c1a-fd23-4d13-96bf-d1c5daedd34b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:1e8ca30b-0bd0-426f-b2fd-2a84f3c0df26
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '92c82c1a-fd23-4d13-96bf-d1c5daedd34b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a78cd-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c3ab5-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:1a114bb5-b3de-4e8e-8038-6436c70781ff
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '0f48fd5b-414e-4492-b0a4-a0a2a8bd1a0b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:1a114bb5-b3de-4e8e-8038-6436c70781ff
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '0f48fd5b-414e-4492-b0a4-a0a2a8bd1a0b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a751a-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c3675-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:fc1c474a-93d1-4faf-9180-cb4136043ef9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f823ed3e-cc27-4614-93a1-63d311c54a59', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:fc1c474a-93d1-4faf-9180-cb4136043ef9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f823ed3e-cc27-4614-93a1-63d311c54a59', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a70a6-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c30bc-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:faf8cebd-72ad-4da2-b55e-73cddd8dafff
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '13e9b933-674b-48c3-b154-544741799787', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:faf8cebd-72ad-4da2-b55e-73cddd8dafff
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '13e9b933-674b-48c3-b154-544741799787', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a4a82-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c07f8-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:53c60788-10b1-4ba1-afdd-63376587b7cb
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '692fe5ae-4c24-4153-8526-5782675daaa4', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:53c60788-10b1-4ba1-afdd-63376587b7cb
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '692fe5ae-4c24-4153-8526-5782675daaa4', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a5d16-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c192b-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:1fe09e41-2ce0-4e8f-a05b-868afa54247d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ecf8d357-2ba4-46aa-8e3c-2c87ffd3a05e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:1fe09e41-2ce0-4e8f-a05b-868afa54247d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ecf8d357-2ba4-46aa-8e3c-2c87ffd3a05e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:c2cf7e96-63d5-11e8-bcf1-0a2705229b82
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ff2f0dd0-70ca-11e8-bcf1-0a2705229b82', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:52e4305e-1ff0-4a92-a38a-136696eb8968
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2cf23f78-056c-4faf-be5d-fb9b3106b910', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:52e4305e-1ff0-4a92-a38a-136696eb8968
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2cf23f78-056c-4faf-be5d-fb9b3106b910', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:c58bad65-63d5-11e8-bcf1-0a2705229b82
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ff2f13b3-70ca-11e8-bcf1-0a2705229b82', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:83a99225-3034-4db7-a171-f073dbb087ca
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'a90a692b-0e33-4794-9175-f53559b3da14', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:83a99225-3034-4db7-a171-f073dbb087ca
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'a90a692b-0e33-4794-9175-f53559b3da14', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a3949-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bf676-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:244b7d18-3975-45e6-b159-63e634749a3b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f9308a25-934c-4481-9628-533d0c12050f', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:244b7d18-3975-45e6-b159-63e634749a3b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'f9308a25-934c-4481-9628-533d0c12050f', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a6387-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c2022-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:7cee15a6-0f80-42c8-9120-322226def3fc
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '60abc594-b0e9-4a46-b904-5f0528dd08db', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:7cee15a6-0f80-42c8-9120-322226def3fc
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '60abc594-b0e9-4a46-b904-5f0528dd08db', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a6002-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c1bea-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:485a9225-48b0-4f4e-a59a-299046e2e992
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '6bff7063-cecd-45dd-879b-4911ac3dd40a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:485a9225-48b0-4f4e-a59a-299046e2e992
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '6bff7063-cecd-45dd-879b-4911ac3dd40a', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aab00-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c7634-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:085fbb0b-0924-4c26-a240-94b13d1742b6
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'c68d2d4c-650e-4cba-8aa0-375cee491ebc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:085fbb0b-0924-4c26-a240-94b13d1742b6
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'c68d2d4c-650e-4cba-8aa0-375cee491ebc', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aa0b0-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c66f7-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:426aede7-3fc5-4cf8-9d24-735da96402e9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '9a123455-0bbc-48aa-8ca6-0853d90fb0be', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:426aede7-3fc5-4cf8-9d24-735da96402e9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '9a123455-0bbc-48aa-8ca6-0853d90fb0be', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a5774-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c1357-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:d7e3db60-1891-494b-81cb-5412cab99f5d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '3c4f3e64-e649-4435-9b2a-9703c8f7fecf', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:d7e3db60-1891-494b-81cb-5412cab99f5d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '3c4f3e64-e649-4435-9b2a-9703c8f7fecf', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a514c-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c0eda-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:a89f79e5-b2b4-4a90-acb4-5d1365146532
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '033e74fb-4013-4d6d-b3fe-ce160ae92727', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:a89f79e5-b2b4-4a90-acb4-5d1365146532
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '033e74fb-4013-4d6d-b3fe-ce160ae92727', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a7bd7-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c3d7a-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:f502e00b-e025-481b-9593-a6f7b363b63b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ca7e17ed-b1e2-4239-8c4c-9809c4aa65df', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:f502e00b-e025-481b-9593-a6f7b363b63b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ca7e17ed-b1e2-4239-8c4c-9809c4aa65df', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a82cb-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c462b-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:611615b2-e6d8-4b3c-8e0c-c115aa97c9d1
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '6b2288da-9f8d-445b-8fa1-2adf8e7ce9a9', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:611615b2-e6d8-4b3c-8e0c-c115aa97c9d1
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '6b2288da-9f8d-445b-8fa1-2adf8e7ce9a9', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a69a7-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c2751-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:2e174f9b-290f-444f-b16e-530085416b13
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'c2a70e9a-d02d-4746-a088-b32e581edb1b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:2e174f9b-290f-444f-b16e-530085416b13
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'c2a70e9a-d02d-4746-a088-b32e581edb1b', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a45be-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c0307-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:e7e2597f-c6a3-4bdc-9daa-d17fc8ab9f76
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '6eb2f66a-fa6b-4b1a-9d81-f47bceb6ec7d', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:e7e2597f-c6a3-4bdc-9daa-d17fc8ab9f76
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '6eb2f66a-fa6b-4b1a-9d81-f47bceb6ec7d', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a5065-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c0d7c-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:efc15407-78da-4c08-9fbf-2b02c17894b4
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '14bf214c-e43f-4a37-8130-0f710c1a464e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:efc15407-78da-4c08-9fbf-2b02c17894b4
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '14bf214c-e43f-4a37-8130-0f710c1a464e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a5ae9-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c1630-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:de970d08-9907-464c-8175-47f6d2be62e0
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '168d5b0d-fdde-4d44-8b13-a8e274068f35', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:de970d08-9907-464c-8175-47f6d2be62e0
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '168d5b0d-fdde-4d44-8b13-a8e274068f35', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a8b79-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c507f-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:b5327171-0105-403e-9b91-125eecb02389
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'cb1a42d2-e1f6-4046-ae05-44c2a7a39763', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:b5327171-0105-403e-9b91-125eecb02389
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'cb1a42d2-e1f6-4046-ae05-44c2a7a39763', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:c1ef8404-63d6-11e8-bcf1-0a2705229b82
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ff303760-70ca-11e8-bcf1-0a2705229b82', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:68f99d2b-5a98-4cd8-8192-5f36fab4221b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '21af4186-087e-4c77-bc23-a7065089841e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:68f99d2b-5a98-4cd8-8192-5f36fab4221b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '21af4186-087e-4c77-bc23-a7065089841e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:32b6f61f-63d7-11e8-bcf1-0a2705229b82
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'ff315534-70ca-11e8-bcf1-0a2705229b82', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:14cca285-5fbb-45c8-bbd3-3a901154a1e3
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '3208009d-4dfe-45f9-873e-d429fe4efa57', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:14cca285-5fbb-45c8-bbd3-3a901154a1e3
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '3208009d-4dfe-45f9-873e-d429fe4efa57', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a3c86-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bf934-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:39df45ff-87f7-4781-90b7-e1ea2f15a9d3
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'dc5a8382-e454-4c61-b544-da1e4fea8304', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:39df45ff-87f7-4781-90b7-e1ea2f15a9d3
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'dc5a8382-e454-4c61-b544-da1e4fea8304', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a7cfe-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c3f16-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:8beaf23a-9e0e-4fc1-b604-5de8c857fbd9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '7fd9943e-d791-4cd8-9661-3ba9365e6492', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:8beaf23a-9e0e-4fc1-b604-5de8c857fbd9
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '7fd9943e-d791-4cd8-9661-3ba9365e6492', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a587e-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c1479-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:4df205bf-ad0a-408e-bbfe-2f807fad2e3e
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'cfa6313d-f03e-48cc-810d-a6b6ee41a308', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:4df205bf-ad0a-408e-bbfe-2f807fad2e3e
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'cfa6313d-f03e-48cc-810d-a6b6ee41a308', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a6d21-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c2c11-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:9c6f433a-ca9e-4590-8a7b-6ddb69cc1398
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2c8abf2a-4b03-4eaf-ba49-adc10dbbe69c', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:9c6f433a-ca9e-4590-8a7b-6ddb69cc1398
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2c8abf2a-4b03-4eaf-ba49-adc10dbbe69c', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a67e6-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c259b-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:8b87e1ea-7386-4da7-9df7-8e16e6113f37
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2b0ec2b7-13df-44bd-b5b8-9689adcc686e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:8b87e1ea-7386-4da7-9df7-8e16e6113f37
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '2b0ec2b7-13df-44bd-b5b8-9689adcc686e', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a3812-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bf4bb-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:1521ff7d-3781-439d-a4af-3acd83734b3b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'e1bd99e6-8022-43c2-9463-023dbe40aca6', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:1521ff7d-3781-439d-a4af-3acd83734b3b
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'e1bd99e6-8022-43c2-9463-023dbe40aca6', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a9d9d-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c63bd-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:848d4e80-9658-4f99-bcdb-e3f7275bb72d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'b7e1ef35-77ff-4f16-8599-678f930a1afa', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:848d4e80-9658-4f99-bcdb-e3f7275bb72d
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'b7e1ef35-77ff-4f16-8599-678f930a1afa', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aa956-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c737e-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:df907ef8-3c26-4c50-8a87-ee8290296117
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '70efed1c-547d-4162-8cf7-42d85f0a3534', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:df907ef8-3c26-4c50-8a87-ee8290296117
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '70efed1c-547d-4162-8cf7-42d85f0a3534', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526aaf30-0881-11eb-bc0e-0aad30af8a83
# {'morphology': '8441/3', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526c7c1c-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
#
# 	system:GDC id:857845ca-096c-40ed-8edc-ab4572688280
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'a5b86352-d280-4958-a562-7315f9a1d833', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:GDC id:857845ca-096c-40ed-8edc-ab4572688280
# {'morphology': '8441/3', 'tumor_stage': 'IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': 'a5b86352-d280-4958-a562-7315f9a1d833', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': None}
#
# 		system:PDC id:526a4022-0881-11eb-bc0e-0aad30af8a83
# {'morphology': 'Not Reported', 'tumor_stage': 'Stage IIIC', 'tumor_grade': 'Not Reported', 'Treatment': [], 'id': '526bfd80-0881-11eb-bc0e-0aad30af8a83', 'primary_diagnosis': 'Serous adenocarcinoma, NOS', 'age_at_diagnosis': 0}
