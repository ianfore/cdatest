# %% [markdown]
# ## File metadata via Cancer Data Aggregator

# %% [markdown]
# This notebook explores the subject and specimen attributes that can be obtained from the Cancer Data Aggregator (CDA) for a given DRS id.
#
# #### Function to call the CDA API
# Set up a function to call the CDA API directly with an SQL query

# %%
import requests
def runAPIQuery(querystring, limit=None):
    cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3'
    #Using a limit:
    if limit is not None:
        cdaURL = "{}?limit={}".format(cdaURL, str(limit))
        
    headers = {'accept' : 'application/json', 'Content-Type' : 'text/plain'}

    request = requests.post(cdaURL, headers = headers, data = querystring)

    if request.status_code == 200:
        return request.json()
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code,query))

# %% [markdown]
# #### Query for the file information specifically
# Query on DRS id.

# %%
querystring = '''SELECT f.* FROM gdc-bq-sample.cda_mvp.v3 p, 
UNNEST(ResearchSubject) AS su, 
UNNEST(su.Specimen) AS sp,
UNNEST(sp.File) AS f
WHERE f.drs_uri = 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056'

'''
query = runAPIQuery(querystring)
query['result']
# Out:
# [{'label': '46db33a7f2003837e88d0a81b8ebec2c_gdc_realn.bam',
#   'associated_project': ['TCGA-BRCA'],
#   'drs_uri': 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056',
#   'identifier': [{'system': 'GDC',
#     'value': '030e5e74-6461-4f05-a399-de8e470bc056'}],
#   'data_category': 'Sequencing Reads',
#   'byte_size': '23894757370',
#   'type': None,
#   'file_format': None,
#   'checksum': 'f0cf564932ed0418c08b828a556d6478',
#   'id': '030e5e74-6461-4f05-a399-de8e470bc056',
#   'data_type': 'Aligned Reads'}]

# %% [markdown]
# That provides minimal additional metadata beyond what DRS tells us already.
#
# #### Query 2 - specimen attributes
# The specimen data could be obtained with the query below.
#
# Note: the except statement provides a way to avoid including the other files derived from this specimen. We are really just interested in attributes of the specimen as they tell us something about the specific file in question. (Of course, in some circumstances those other files, and/or data about them, might be useful. It will depend on the user and the use case).

# %%
specimen_querystring = '''SELECT sp.*  except (File)
FROM gdc-bq-sample.cda_mvp.v3 p, 
UNNEST(ResearchSubject) AS su, 
UNNEST(su.Specimen) AS sp,
UNNEST(sp.File) AS f
WHERE f.drs_uri = 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056'

'''
specimen_query = runAPIQuery(specimen_querystring)
specimen_query['result']
# Out:
# [{'derived_from_specimen': 'Initial sample',
#   'associated_project': 'TCGA-BRCA',
#   'age_at_collection': None,
#   'anatomical_site': None,
#   'source_material_type': 'Primary Tumor',
#   'derived_from_subject': 'TCGA-AR-A2LK',
#   'specimen_type': 'sample',
#   'id': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915',
#   'primary_disease_type': 'Ductal and Lobular Neoplasms',
#   'identifier': [{'system': 'GDC',
#     'value': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915'}]}]

# %% [markdown]
# #### Data from multiple objects
# A query returning values from multiple levels of the model is possible as follows.

# %%
specimen_querystring3 = '''SELECT 
p.days_to_birth,
p.race,
p.sex,
p.ethnicity,
su.Diagnosis,
sp.derived_from_specimen,
sp.age_at_collection,
sp.anatomical_site,
sp.source_material_type,
sp.primary_disease_type,
f.drs_uri,
f.data_category
FROM gdc-bq-sample.cda_mvp.v3 p, 
UNNEST(ResearchSubject) AS su, 
UNNEST(su.Specimen) AS sp,
UNNEST(sp.File) AS f
WHERE f.drs_uri = 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056'

'''
specimen_query3 = runAPIQuery(specimen_querystring3)
specimen_query3['result']
# Out:
# [{'days_to_birth': '-22800',
#   'race': 'white',
#   'sex': 'female',
#   'ethnicity': 'not hispanic or latino',
#   'Diagnosis': [{'morphology': '8520/3',
#     'tumor_stage': 'stage iii',
#     'tumor_grade': 'not reported',
#     'Treatment': [{'type': 'Radiation Therapy, NOS', 'outcome': None},
#      {'type': 'Pharmaceutical Therapy, NOS', 'outcome': None}],
#     'id': '1f41548f-081a-5bc8-937e-58e6205f3794',
#     'primary_diagnosis': 'Lobular carcinoma, NOS',
#     'age_at_diagnosis': '22800'}],
#   'derived_from_specimen': 'Initial sample',
#   'age_at_collection': None,
#   'anatomical_site': None,
#   'source_material_type': 'Primary Tumor',
#   'primary_disease_type': 'Ductal and Lobular Neoplasms',
#   'drs_uri': 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056',
#   'data_category': 'Sequencing Reads'}]

# %% [markdown]
# It's possible to use 'except' again as follows in a more compact version of the previous query. This saves having to enumerate all the required columns, but does have the danger that columns with the same name at different levels of nesting may be ambiguous.

# %%
specimen_querystring4 = '''SELECT 
p.* except (ResearchSubject),
su.* except (Specimen, identifier),
sp.* except (File, identifier),
f.drs_uri,
f.data_category
FROM gdc-bq-sample.cda_mvp.v3 p, 
UNNEST(ResearchSubject) AS su, 
UNNEST(su.Specimen) AS sp,
UNNEST(sp.File) AS f
WHERE f.drs_uri = 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056'

'''
specimen_query4 = runAPIQuery(specimen_querystring4)
specimen_query4['result']
# Out:
# [{'days_to_birth': '-22800',
#   'race': 'white',
#   'sex': 'female',
#   'ethnicity': 'not hispanic or latino',
#   'id': 'TCGA-AR-A2LK',
#   'Diagnosis': [{'morphology': '8520/3',
#     'tumor_stage': 'stage iii',
#     'tumor_grade': 'not reported',
#     'Treatment': [{'type': 'Radiation Therapy, NOS', 'outcome': None},
#      {'type': 'Pharmaceutical Therapy, NOS', 'outcome': None}],
#     'id': '1f41548f-081a-5bc8-937e-58e6205f3794',
#     'primary_diagnosis': 'Lobular carcinoma, NOS',
#     'age_at_diagnosis': '22800'}],
#   'associated_project': 'TCGA-BRCA',
#   'id_1': '1b703058-e596-45bc-80fe-8b98d545c2e2',
#   'primary_disease_type': 'Ductal and Lobular Neoplasms',
#   'primary_disease_site': 'Breast',
#   'derived_from_specimen': 'Initial sample',
#   'associated_project_1': 'TCGA-BRCA',
#   'age_at_collection': None,
#   'anatomical_site': None,
#   'source_material_type': 'Primary Tumor',
#   'derived_from_subject': 'TCGA-AR-A2LK',
#   'specimen_type': 'sample',
#   'id_2': 'd6f5c34a-0f5c-4aed-977a-74a1e5d50915',
#   'primary_disease_type_1': 'Ductal and Lobular Neoplasms',
#   'drs_uri': 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056',
#   'data_category': 'Sequencing Reads'}]

# %% [markdown]
# #### Using the CDA Python API
# Rather than writing SQL it's also possible to use the CDA Python API.
#
# A query can be formulated on the DRS id as follows.

# %%
from cdapython import Q
import json

q1 = Q('ResearchSubject.Specimen.File.drs_uri = "drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056"')
r = q1.run() 
r.sql
print(r)
# Out:
# Query: SELECT p.* FROM gdc-bq-sample.cda_mvp.v3 AS p, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File) AS _File WHERE (_File.drs_uri = 'drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056')
# Offset: 0
# Limit: 1000
# Count: 1
# More pages: No

# %% [markdown]
# The result in this case is the whole data structure for the Patient from which this file came. It is included in context with other data from the same patient.
#
# The listing of results is long. Included for completeness here at the end.

# %%
for res in r:
    print(json.dumps(res, indent= 2))
# Out:
# {
#   "days_to_birth": "-22800",
#   "race": "white",
#   "sex": "female",
#   "ethnicity": "not hispanic or latino",
#   "id": "TCGA-AR-A2LK",
#   "ResearchSubject": [
#     {
#       "Diagnosis": [
#         {
#           "morphology": "8520/3",
#           "tumor_stage": "stage iii",
#           "tumor_grade": "not reported",
#           "Treatment": [
#             {
#               "type": "Radiation Therapy, NOS",
#               "outcome": null
#             },
#             {
#               "type": "Pharmaceutical Therapy, NOS",
#               "outcome": null
#             }
#           ],
#           "id": "1f41548f-081a-5bc8-937e-58e6205f3794",
#           "primary_diagnosis": "Lobular carcinoma, NOS",
#           "age_at_diagnosis": "22800"
#         }
#       ],
#       "Specimen": [
#         {
#           "File": [
#             {
#               "label": "TCGA.BRCA.mutect.053f01ed-3154-4aea-9e7f-932c435034b3.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:053f01ed-3154-4aea-9e7f-932c435034b3",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "053f01ed-3154-4aea-9e7f-932c435034b3"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "1882061658",
#               "type": null,
#               "file_format": null,
#               "checksum": "ae12bbce7abcc03eff228935fa8d3d22",
#               "id": "053f01ed-3154-4aea-9e7f-932c435034b3",
#               "data_type": "Aggregated Somatic Mutation"
#             },
#             {
#               "label": "097d9d39-5794-4ccf-abb4-915ed60ff8a2.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:097d9d39-5794-4ccf-abb4-915ed60ff8a2",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "097d9d39-5794-4ccf-abb4-915ed60ff8a2"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "1822943",
#               "type": null,
#               "file_format": null,
#               "checksum": "80ffed432f33b6e88cc077abb8dc4fa2",
#               "id": "097d9d39-5794-4ccf-abb4-915ed60ff8a2",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "1ee3e654-b508-4a6c-b854-41efdf88d7f5.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:1ee3e654-b508-4a6c-b854-41efdf88d7f5",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "1ee3e654-b508-4a6c-b854-41efdf88d7f5"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "2861743",
#               "type": null,
#               "file_format": null,
#               "checksum": "0ad55cc2f29d951921bfb8546aacb756",
#               "id": "1ee3e654-b508-4a6c-b854-41efdf88d7f5",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "4cf13ec0-c0d9-4a74-9437-668670ab7db0.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:4cf13ec0-c0d9-4a74-9437-668670ab7db0",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "4cf13ec0-c0d9-4a74-9437-668670ab7db0"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "229450",
#               "type": null,
#               "file_format": null,
#               "checksum": "8be66848a9cf1040094e945197587f63",
#               "id": "4cf13ec0-c0d9-4a74-9437-668670ab7db0",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "TCGA-BRCA.263be494-445c-469b-8b53-d27860d73f8d.gene_level_copy_number.tsv",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:53c665e8-61b6-455e-bef9-954de078cc74",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "53c665e8-61b6-455e-bef9-954de078cc74"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "3482768",
#               "type": null,
#               "file_format": null,
#               "checksum": "39ef4839ea205ccf74dc37f2c6f30cc2",
#               "id": "53c665e8-61b6-455e-bef9-954de078cc74",
#               "data_type": "Gene Level Copy Number"
#             },
#             {
#               "label": "TCGA.BRCA.varscan.5a6c3396-8c49-4c25-8a86-7ae63a887c43.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:5a6c3396-8c49-4c25-8a86-7ae63a887c43",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "5a6c3396-8c49-4c25-8a86-7ae63a887c43"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "342281557",
#               "type": null,
#               "file_format": null,
#               "checksum": "735d3ccbf64778336ef535388e2c0939",
#               "id": "5a6c3396-8c49-4c25-8a86-7ae63a887c43",
#               "data_type": "Aggregated Somatic Mutation"
#             },
#             {
#               "label": "f4ebe9b3a70fb929c38a4c6e48e178d5_gdc_realn.bam",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:61c07e4e-4ed2-4d33-9cec-64cde743af44",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "61c07e4e-4ed2-4d33-9cec-64cde743af44"
#                 }
#               ],
#               "data_category": "Sequencing Reads",
#               "byte_size": "19965550114",
#               "type": null,
#               "file_format": null,
#               "checksum": "67139b765f9321decbdefc1be3cee8dd",
#               "id": "61c07e4e-4ed2-4d33-9cec-64cde743af44",
#               "data_type": "Aligned Reads"
#             },
#             {
#               "label": "TCGA.BRCA.varscan.6c93f518-1956-4435-9806-37185266d248.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:6c93f518-1956-4435-9806-37185266d248",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "6c93f518-1956-4435-9806-37185266d248"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "24161125",
#               "type": null,
#               "file_format": null,
#               "checksum": "23f303806e40f6f30fc52b5a9c6eb327",
#               "id": "6c93f518-1956-4435-9806-37185266d248",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.somaticsniper.7dd592e3-5950-4438-96d5-3c718aca3f13.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:7dd592e3-5950-4438-96d5-3c718aca3f13",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "7dd592e3-5950-4438-96d5-3c718aca3f13"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "16910889",
#               "type": null,
#               "file_format": null,
#               "checksum": "21d64325c5780be0b1fadcc55fe5e3d4",
#               "id": "7dd592e3-5950-4438-96d5-3c718aca3f13",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "PITON_p_TCGA_b162_167_SNP_N_GenomeWideSNP_6_H04_844802.grch38.seg.v2.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:91f7e904-2f2f-4ffe-b62a-081181033339",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "91f7e904-2f2f-4ffe-b62a-081181033339"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "33552",
#               "type": null,
#               "file_format": null,
#               "checksum": "b0149adf2e3c7a81e188e8b0140b6abd",
#               "id": "91f7e904-2f2f-4ffe-b62a-081181033339",
#               "data_type": "Copy Number Segment"
#             },
#             {
#               "label": "TCGA.BRCA.mutect.995c0111-d90b-4140-bee7-3845436c3b42.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:995c0111-d90b-4140-bee7-3845436c3b42",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "995c0111-d90b-4140-bee7-3845436c3b42"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "31058116",
#               "type": null,
#               "file_format": null,
#               "checksum": "4a00a1c3611c2ddcb2eed684c451eea7",
#               "id": "995c0111-d90b-4140-bee7-3845436c3b42",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "TCGA-BRCA.263be494-445c-469b-8b53-d27860d73f8d.ascat2.allelic_specific.seg.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:acc481b0-162e-4f89-b5ac-d8d8e261283c",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "acc481b0-162e-4f89-b5ac-d8d8e261283c"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "5238",
#               "type": null,
#               "file_format": null,
#               "checksum": "779fc47a3412af683e7c8664569ef14a",
#               "id": "acc481b0-162e-4f89-b5ac-d8d8e261283c",
#               "data_type": "Allele-specific Copy Number Segment"
#             },
#             {
#               "label": "b68a22c3-110e-492f-866d-062518d296e5.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:b68a22c3-110e-492f-866d-062518d296e5",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "b68a22c3-110e-492f-866d-062518d296e5"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "4033537",
#               "type": null,
#               "file_format": null,
#               "checksum": "784d51956fafd425534f082549600e62",
#               "id": "b68a22c3-110e-492f-866d-062518d296e5",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.muse.b8ca5856-9819-459c-87c5-94e91aca4032.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:b8ca5856-9819-459c-87c5-94e91aca4032",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "b8ca5856-9819-459c-87c5-94e91aca4032"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "23039649",
#               "type": null,
#               "file_format": null,
#               "checksum": "f814c909403da10f3d2200d2a4b45f42",
#               "id": "b8ca5856-9819-459c-87c5-94e91aca4032",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "c29294b1-ce40-4eaa-88e0-ed10c1848834.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:c29294b1-ce40-4eaa-88e0-ed10c1848834",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "c29294b1-ce40-4eaa-88e0-ed10c1848834"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "646238",
#               "type": null,
#               "file_format": null,
#               "checksum": "6a512e2085880e2e4839276d88bf021f",
#               "id": "c29294b1-ce40-4eaa-88e0-ed10c1848834",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.muse.cd0d1636-ae95-4141-94b3-8218eb3b8b25.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:cd0d1636-ae95-4141-94b3-8218eb3b8b25",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "cd0d1636-ae95-4141-94b3-8218eb3b8b25"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "148613852",
#               "type": null,
#               "file_format": null,
#               "checksum": "12ac15df6973cfab8a7fef182082972a",
#               "id": "cd0d1636-ae95-4141-94b3-8218eb3b8b25",
#               "data_type": "Aggregated Somatic Mutation"
#             },
#             {
#               "label": "cf28ecc8-7856-4c3b-89b1-ac34bd1fd662.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:cf28ecc8-7856-4c3b-89b1-ac34bd1fd662",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "cf28ecc8-7856-4c3b-89b1-ac34bd1fd662"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "125450",
#               "type": null,
#               "file_format": null,
#               "checksum": "6aabbc323270a24c95a42c126188b6f8",
#               "id": "cf28ecc8-7856-4c3b-89b1-ac34bd1fd662",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "d1ef3b6c-cce1-408c-85e6-9ca60c93ae28.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:d1ef3b6c-cce1-408c-85e6-9ca60c93ae28",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "d1ef3b6c-cce1-408c-85e6-9ca60c93ae28"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "58399",
#               "type": null,
#               "file_format": null,
#               "checksum": "ae5c8220fbd72c3f57595c73d22350f7",
#               "id": "d1ef3b6c-cce1-408c-85e6-9ca60c93ae28",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "PITON_p_TCGA_b162_167_SNP_N_GenomeWideSNP_6_H04_844802.nocnv_grch38.seg.v2.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:e0efbb2d-ec72-414e-bb84-45889c59132e",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "e0efbb2d-ec72-414e-bb84-45889c59132e"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "6740",
#               "type": null,
#               "file_format": null,
#               "checksum": "7e7ebbbc28b5a51c24947922ffb75052",
#               "id": "e0efbb2d-ec72-414e-bb84-45889c59132e",
#               "data_type": "Masked Copy Number Segment"
#             },
#             {
#               "label": "f0382a48-0f82-494a-9224-7b41103d519b.vcf",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:f0382a48-0f82-494a-9224-7b41103d519b",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "f0382a48-0f82-494a-9224-7b41103d519b"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "294854",
#               "type": null,
#               "file_format": null,
#               "checksum": "3af41551518ebb57e8b639c612acf075",
#               "id": "f0382a48-0f82-494a-9224-7b41103d519b",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.somaticsniper.f9ff49e9-31ce-4051-9157-4bf4b0c5859a.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:f9ff49e9-31ce-4051-9157-4bf4b0c5859a",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "f9ff49e9-31ce-4051-9157-4bf4b0c5859a"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "621054920",
#               "type": null,
#               "file_format": null,
#               "checksum": "a5d844676518cfe8517d86cccf588ccc",
#               "id": "f9ff49e9-31ce-4051-9157-4bf4b0c5859a",
#               "data_type": "Aggregated Somatic Mutation"
#             }
#           ],
#           "derived_from_specimen": "Initial sample",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "sample",
#           "id": "6ec8ccf0-4292-4add-9190-7339ffed7ffa",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "6ec8ccf0-4292-4add-9190-7339ffed7ffa"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "6ec8ccf0-4292-4add-9190-7339ffed7ffa",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "portion",
#           "id": "1b598c5b-6336-4fab-ac0e-25f064ce76da",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "1b598c5b-6336-4fab-ac0e-25f064ce76da"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "1b598c5b-6336-4fab-ac0e-25f064ce76da",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "analyte",
#           "id": "44194faa-ca91-463b-b103-086fb4d010d0",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "44194faa-ca91-463b-b103-086fb4d010d0"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "44194faa-ca91-463b-b103-086fb4d010d0",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "adfefa9c-2e3e-444d-8018-f364999f5f42",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "adfefa9c-2e3e-444d-8018-f364999f5f42"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "44194faa-ca91-463b-b103-086fb4d010d0",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "d1198f16-c425-42fa-995f-f9bc2d259b81",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "d1198f16-c425-42fa-995f-f9bc2d259b81"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "1b598c5b-6336-4fab-ac0e-25f064ce76da",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "analyte",
#           "id": "f64325ee-f430-4629-a824-a3060d2f52f0",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "f64325ee-f430-4629-a824-a3060d2f52f0"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "f64325ee-f430-4629-a824-a3060d2f52f0",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Blood Derived Normal",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "d2cd10ca-f08f-4bb0-965a-c64bfd99e532",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "d2cd10ca-f08f-4bb0-965a-c64bfd99e532"
#             }
#           ]
#         },
#         {
#           "File": [
#             {
#               "label": "46db33a7f2003837e88d0a81b8ebec2c_gdc_realn.bam",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:030e5e74-6461-4f05-a399-de8e470bc056",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "030e5e74-6461-4f05-a399-de8e470bc056"
#                 }
#               ],
#               "data_category": "Sequencing Reads",
#               "byte_size": "23894757370",
#               "type": null,
#               "file_format": null,
#               "checksum": "f0cf564932ed0418c08b828a556d6478",
#               "id": "030e5e74-6461-4f05-a399-de8e470bc056",
#               "data_type": "Aligned Reads"
#             },
#             {
#               "label": "TCGA.BRCA.mutect.053f01ed-3154-4aea-9e7f-932c435034b3.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:053f01ed-3154-4aea-9e7f-932c435034b3",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "053f01ed-3154-4aea-9e7f-932c435034b3"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "1882061658",
#               "type": null,
#               "file_format": null,
#               "checksum": "ae12bbce7abcc03eff228935fa8d3d22",
#               "id": "053f01ed-3154-4aea-9e7f-932c435034b3",
#               "data_type": "Aggregated Somatic Mutation"
#             },
#             {
#               "label": "097d9d39-5794-4ccf-abb4-915ed60ff8a2.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:097d9d39-5794-4ccf-abb4-915ed60ff8a2",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "097d9d39-5794-4ccf-abb4-915ed60ff8a2"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "1822943",
#               "type": null,
#               "file_format": null,
#               "checksum": "80ffed432f33b6e88cc077abb8dc4fa2",
#               "id": "097d9d39-5794-4ccf-abb4-915ed60ff8a2",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "1ee3e654-b508-4a6c-b854-41efdf88d7f5.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:1ee3e654-b508-4a6c-b854-41efdf88d7f5",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "1ee3e654-b508-4a6c-b854-41efdf88d7f5"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "2861743",
#               "type": null,
#               "file_format": null,
#               "checksum": "0ad55cc2f29d951921bfb8546aacb756",
#               "id": "1ee3e654-b508-4a6c-b854-41efdf88d7f5",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "jhu-usc.edu_BRCA.HumanMethylation450.18.lvl-3.TCGA-AR-A2LK-01A-11D-A17Z-05.gdc_hg38.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:1f42f66c-51cf-415a-bb7a-45c74da5ea61",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "1f42f66c-51cf-415a-bb7a-45c74da5ea61"
#                 }
#               ],
#               "data_category": "DNA Methylation",
#               "byte_size": "141277985",
#               "type": null,
#               "file_format": null,
#               "checksum": "8e32e637e5ab94bdfb89e462be2607b6",
#               "id": "1f42f66c-51cf-415a-bb7a-45c74da5ea61",
#               "data_type": "Methylation Beta Value"
#             },
#             {
#               "label": "e7a00fda-0d05-468f-b6a0-18653e961da7.mirbase21.mirnas.quantification.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:25bc9363-e25e-4b4a-9d57-a70b867716b1",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "25bc9363-e25e-4b4a-9d57-a70b867716b1"
#                 }
#               ],
#               "data_category": "Transcriptome Profiling",
#               "byte_size": "50130",
#               "type": null,
#               "file_format": null,
#               "checksum": "06564e7ed66d0e9c568157be42cc480c",
#               "id": "25bc9363-e25e-4b4a-9d57-a70b867716b1",
#               "data_type": "miRNA Expression Quantification"
#             },
#             {
#               "label": "786873b7-1515-4aaf-872a-ee2e0ee05bf2.FPKM.txt.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:30ad67fa-d755-41f9-80a6-b063ead4aace",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "30ad67fa-d755-41f9-80a6-b063ead4aace"
#                 }
#               ],
#               "data_category": "Transcriptome Profiling",
#               "byte_size": "532937",
#               "type": null,
#               "file_format": null,
#               "checksum": "f5c0aed12f5c9ff6f31158e1b053c53c",
#               "id": "30ad67fa-d755-41f9-80a6-b063ead4aace",
#               "data_type": "Gene Expression Quantification"
#             },
#             {
#               "label": "e7a00fda-0d05-468f-b6a0-18653e961da7.mirbase21.isoforms.quantification.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:3c6e4b51-ef92-43b6-804a-386ec3616d43",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "3c6e4b51-ef92-43b6-804a-386ec3616d43"
#                 }
#               ],
#               "data_category": "Transcriptome Profiling",
#               "byte_size": "318733",
#               "type": null,
#               "file_format": null,
#               "checksum": "15b00e1b8df808dfaeb330bcfd502516",
#               "id": "3c6e4b51-ef92-43b6-804a-386ec3616d43",
#               "data_type": "Isoform Expression Quantification"
#             },
#             {
#               "label": "786873b7-1515-4aaf-872a-ee2e0ee05bf2.FPKM-UQ.txt.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:409feff6-332b-4a5e-9a24-a7ae2efdd6f5",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "409feff6-332b-4a5e-9a24-a7ae2efdd6f5"
#                 }
#               ],
#               "data_category": "Transcriptome Profiling",
#               "byte_size": "535020",
#               "type": null,
#               "file_format": null,
#               "checksum": "408fff41e2e5e02bff0f6f0011d11aa4",
#               "id": "409feff6-332b-4a5e-9a24-a7ae2efdd6f5",
#               "data_type": "Gene Expression Quantification"
#             },
#             {
#               "label": "4cf13ec0-c0d9-4a74-9437-668670ab7db0.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:4cf13ec0-c0d9-4a74-9437-668670ab7db0",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "4cf13ec0-c0d9-4a74-9437-668670ab7db0"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "229450",
#               "type": null,
#               "file_format": null,
#               "checksum": "8be66848a9cf1040094e945197587f63",
#               "id": "4cf13ec0-c0d9-4a74-9437-668670ab7db0",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "TCGA-BRCA.263be494-445c-469b-8b53-d27860d73f8d.gene_level_copy_number.tsv",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:53c665e8-61b6-455e-bef9-954de078cc74",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "53c665e8-61b6-455e-bef9-954de078cc74"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "3482768",
#               "type": null,
#               "file_format": null,
#               "checksum": "39ef4839ea205ccf74dc37f2c6f30cc2",
#               "id": "53c665e8-61b6-455e-bef9-954de078cc74",
#               "data_type": "Gene Level Copy Number"
#             },
#             {
#               "label": "TCGA.BRCA.varscan.5a6c3396-8c49-4c25-8a86-7ae63a887c43.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:5a6c3396-8c49-4c25-8a86-7ae63a887c43",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "5a6c3396-8c49-4c25-8a86-7ae63a887c43"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "342281557",
#               "type": null,
#               "file_format": null,
#               "checksum": "735d3ccbf64778336ef535388e2c0939",
#               "id": "5a6c3396-8c49-4c25-8a86-7ae63a887c43",
#               "data_type": "Aggregated Somatic Mutation"
#             },
#             {
#               "label": "PITON_p_TCGA_b162_167_SNP_N_GenomeWideSNP_6_F06_844762.nocnv_grch38.seg.v2.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:5b959684-5887-4f69-90a1-68b92a270490",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "5b959684-5887-4f69-90a1-68b92a270490"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "7975",
#               "type": null,
#               "file_format": null,
#               "checksum": "d82a4cd763e85fc45a1ce948d2fee84c",
#               "id": "5b959684-5887-4f69-90a1-68b92a270490",
#               "data_type": "Masked Copy Number Segment"
#             },
#             {
#               "label": "86b7398d-2319-483a-bd8f-2206726205de_gdc_realn_rehead.bam",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:650f4b42-5e50-41e2-a39b-a3015d14f39a",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "650f4b42-5e50-41e2-a39b-a3015d14f39a"
#                 }
#               ],
#               "data_category": "Sequencing Reads",
#               "byte_size": "9061383260",
#               "type": null,
#               "file_format": null,
#               "checksum": "188bac03acaf3b39171196b46615e902",
#               "id": "650f4b42-5e50-41e2-a39b-a3015d14f39a",
#               "data_type": "Aligned Reads"
#             },
#             {
#               "label": "TCGA.BRCA.varscan.6c93f518-1956-4435-9806-37185266d248.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:6c93f518-1956-4435-9806-37185266d248",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "6c93f518-1956-4435-9806-37185266d248"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "24161125",
#               "type": null,
#               "file_format": null,
#               "checksum": "23f303806e40f6f30fc52b5a9c6eb327",
#               "id": "6c93f518-1956-4435-9806-37185266d248",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.somaticsniper.7dd592e3-5950-4438-96d5-3c718aca3f13.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:7dd592e3-5950-4438-96d5-3c718aca3f13",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "7dd592e3-5950-4438-96d5-3c718aca3f13"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "16910889",
#               "type": null,
#               "file_format": null,
#               "checksum": "21d64325c5780be0b1fadcc55fe5e3d4",
#               "id": "7dd592e3-5950-4438-96d5-3c718aca3f13",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "PITON_p_TCGA_b162_167_SNP_N_GenomeWideSNP_6_F06_844762.grch38.seg.v2.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:982143aa-5a61-4d1e-9f98-3a0d77a1e585",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "982143aa-5a61-4d1e-9f98-3a0d77a1e585"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "19675",
#               "type": null,
#               "file_format": null,
#               "checksum": "aba74a623bce67f36e06bf2db55f3851",
#               "id": "982143aa-5a61-4d1e-9f98-3a0d77a1e585",
#               "data_type": "Copy Number Segment"
#             },
#             {
#               "label": "TCGA.BRCA.mutect.995c0111-d90b-4140-bee7-3845436c3b42.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:995c0111-d90b-4140-bee7-3845436c3b42",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "995c0111-d90b-4140-bee7-3845436c3b42"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "31058116",
#               "type": null,
#               "file_format": null,
#               "checksum": "4a00a1c3611c2ddcb2eed684c451eea7",
#               "id": "995c0111-d90b-4140-bee7-3845436c3b42",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "BRCA.focal_score_by_genes.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:9afe6c9d-ed2f-402a-b043-77f042c4e7fc",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "9afe6c9d-ed2f-402a-b043-77f042c4e7fc"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "45161979",
#               "type": null,
#               "file_format": null,
#               "checksum": "cd4bc677968e6b8eea7b663dba692c40",
#               "id": "9afe6c9d-ed2f-402a-b043-77f042c4e7fc",
#               "data_type": "Gene Level Copy Number Scores"
#             },
#             {
#               "label": "786873b7-1515-4aaf-872a-ee2e0ee05bf2.htseq.counts.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:9e8a9007-7a7c-4767-9c77-c91291dc79ff",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "9e8a9007-7a7c-4767-9c77-c91291dc79ff"
#                 }
#               ],
#               "data_category": "Transcriptome Profiling",
#               "byte_size": "256643",
#               "type": null,
#               "file_format": null,
#               "checksum": "ec154f9589c41183e632a2abf614e582",
#               "id": "9e8a9007-7a7c-4767-9c77-c91291dc79ff",
#               "data_type": "Gene Expression Quantification"
#             },
#             {
#               "label": "TCGA-BRCA.263be494-445c-469b-8b53-d27860d73f8d.ascat2.allelic_specific.seg.txt",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:acc481b0-162e-4f89-b5ac-d8d8e261283c",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "acc481b0-162e-4f89-b5ac-d8d8e261283c"
#                 }
#               ],
#               "data_category": "Copy Number Variation",
#               "byte_size": "5238",
#               "type": null,
#               "file_format": null,
#               "checksum": "779fc47a3412af683e7c8664569ef14a",
#               "id": "acc481b0-162e-4f89-b5ac-d8d8e261283c",
#               "data_type": "Allele-specific Copy Number Segment"
#             },
#             {
#               "label": "TCGA-AR-A2LK-01A-11R-A17X-13_mirna_gdc_realn.bam",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:b00e95ee-6373-413b-acb5-d3d2533c82b8",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "b00e95ee-6373-413b-acb5-d3d2533c82b8"
#                 }
#               ],
#               "data_category": "Sequencing Reads",
#               "byte_size": "129562992",
#               "type": null,
#               "file_format": null,
#               "checksum": "300d9f3f18968c6492b6a4733e6d2c89",
#               "id": "b00e95ee-6373-413b-acb5-d3d2533c82b8",
#               "data_type": "Aligned Reads"
#             },
#             {
#               "label": "b68a22c3-110e-492f-866d-062518d296e5.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:b68a22c3-110e-492f-866d-062518d296e5",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "b68a22c3-110e-492f-866d-062518d296e5"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "4033537",
#               "type": null,
#               "file_format": null,
#               "checksum": "784d51956fafd425534f082549600e62",
#               "id": "b68a22c3-110e-492f-866d-062518d296e5",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.muse.b8ca5856-9819-459c-87c5-94e91aca4032.DR-10.0.somatic.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:b8ca5856-9819-459c-87c5-94e91aca4032",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "b8ca5856-9819-459c-87c5-94e91aca4032"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "23039649",
#               "type": null,
#               "file_format": null,
#               "checksum": "f814c909403da10f3d2200d2a4b45f42",
#               "id": "b8ca5856-9819-459c-87c5-94e91aca4032",
#               "data_type": "Masked Somatic Mutation"
#             },
#             {
#               "label": "c29294b1-ce40-4eaa-88e0-ed10c1848834.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:c29294b1-ce40-4eaa-88e0-ed10c1848834",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "c29294b1-ce40-4eaa-88e0-ed10c1848834"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "646238",
#               "type": null,
#               "file_format": null,
#               "checksum": "6a512e2085880e2e4839276d88bf021f",
#               "id": "c29294b1-ce40-4eaa-88e0-ed10c1848834",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.muse.cd0d1636-ae95-4141-94b3-8218eb3b8b25.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:cd0d1636-ae95-4141-94b3-8218eb3b8b25",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "cd0d1636-ae95-4141-94b3-8218eb3b8b25"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "148613852",
#               "type": null,
#               "file_format": null,
#               "checksum": "12ac15df6973cfab8a7fef182082972a",
#               "id": "cd0d1636-ae95-4141-94b3-8218eb3b8b25",
#               "data_type": "Aggregated Somatic Mutation"
#             },
#             {
#               "label": "cf28ecc8-7856-4c3b-89b1-ac34bd1fd662.vep.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:cf28ecc8-7856-4c3b-89b1-ac34bd1fd662",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "cf28ecc8-7856-4c3b-89b1-ac34bd1fd662"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "125450",
#               "type": null,
#               "file_format": null,
#               "checksum": "6aabbc323270a24c95a42c126188b6f8",
#               "id": "cf28ecc8-7856-4c3b-89b1-ac34bd1fd662",
#               "data_type": "Annotated Somatic Mutation"
#             },
#             {
#               "label": "d1ef3b6c-cce1-408c-85e6-9ca60c93ae28.vcf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:d1ef3b6c-cce1-408c-85e6-9ca60c93ae28",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "d1ef3b6c-cce1-408c-85e6-9ca60c93ae28"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "58399",
#               "type": null,
#               "file_format": null,
#               "checksum": "ae5c8220fbd72c3f57595c73d22350f7",
#               "id": "d1ef3b6c-cce1-408c-85e6-9ca60c93ae28",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA-AR-A2LK-01A-01-TSA.53C36847-0443-432D-97FF-02949CCBA21B.svs",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:dafbde56-05bf-43f6-8245-01b315f69220",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "dafbde56-05bf-43f6-8245-01b315f69220"
#                 }
#               ],
#               "data_category": "Biospecimen",
#               "byte_size": "112367267",
#               "type": null,
#               "file_format": null,
#               "checksum": "b0904a48af5798fcb8abe6b78b27a0c0",
#               "id": "dafbde56-05bf-43f6-8245-01b315f69220",
#               "data_type": "Slide Image"
#             },
#             {
#               "label": "f0382a48-0f82-494a-9224-7b41103d519b.vcf",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:f0382a48-0f82-494a-9224-7b41103d519b",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "f0382a48-0f82-494a-9224-7b41103d519b"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "294854",
#               "type": null,
#               "file_format": null,
#               "checksum": "3af41551518ebb57e8b639c612acf075",
#               "id": "f0382a48-0f82-494a-9224-7b41103d519b",
#               "data_type": "Raw Simple Somatic Mutation"
#             },
#             {
#               "label": "TCGA.BRCA.somaticsniper.f9ff49e9-31ce-4051-9157-4bf4b0c5859a.DR-10.0.protected.maf.gz",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:f9ff49e9-31ce-4051-9157-4bf4b0c5859a",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "f9ff49e9-31ce-4051-9157-4bf4b0c5859a"
#                 }
#               ],
#               "data_category": "Simple Nucleotide Variation",
#               "byte_size": "621054920",
#               "type": null,
#               "file_format": null,
#               "checksum": "a5d844676518cfe8517d86cccf588ccc",
#               "id": "f9ff49e9-31ce-4051-9157-4bf4b0c5859a",
#               "data_type": "Aggregated Somatic Mutation"
#             }
#           ],
#           "derived_from_specimen": "Initial sample",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "sample",
#           "id": "d6f5c34a-0f5c-4aed-977a-74a1e5d50915",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "d6f5c34a-0f5c-4aed-977a-74a1e5d50915"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "d6f5c34a-0f5c-4aed-977a-74a1e5d50915",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "portion",
#           "id": "bcdf5107-7ac1-4f83-8b7e-30173b7d4760",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "bcdf5107-7ac1-4f83-8b7e-30173b7d4760"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "d6f5c34a-0f5c-4aed-977a-74a1e5d50915",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "portion",
#           "id": "7f828ba3-1814-4036-99ff-c5e3035906b4",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "7f828ba3-1814-4036-99ff-c5e3035906b4"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "7f828ba3-1814-4036-99ff-c5e3035906b4",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "slide",
#           "id": "53c36847-0443-432d-97ff-02949ccba21b",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "53c36847-0443-432d-97ff-02949ccba21b"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "7f828ba3-1814-4036-99ff-c5e3035906b4",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "analyte",
#           "id": "70f0c3d1-1aac-4142-95fe-b0ab1660c8c8",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "70f0c3d1-1aac-4142-95fe-b0ab1660c8c8"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "70f0c3d1-1aac-4142-95fe-b0ab1660c8c8",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "95b0db1f-1a31-48c3-aee9-6bc233a232c5",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "95b0db1f-1a31-48c3-aee9-6bc233a232c5"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "70f0c3d1-1aac-4142-95fe-b0ab1660c8c8",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "047160f7-3727-4915-b02d-61557350d88b",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "047160f7-3727-4915-b02d-61557350d88b"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "7f828ba3-1814-4036-99ff-c5e3035906b4",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "analyte",
#           "id": "68b6e9ec-9996-4224-8f94-e372ce7bbb12",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "68b6e9ec-9996-4224-8f94-e372ce7bbb12"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "68b6e9ec-9996-4224-8f94-e372ce7bbb12",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "72e7b9a4-f240-4014-85fb-d0b2e1f86e86",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "72e7b9a4-f240-4014-85fb-d0b2e1f86e86"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "68b6e9ec-9996-4224-8f94-e372ce7bbb12",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "263be494-445c-469b-8b53-d27860d73f8d",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "263be494-445c-469b-8b53-d27860d73f8d"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "68b6e9ec-9996-4224-8f94-e372ce7bbb12",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "7b0b60c7-5fa0-440e-937f-8d82119330d6",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "7b0b60c7-5fa0-440e-937f-8d82119330d6"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "7f828ba3-1814-4036-99ff-c5e3035906b4",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "analyte",
#           "id": "856107f7-fa4e-4add-a9b1-c29632fe452a",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "856107f7-fa4e-4add-a9b1-c29632fe452a"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "856107f7-fa4e-4add-a9b1-c29632fe452a",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "aliquot",
#           "id": "5a147991-2667-4ee1-92fd-3c855bfc39c7",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "5a147991-2667-4ee1-92fd-3c855bfc39c7"
#             }
#           ]
#         },
#         {
#           "File": [
#             {
#               "label": "TCGA-AR-A2LK-01Z-00-DX1.FBD59C38-CD4E-4C22-BC74-A57C192A9BBC.svs",
#               "associated_project": [
#                 "TCGA-BRCA"
#               ],
#               "drs_uri": "drs://dg.4DFC:77c4e7e8-b3cb-4c5d-9486-7e70c1f3ae7e",
#               "identifier": [
#                 {
#                   "system": "GDC",
#                   "value": "77c4e7e8-b3cb-4c5d-9486-7e70c1f3ae7e"
#                 }
#               ],
#               "data_category": "Biospecimen",
#               "byte_size": "897435743",
#               "type": null,
#               "file_format": null,
#               "checksum": "6167ace04b4c0fe03c553eb8163c8ce1",
#               "id": "77c4e7e8-b3cb-4c5d-9486-7e70c1f3ae7e",
#               "data_type": "Slide Image"
#             }
#           ],
#           "derived_from_specimen": "Initial sample",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "sample",
#           "id": "c118fdb6-cd92-4769-badf-37ce3b5c8ce7",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "c118fdb6-cd92-4769-badf-37ce3b5c8ce7"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "c118fdb6-cd92-4769-badf-37ce3b5c8ce7",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "portion",
#           "id": "cab97ce2-dcba-59d6-9c39-3ab968e55521",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "cab97ce2-dcba-59d6-9c39-3ab968e55521"
#             }
#           ]
#         },
#         {
#           "File": [],
#           "derived_from_specimen": "cab97ce2-dcba-59d6-9c39-3ab968e55521",
#           "associated_project": "TCGA-BRCA",
#           "age_at_collection": null,
#           "anatomical_site": null,
#           "source_material_type": "Primary Tumor",
#           "derived_from_subject": "TCGA-AR-A2LK",
#           "specimen_type": "slide",
#           "id": "fcc6179a-6421-47a0-b4a7-ab5bddeac96b",
#           "primary_disease_type": "Ductal and Lobular Neoplasms",
#           "identifier": [
#             {
#               "system": "GDC",
#               "value": "fcc6179a-6421-47a0-b4a7-ab5bddeac96b"
#             }
#           ]
#         }
#       ],
#       "associated_project": "TCGA-BRCA",
#       "id": "1b703058-e596-45bc-80fe-8b98d545c2e2",
#       "primary_disease_type": "Ductal and Lobular Neoplasms",
#       "identifier": [
#         {
#           "system": "GDC",
#           "value": "1b703058-e596-45bc-80fe-8b98d545c2e2"
#         }
#       ],
#       "primary_disease_site": "Breast"
#     }
#   ]
# }
