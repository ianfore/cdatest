# %% [markdown]
# ## CDA Example for subject 09CO022
#
# This notebook explores whether the genomic and proteomic data from a single CPTAC2 subject (person) become aggregated by the Cancer Data Aggregator (CDA). The following diagram shows, independent of CDA, a hierarchy of specimens and sub-specimens that were derived from that subject. In a sense one might say it is a 'ground truth' which it is useful to see whether CDA accurately represent. The subject was part of the TCGA Colon Cancer project and has the identifier 09CO022<sup>1</sup>.
#
# ![09CO022](images/09CO022.jpg)
#
# In the Genomic Data Commons portal we can see the three specimens that were used for genomic analysis. The ids for the specimens match those in blue in the diagram above. Note that the specimen ids shown are those used by the TCGA/CPTAC2 projects, as opposed to the UUIDs within the GDC.
# ![09CO022](images/09CO022_GDC.jpg)
#
# We'll leave aside for now how to do a query using the '09CO022' identifier. From the GDC portal page shown above we identify that the ResearchSubject.id that the CDA will use is c5421e34-e5c7-4ba5-aed9-146a5575fd8d.
#
# On to a query using that value.
#
# <sup>1</sup>Other identifiers were created for the subject in different systems but this identifier is used so we can refer to the subject independently of any of those specific systems. It is also a more convenient id to use than a UUID when writing or speaking.

# %%
from cdapython import Q, columns, unique_terms
import json

# %% [markdown]
# The following query is what one would expect to return the subject shown above. We'll save the json result to a file.

# %%
q1 = Q('ResearchSubject.id = "c5421e34-e5c7-4ba5-aed9-146a5575fd8d"')
r = q1.run(limit=2) 
r.sql
print(r)
j = json.dumps(r[0], indent=3)
with open('query_results/09CO022.json', 'w') as f:
    f.write(j)
# Out:
# Getting results from database
#
# Total execution time: 1149 ms
#
# QueryID: 762598c7-91d4-4fe4-8ef1-357a05b29b52
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject WHERE (_ResearchSubject.id = 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d')
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False

# %% [markdown]
# Worth noting that this gave one result, as would be expected for a query specifying a single subject id.
#
# Did this return the expected specimens from the diagram? First, a count of those specimens.

# %%
specimensFromRoot = r[0]['Specimen']
len(specimensFromRoot)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_53457/1005705812.py in <module>
# ----> 1 specimensFromRoot = r[0]['Specimen']
#       2 len(specimensFromRoot)
#
# KeyError: 'Specimen'

# %% [markdown]
# In v1 that returned results because Specimen was available at the top level. That was in fact an error and has now been removed.
#
# Looking at the specimens within Research Subject

# %%
for subj in r[0]['ResearchSubject']:
    for k, v in subj.items():
        if v.__class__.__name__ == 'list':
            print ('{} has {} items'.format(k, len(v)))
        else:
            print ('{} : {}'.format(k, v))

    print('_'*80)
# Out:
# id : c5421e34-e5c7-4ba5-aed9-146a5575fd8d
# identifier has 1 items
# associated_project : CPTAC-2
# primary_disease_type : Adenomas and Adenocarcinomas
# primary_disease_site : Colon
# Diagnosis has 1 items
# File has 30 items
# Specimen has 11 items
# ________________________________________________________________________________
# id : 459e3b69-63d6-11e8-bcf1-0a2705229b82
# identifier has 1 items
# associated_project : CPTAC-2
# primary_disease_type : Colon Adenocarcinoma
# primary_disease_site : Colon
# Diagnosis has 1 items
# File has 163 items
# Specimen has 5 items
# ________________________________________________________________________________

# %% [markdown]
# That's more that what we might expect. However, the following exploration of the specimens shows that the count of 11 is exactly the same hierarchy as in the GDC screenshot above. Namely, two parent samples, leading to three aliquots on which genomic sequencing was performed.

# %%
import pandas as pd
rowsFromRoot = []
for s in r[0]['ResearchSubject'][0]['Specimen']:
    rowsFromRoot.append([s['identifier'][0]['value'], s['derived_from_specimen'], s['specimen_type'], s['source_material_type']])
df = pd.DataFrame(rowsFromRoot)
df.columns = ['identifier','derived_from_specimen','specimen_type','source_material']
df
# Out:
#                               identifier  \
# 0   4591a53d-5668-4a70-b44b-e08a3d59267e
# 1   c53c4d60-2ddb-5da8-932e-00a86fa2347f
# 2   31075cfa-7aef-59f1-bf54-a1cddb5ee0fd
# 3   0d8adcbf-13f0-48c3-83df-3fa205b79ae8
# 4   d085ebd9-7605-54a0-abb9-10867f5fa1b1
# 5   a31724b6-e550-552b-bd61-41341c534e28
# 6   9250d96e-1cdc-4d68-8a56-f7b186a6fab5
# 7   b12c257d-7409-4858-9384-c430929a075a
# 8   702d7ba0-9558-5b2d-af4d-cd797485b8c1
# 9   f0003f0a-07ea-548e-b1f7-7e6d1b27d47a
# 10  ce309009-9257-4c13-9241-83fc629c35a0
#
#                    derived_from_specimen specimen_type       source_material
# 0                       initial specimen        sample         Primary Tumor
# 1   4591a53d-5668-4a70-b44b-e08a3d59267e       portion         Primary Tumor
# 2   c53c4d60-2ddb-5da8-932e-00a86fa2347f       analyte         Primary Tumor
# 3   31075cfa-7aef-59f1-bf54-a1cddb5ee0fd       aliquot         Primary Tumor
# 4   4591a53d-5668-4a70-b44b-e08a3d59267e       portion         Primary Tumor
# 5   d085ebd9-7605-54a0-abb9-10867f5fa1b1       analyte         Primary Tumor
# 6   a31724b6-e550-552b-bd61-41341c534e28       aliquot         Primary Tumor
# 7                       initial specimen        sample  Blood Derived Normal
# 8   b12c257d-7409-4858-9384-c430929a075a       portion  Blood Derived Normal
# 9   702d7ba0-9558-5b2d-af4d-cd797485b8c1       analyte  Blood Derived Normal
# 10  f0003f0a-07ea-548e-b1f7-7e6d1b27d47a       aliquot  Blood Derived Normal

# %%
rowsFromRoot = []
for s in r[0]['ResearchSubject'][1]['Specimen']:
    rowsFromRoot.append([s['identifier'][0]['value'], s['derived_from_specimen'], s['specimen_type'], s['source_material_type']])
df = pd.DataFrame(rowsFromRoot)
df.columns = ['identifier','derived_from_specimen','specimen_type','source_material']
df
# Out:
# {
#    "id": "f4af3e4d-641b-11e8-bcf1-0a2705229b82",
#    "identifier": [
#       {
#          "system": "PDC",
#          "value": "f4af3e4d-641b-11e8-bcf1-0a2705229b82"
#       }
#    ],
#    "associated_project": "CPTAC-2",
#    "age_at_collection": null,
#    "primary_disease_type": "Colon Adenocarcinoma",
#    "anatomical_site": "Not Reported",
#    "source_material_type": "Solid Tissue Normal",
#    "specimen_type": "sample",
#    "derived_from_specimen": "initial specimen",
#    "derived_from_subject": "09CO022",
#    "File": [
#       {
#          "id": "0235942c-7bd3-46c1-8a3d-87e42a0b1e86",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "0235942c-7bd3-46c1-8a3d-87e42a0b1e86"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:0235942c-7bd3-46c1-8a3d-87e42a0b1e86",
#          "byte_size": "5195961",
#          "checksum": "c1e585b85d70314ddfb9fe930faf6a0f"
#       },
#       {
#          "id": "0a63771a-14b2-4d6b-9c08-c7177c372789",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "0a63771a-14b2-4d6b-9c08-c7177c372789"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:0a63771a-14b2-4d6b-9c08-c7177c372789",
#          "byte_size": "213302411",
#          "checksum": "8e16ac2e87bffdea86d75e03a8cf0ffa"
#       },
#       {
#          "id": "0d846fdf-169e-4081-910d-a792fab3df43",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "0d846fdf-169e-4081-910d-a792fab3df43"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:0d846fdf-169e-4081-910d-a792fab3df43",
#          "byte_size": "4247403",
#          "checksum": "5f8d183651df64850a85a64586aa2d9b"
#       },
#       {
#          "id": "0daea74c-6886-415b-9395-cd4e0857acb4",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "0daea74c-6886-415b-9395-cd4e0857acb4"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:0daea74c-6886-415b-9395-cd4e0857acb4",
#          "byte_size": "7044458",
#          "checksum": "fc0008314a37ba989ed29b1c7f9d67e1"
#       },
#       {
#          "id": "1279b00d-cb50-4021-a595-08e7c3dd35c0",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "1279b00d-cb50-4021-a595-08e7c3dd35c0"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:1279b00d-cb50-4021-a595-08e7c3dd35c0",
#          "byte_size": "7311308",
#          "checksum": "48c15a24e109b3f783b8a23766f25a94"
#       },
#       {
#          "id": "1a1b004e-2ac6-42a7-b745-3e52be7fa22c",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "1a1b004e-2ac6-42a7-b745-3e52be7fa22c"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:1a1b004e-2ac6-42a7-b745-3e52be7fa22c",
#          "byte_size": "814691558",
#          "checksum": "4a8c37b53a8dfd37df9f8a2457f08d8b"
#       },
#       {
#          "id": "1cf6afc7-d8dd-492e-88b4-ce73f63f0525",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "1cf6afc7-d8dd-492e-88b4-ce73f63f0525"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:1cf6afc7-d8dd-492e-88b4-ce73f63f0525",
#          "byte_size": "228828721",
#          "checksum": "3f1e328de8a3cbc58ea38fb7e6b4be97"
#       },
#       {
#          "id": "21b0644c-4bc2-4a72-826a-eb0b507add08",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "21b0644c-4bc2-4a72-826a-eb0b507add08"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:21b0644c-4bc2-4a72-826a-eb0b507add08",
#          "byte_size": "5574069",
#          "checksum": "0fed23511a9cfd34d95dfa610e194b3d"
#       },
#       {
#          "id": "250dbc86-4d5c-45aa-bab5-0fb75678574b",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "250dbc86-4d5c-45aa-bab5-0fb75678574b"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:250dbc86-4d5c-45aa-bab5-0fb75678574b",
#          "byte_size": "6920705",
#          "checksum": "59c5839127bf5e75de5099a6ef431a1b"
#       },
#       {
#          "id": "28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a",
#          "byte_size": "1885185505",
#          "checksum": "60a11fff4769d03b7d7a7586b5b05828"
#       },
#       {
#          "id": "2834e1b0-1323-4ee5-b819-0e836aac244e",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "2834e1b0-1323-4ee5-b819-0e836aac244e"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:2834e1b0-1323-4ee5-b819-0e836aac244e",
#          "byte_size": "2529641",
#          "checksum": "f5ce083f494f80aa6485cbfe65c3bf9d"
#       },
#       {
#          "id": "2f42f669-8819-423f-9078-ec988cb71d11",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "2f42f669-8819-423f-9078-ec988cb71d11"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:2f42f669-8819-423f-9078-ec988cb71d11",
#          "byte_size": "5306074",
#          "checksum": "0c51b70a9ec74aabb52dc59120dcb18b"
#       },
#       {
#          "id": "31a66bc4-2b12-4310-919f-b8c0231e252d",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "31a66bc4-2b12-4310-919f-b8c0231e252d"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:31a66bc4-2b12-4310-919f-b8c0231e252d",
#          "byte_size": "5725135",
#          "checksum": "cb5debd1ade07dfc256522f2332bb320"
#       },
#       {
#          "id": "3ac4db66-7660-451f-833d-32ffa4f159d6",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "3ac4db66-7660-451f-833d-32ffa4f159d6"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:3ac4db66-7660-451f-833d-32ffa4f159d6",
#          "byte_size": "199273832",
#          "checksum": "e2e505e6dc18ec1eead1576d2289a09d"
#       },
#       {
#          "id": "3d1ffaff-47b5-4e63-9840-6490055fd38d",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "3d1ffaff-47b5-4e63-9840-6490055fd38d"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:3d1ffaff-47b5-4e63-9840-6490055fd38d",
#          "byte_size": "200810764",
#          "checksum": "be9c1aa166ae610d36d3ae4b622d5112"
#       },
#       {
#          "id": "3d462e53-b907-4586-9b1f-041dde2b5dd5",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "3d462e53-b907-4586-9b1f-041dde2b5dd5"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:3d462e53-b907-4586-9b1f-041dde2b5dd5",
#          "byte_size": "1613377052",
#          "checksum": "f08c5881ec4ee03927ae8bf8676faee5"
#       },
#       {
#          "id": "40617525-424e-4bc0-8468-4e00ff9f0ccb",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "40617525-424e-4bc0-8468-4e00ff9f0ccb"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:40617525-424e-4bc0-8468-4e00ff9f0ccb",
#          "byte_size": "1638996500",
#          "checksum": "de695ce745d100a3c1512e6a7232956c"
#       },
#       {
#          "id": "41057289-39ea-4f09-b24f-dfd1336fc1ed",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "41057289-39ea-4f09-b24f-dfd1336fc1ed"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:41057289-39ea-4f09-b24f-dfd1336fc1ed",
#          "byte_size": "3715668",
#          "checksum": "c2ca24934a561a4d2f41e1a9e9fc474a"
#       },
#       {
#          "id": "42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8",
#          "byte_size": "2549143",
#          "checksum": "b64210b35e7be647ed2450f872784e92"
#       },
#       {
#          "id": "47832160-26f2-4ad2-ae65-a781303b21d7",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "47832160-26f2-4ad2-ae65-a781303b21d7"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:47832160-26f2-4ad2-ae65-a781303b21d7",
#          "byte_size": "7424654",
#          "checksum": "61e93fdf0c6dc5e6b2db07971db2dac8"
#       },
#       {
#          "id": "48d6afa8-9a0d-49b1-b080-f879108aefe9",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "48d6afa8-9a0d-49b1-b080-f879108aefe9"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:48d6afa8-9a0d-49b1-b080-f879108aefe9",
#          "byte_size": "7140369",
#          "checksum": "9ed307f94c00a23eacaf1901ad2f64fa"
#       },
#       {
#          "id": "4ac75865-1dd4-4785-b8b0-ec0e133eab6c",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "4ac75865-1dd4-4785-b8b0-ec0e133eab6c"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:4ac75865-1dd4-4785-b8b0-ec0e133eab6c",
#          "byte_size": "4067116",
#          "checksum": "ce117eb92b13ad29aef6fe713b22e8f5"
#       },
#       {
#          "id": "4d60d292-cbbf-4610-8ef8-cd99fe3f900f",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "4d60d292-cbbf-4610-8ef8-cd99fe3f900f"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:4d60d292-cbbf-4610-8ef8-cd99fe3f900f",
#          "byte_size": "175999741",
#          "checksum": "2191752cf2fe702cdf8dbb8c5861029a"
#       },
#       {
#          "id": "51906b58-0772-436f-bcb8-fc2f36fcd5e2",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "51906b58-0772-436f-bcb8-fc2f36fcd5e2"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:51906b58-0772-436f-bcb8-fc2f36fcd5e2",
#          "byte_size": "7198841",
#          "checksum": "9610217d33d3c5a8f911df6c2f588bf8"
#       },
#       {
#          "id": "517cb574-ed34-4e1d-9419-bb518ce71739",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "517cb574-ed34-4e1d-9419-bb518ce71739"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:517cb574-ed34-4e1d-9419-bb518ce71739",
#          "byte_size": "4297928",
#          "checksum": "0c9f2ee97655a7cb987723a1962d4fb5"
#       },
#       {
#          "id": "52b34ed8-f4fb-4fea-92dc-c5e3d19e2289",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "52b34ed8-f4fb-4fea-92dc-c5e3d19e2289"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:52b34ed8-f4fb-4fea-92dc-c5e3d19e2289",
#          "byte_size": "176085816",
#          "checksum": "2b295045b937bb43fe7060056a8f63ed"
#       },
#       {
#          "id": "55dea7f7-c521-4b71-8eb6-4b18fde8dd3e",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "55dea7f7-c521-4b71-8eb6-4b18fde8dd3e"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:55dea7f7-c521-4b71-8eb6-4b18fde8dd3e",
#          "byte_size": "5832441",
#          "checksum": "c0e8076a7b38596e42d8bed774254f13"
#       },
#       {
#          "id": "58797074-31b1-4ad2-8c4f-5bcc39486c85",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "58797074-31b1-4ad2-8c4f-5bcc39486c85"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:58797074-31b1-4ad2-8c4f-5bcc39486c85",
#          "byte_size": "799130176",
#          "checksum": "6ba4efe4c4db8802093dce30ccb0ed18"
#       },
#       {
#          "id": "619b5c69-ffb3-494d-bf19-242e453c2c05",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "619b5c69-ffb3-494d-bf19-242e453c2c05"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:619b5c69-ffb3-494d-bf19-242e453c2c05",
#          "byte_size": "3000707",
#          "checksum": "632ec29efeacf19df90f85b11d6d94ba"
#       },
#       {
#          "id": "627d302f-557c-4e03-9050-89ee2404d04a",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "627d302f-557c-4e03-9050-89ee2404d04a"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:627d302f-557c-4e03-9050-89ee2404d04a",
#          "byte_size": "1871323562",
#          "checksum": "f72175965f2b84063c459beca59d0ef9"
#       },
#       {
#          "id": "678d2b2c-794a-46d5-b510-c7def707a498",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "678d2b2c-794a-46d5-b510-c7def707a498"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:678d2b2c-794a-46d5-b510-c7def707a498",
#          "byte_size": "7319787",
#          "checksum": "11292553428603ace5070e2e3688e7c4"
#       },
#       {
#          "id": "6ca7d2db-8d2e-4b3a-b296-18b401a8a447",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "6ca7d2db-8d2e-4b3a-b296-18b401a8a447"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:6ca7d2db-8d2e-4b3a-b296-18b401a8a447",
#          "byte_size": "6828210",
#          "checksum": "12b4d93685f15ff3eeb4d4b41126bab8"
#       },
#       {
#          "id": "6e2d5918-e230-433d-9178-7c8fb348d19b",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "6e2d5918-e230-433d-9178-7c8fb348d19b"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:6e2d5918-e230-433d-9178-7c8fb348d19b",
#          "byte_size": "7394076",
#          "checksum": "c9cb97aa6db42b5842bdb23743075b5a"
#       },
#       {
#          "id": "715b45d8-9afe-4831-ad94-a254697bb353",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "715b45d8-9afe-4831-ad94-a254697bb353"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:715b45d8-9afe-4831-ad94-a254697bb353",
#          "byte_size": "2759858",
#          "checksum": "7d662588d0267596b721458f49463947"
#       },
#       {
#          "id": "72af85d8-ca3e-461d-8813-83e4981a7447",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "72af85d8-ca3e-461d-8813-83e4981a7447"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:72af85d8-ca3e-461d-8813-83e4981a7447",
#          "byte_size": "786578098",
#          "checksum": "d27a0f64f26b61bd4f0c6db7d9725108"
#       },
#       {
#          "id": "75b3f79d-a90e-4204-a67d-dd8af9fb2c12",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "75b3f79d-a90e-4204-a67d-dd8af9fb2c12"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:75b3f79d-a90e-4204-a67d-dd8af9fb2c12",
#          "byte_size": "5730048",
#          "checksum": "7d5afe756762e38f35ab6e686808ffbf"
#       },
#       {
#          "id": "78d4f347-6f5a-4180-a62e-15a852049269",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "78d4f347-6f5a-4180-a62e-15a852049269"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:78d4f347-6f5a-4180-a62e-15a852049269",
#          "byte_size": "2609677",
#          "checksum": "4412e34b943f37cca2b0dc756b5ffb89"
#       },
#       {
#          "id": "7b831b12-9e11-489f-bd37-47d37d740d4d",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "7b831b12-9e11-489f-bd37-47d37d740d4d"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:7b831b12-9e11-489f-bd37-47d37d740d4d",
#          "byte_size": "805827984",
#          "checksum": "89aa559c7eaa027af4715e105b66cfba"
#       },
#       {
#          "id": "7f46f4ad-053e-4e22-be36-5df3dcdee61f",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "7f46f4ad-053e-4e22-be36-5df3dcdee61f"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:7f46f4ad-053e-4e22-be36-5df3dcdee61f",
#          "byte_size": "5495721",
#          "checksum": "84e960cf38e534333b7fb8c8cb9f3871"
#       },
#       {
#          "id": "7f475e53-7efa-45f4-8e34-3bc84cc068b8",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "7f475e53-7efa-45f4-8e34-3bc84cc068b8"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:7f475e53-7efa-45f4-8e34-3bc84cc068b8",
#          "byte_size": "234831802",
#          "checksum": "8c461f4f7847beef3fe68c3295658038"
#       },
#       {
#          "id": "80de8307-400c-4e91-86c5-110183826a8f",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "80de8307-400c-4e91-86c5-110183826a8f"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:80de8307-400c-4e91-86c5-110183826a8f",
#          "byte_size": "6674206",
#          "checksum": "6182d0d5cc5cd9b1cb06d4b0434af0ad"
#       },
#       {
#          "id": "8119ed56-ce52-43a3-a323-c4bf58dd935c",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "8119ed56-ce52-43a3-a323-c4bf58dd935c"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:8119ed56-ce52-43a3-a323-c4bf58dd935c",
#          "byte_size": "216672618",
#          "checksum": "55f42cd2c22724f66e344e01f641a358"
#       },
#       {
#          "id": "81c2839d-9f30-4f26-bca7-bc5616b1e7c7",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "81c2839d-9f30-4f26-bca7-bc5616b1e7c7"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:81c2839d-9f30-4f26-bca7-bc5616b1e7c7",
#          "byte_size": "237060809",
#          "checksum": "f3195ce5dee1fcacf6ff22b3c93a7cc6"
#       },
#       {
#          "id": "895ca622-be08-40cd-ae54-6b7de92babda",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "895ca622-be08-40cd-ae54-6b7de92babda"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:895ca622-be08-40cd-ae54-6b7de92babda",
#          "byte_size": "1943913508",
#          "checksum": "350cd6a1b03507bb8c7dd2a2eee46dfb"
#       },
#       {
#          "id": "8e5af17a-02fc-4ba7-9887-bc03b0c83fca",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "8e5af17a-02fc-4ba7-9887-bc03b0c83fca"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:8e5af17a-02fc-4ba7-9887-bc03b0c83fca",
#          "byte_size": "170576005",
#          "checksum": "364b0ec4f671fecc9ecfda69b29b4fba"
#       },
#       {
#          "id": "984427aa-2013-4822-9a04-2e7e3a95e542",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "984427aa-2013-4822-9a04-2e7e3a95e542"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:984427aa-2013-4822-9a04-2e7e3a95e542",
#          "byte_size": "201734231",
#          "checksum": "57db3a2d3e87002b37c636902df8faf1"
#       },
#       {
#          "id": "a1b929ad-9041-4da3-bc95-d17f38820b03",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "a1b929ad-9041-4da3-bc95-d17f38820b03"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:a1b929ad-9041-4da3-bc95-d17f38820b03",
#          "byte_size": "5673113",
#          "checksum": "5891384a7d76bda7d5665fd8e81369b4"
#       },
#       {
#          "id": "a0f64b2a-3672-49a7-9a45-509d4f89a5d6",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "a0f64b2a-3672-49a7-9a45-509d4f89a5d6"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:a0f64b2a-3672-49a7-9a45-509d4f89a5d6",
#          "byte_size": "185393241",
#          "checksum": "0b7f296fbe9b3467d81fd12569674e3b"
#       },
#       {
#          "id": "a105451a-ae8c-4c30-b7e5-6a678d920a6f",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "a105451a-ae8c-4c30-b7e5-6a678d920a6f"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:a105451a-ae8c-4c30-b7e5-6a678d920a6f",
#          "byte_size": "172322204",
#          "checksum": "d1f24aca03d81f94cbf86b08cd60052b"
#       },
#       {
#          "id": "a53aa3f0-1659-4c46-9c1c-73879ea12985",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "a53aa3f0-1659-4c46-9c1c-73879ea12985"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:a53aa3f0-1659-4c46-9c1c-73879ea12985",
#          "byte_size": "4098101",
#          "checksum": "4859dd745af07b16e160e20e33b0ed0c"
#       },
#       {
#          "id": "ac6ab1f8-cc31-4b40-a948-d0eb631ae68f",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "ac6ab1f8-cc31-4b40-a948-d0eb631ae68f"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:ac6ab1f8-cc31-4b40-a948-d0eb631ae68f",
#          "byte_size": "5596877",
#          "checksum": "d4eaf9fa62baeb81b493c501a3997caa"
#       },
#       {
#          "id": "aeee4181-b277-472a-881d-b61bf178f597",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "aeee4181-b277-472a-881d-b61bf178f597"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:aeee4181-b277-472a-881d-b61bf178f597",
#          "byte_size": "1765297003",
#          "checksum": "d884bae286c11218563937805cbcf797"
#       },
#       {
#          "id": "aff41011-83d2-412d-9ece-887272bbfcb1",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "aff41011-83d2-412d-9ece-887272bbfcb1"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:aff41011-83d2-412d-9ece-887272bbfcb1",
#          "byte_size": "2281937",
#          "checksum": "f0e12b5613393ccffb0cf2a98e783c06"
#       },
#       {
#          "id": "b63506ea-c6c2-41b4-9c4e-0591f3c5b620",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b63506ea-c6c2-41b4-9c4e-0591f3c5b620"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b63506ea-c6c2-41b4-9c4e-0591f3c5b620",
#          "byte_size": "1931087946",
#          "checksum": "e6805eb6b4e9044555c9da49706c5d8f"
#       },
#       {
#          "id": "b6b5ce5c-ac41-4be9-9c02-5738509ac2f1",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b6b5ce5c-ac41-4be9-9c02-5738509ac2f1"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b6b5ce5c-ac41-4be9-9c02-5738509ac2f1",
#          "byte_size": "215806197",
#          "checksum": "3fe18a3b713f0b9b66382d72622d8b26"
#       },
#       {
#          "id": "bad201f1-6500-4ac0-8396-30a39c0d0c79",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "bad201f1-6500-4ac0-8396-30a39c0d0c79"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:bad201f1-6500-4ac0-8396-30a39c0d0c79",
#          "byte_size": "858236566",
#          "checksum": "89e9982cfe3eb9470a0c5207193db91c"
#       },
#       {
#          "id": "bc748711-2dac-4bd6-85bb-ae2fedd0cc8b",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "bc748711-2dac-4bd6-85bb-ae2fedd0cc8b"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:bc748711-2dac-4bd6-85bb-ae2fedd0cc8b",
#          "byte_size": "1882139615",
#          "checksum": "69ffdc05ddf13f194f41b357ab21f87e"
#       },
#       {
#          "id": "bce10ef2-47dd-4eea-8c91-089e31e24736",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "bce10ef2-47dd-4eea-8c91-089e31e24736"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:bce10ef2-47dd-4eea-8c91-089e31e24736",
#          "byte_size": "4704396",
#          "checksum": "f40920d98dd41b42e300ab978427aaf8"
#       },
#       {
#          "id": "d123999c-98fa-4171-b248-7b782643ab28",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "d123999c-98fa-4171-b248-7b782643ab28"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:d123999c-98fa-4171-b248-7b782643ab28",
#          "byte_size": "5146731",
#          "checksum": "ede86df5c36fc74fdc89ede439947696"
#       },
#       {
#          "id": "d74309bf-30e8-4b47-9d1e-6fb074f7de7d",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "d74309bf-30e8-4b47-9d1e-6fb074f7de7d"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:d74309bf-30e8-4b47-9d1e-6fb074f7de7d",
#          "byte_size": "5273413",
#          "checksum": "286cd9812c003b3879ae70b5eed2875b"
#       },
#       {
#          "id": "dfc26eb6-2c9d-4ac2-bd11-5c4dfc7e006b",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "dfc26eb6-2c9d-4ac2-bd11-5c4dfc7e006b"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:dfc26eb6-2c9d-4ac2-bd11-5c4dfc7e006b",
#          "byte_size": "798831436",
#          "checksum": "726bb127d87d20fda5206adbb6036df8"
#       },
#       {
#          "id": "e22e4280-7ac3-4038-888a-095b4ce4a7a6",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "e22e4280-7ac3-4038-888a-095b4ce4a7a6"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:e22e4280-7ac3-4038-888a-095b4ce4a7a6",
#          "byte_size": "1626928106",
#          "checksum": "6ab4dbb0c864bd62f88ee294e47fe09d"
#       },
#       {
#          "id": "e7b9eafa-47c6-48be-a365-8a8467dcff3b",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "e7b9eafa-47c6-48be-a365-8a8467dcff3b"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:e7b9eafa-47c6-48be-a365-8a8467dcff3b",
#          "byte_size": "5519566",
#          "checksum": "1bf2e4394b6911eee64515ea74079405"
#       },
#       {
#          "id": "ebd17416-a9ee-4ce9-9252-76611337a18e",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "ebd17416-a9ee-4ce9-9252-76611337a18e"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:ebd17416-a9ee-4ce9-9252-76611337a18e",
#          "byte_size": "1756595302",
#          "checksum": "7bff621f39cfcbd29c305f9126651a80"
#       },
#       {
#          "id": "ee639ea3-ff0e-405b-b9b4-16d1c16edea8",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "ee639ea3-ff0e-405b-b9b4-16d1c16edea8"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:ee639ea3-ff0e-405b-b9b4-16d1c16edea8",
#          "byte_size": "1633576871",
#          "checksum": "7f82bf720815e1894eada4986e2c7e95"
#       },
#       {
#          "id": "efcb2319-d4c1-486e-b954-5965ed777dd5",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "efcb2319-d4c1-486e-b954-5965ed777dd5"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:efcb2319-d4c1-486e-b954-5965ed777dd5",
#          "byte_size": "230792790",
#          "checksum": "93657ee56ba5f66116ac0eeb777fd347"
#       },
#       {
#          "id": "f214f823-0d83-4563-9cfd-a4e5d421178a",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "f214f823-0d83-4563-9cfd-a4e5d421178a"
#             }
#          ],
#          "label": "13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:f214f823-0d83-4563-9cfd-a4e5d421178a",
#          "byte_size": "169062751",
#          "checksum": "dcbeab35fea4e6ebb940dc6dfc1d3ae8"
#       },
#       {
#          "id": "f3704d75-cb01-4b0b-81f2-7abeec4420da",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "f3704d75-cb01-4b0b-81f2-7abeec4420da"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:f3704d75-cb01-4b0b-81f2-7abeec4420da",
#          "byte_size": "230013118",
#          "checksum": "1a0f022976c66aae51e0d3eb7c2da581"
#       },
#       {
#          "id": "f89c439d-465d-4b2e-b117-19aa82cd87b4",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "f89c439d-465d-4b2e-b117-19aa82cd87b4"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:f89c439d-465d-4b2e-b117-19aa82cd87b4",
#          "byte_size": "6970617",
#          "checksum": "325aff734b2afd059c199df88986ce6d"
#       },
#       {
#          "id": "fa9b4f1c-0297-4b48-8130-250548130a10",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "fa9b4f1c-0297-4b48-8130-250548130a10"
#             }
#          ],
#          "label": "13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:fa9b4f1c-0297-4b48-8130-250548130a10",
#          "byte_size": "7209659",
#          "checksum": "d29b3f4b07d9b40dc9b85ef5b3559938"
#       },
#       {
#          "id": "02a335f5-ea48-4d29-94b4-e1f50c94eb47",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "02a335f5-ea48-4d29-94b4-e1f50c94eb47"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:02a335f5-ea48-4d29-94b4-e1f50c94eb47",
#          "byte_size": "8025509",
#          "checksum": "9aa20115f7ce6d1de1cf18738bb5096a"
#       },
#       {
#          "id": "017e0e6e-a191-4135-a5f0-07a2819096f5",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "017e0e6e-a191-4135-a5f0-07a2819096f5"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:017e0e6e-a191-4135-a5f0-07a2819096f5",
#          "byte_size": "793619198",
#          "checksum": "775c63f5560e10e30b319bec74a8c23b"
#       },
#       {
#          "id": "033b6ad3-25fe-40e9-87fa-4f317f84478a",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "033b6ad3-25fe-40e9-87fa-4f317f84478a"
#             }
#          ],
#          "label": "87CPTAC_COprospective_W_VU_20160701_09CO022_f04.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:033b6ad3-25fe-40e9-87fa-4f317f84478a",
#          "byte_size": "898729624",
#          "checksum": "c70275a4634bb5c63557585600bdecb8"
#       },
#       {
#          "id": "06b6f850-b3b6-492b-88a5-214906b71338",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "06b6f850-b3b6-492b-88a5-214906b71338"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:06b6f850-b3b6-492b-88a5-214906b71338",
#          "byte_size": "1770001590",
#          "checksum": "10e89c22c721d8fb3aa5bb0c72c1200b"
#       },
#       {
#          "id": "07dde26b-a6b4-4758-8f7d-483bb4340a95",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "07dde26b-a6b4-4758-8f7d-483bb4340a95"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw",
# ...
#                "value": "9fd06628-d752-410e-b96c-d8a52c5eed17"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:9fd06628-d752-410e-b96c-d8a52c5eed17",
#          "byte_size": "217212859",
#          "checksum": "b147733eff4ece99054ef46fef27f75a"
#       },
#       {
#          "id": "a09c62ad-809b-43c7-bd98-d9162ea3b03e",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "a09c62ad-809b-43c7-bd98-d9162ea3b03e"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:a09c62ad-809b-43c7-bd98-d9162ea3b03e",
#          "byte_size": "7488130",
#          "checksum": "ce39029dcf8e454b01c056610dbd8152"
#       },
#       {
#          "id": "aa1ff0a1-1012-420b-9db9-cdf1c988eb54",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "aa1ff0a1-1012-420b-9db9-cdf1c988eb54"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:aa1ff0a1-1012-420b-9db9-cdf1c988eb54",
#          "byte_size": "3271384",
#          "checksum": "3f51dfed56f19d42e536bd6fd40ae3d0"
#       },
#       {
#          "id": "af97d061-29ca-4728-b3eb-3449cf8b39a2",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "af97d061-29ca-4728-b3eb-3449cf8b39a2"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:af97d061-29ca-4728-b3eb-3449cf8b39a2",
#          "byte_size": "175937674",
#          "checksum": "fd6f21eb95c7de501199b93bf9b699fd"
#       },
#       {
#          "id": "b3f95f3e-50ce-40cf-b5e2-4b4c8ae61982",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b3f95f3e-50ce-40cf-b5e2-4b4c8ae61982"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b3f95f3e-50ce-40cf-b5e2-4b4c8ae61982",
#          "byte_size": "5082115",
#          "checksum": "dc5dfc6f27d894a8826f1a1ca4906cdf"
#       },
#       {
#          "id": "b4be77b4-b2de-4b7a-b0ef-c13194f71569",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b4be77b4-b2de-4b7a-b0ef-c13194f71569"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b4be77b4-b2de-4b7a-b0ef-c13194f71569",
#          "byte_size": "1733606276",
#          "checksum": "3fdecd345c95c60d6aff6d1790dcbbd7"
#       },
#       {
#          "id": "b576d133-59f8-40a3-8e02-8b6007547d34",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b576d133-59f8-40a3-8e02-8b6007547d34"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b576d133-59f8-40a3-8e02-8b6007547d34",
#          "byte_size": "2045493648",
#          "checksum": "e3e298f2ddf04f61a866f06924a40086"
#       },
#       {
#          "id": "b86bdaa4-4707-4b3b-88f4-809f6f985fdb",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b86bdaa4-4707-4b3b-88f4-809f6f985fdb"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b86bdaa4-4707-4b3b-88f4-809f6f985fdb",
#          "byte_size": "4588835",
#          "checksum": "1146265fcc1376e7076a3bdcfa283ad4"
#       },
#       {
#          "id": "b93abf59-3591-4921-9695-3cae8898818b",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "b93abf59-3591-4921-9695-3cae8898818b"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:b93abf59-3591-4921-9695-3cae8898818b",
#          "byte_size": "7904892",
#          "checksum": "588dfd5be32fe26d062b045d5d2ae2dd"
#       },
#       {
#          "id": "bc36613c-86ed-42f6-8717-2ba89c9bba7f",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "bc36613c-86ed-42f6-8717-2ba89c9bba7f"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:bc36613c-86ed-42f6-8717-2ba89c9bba7f",
#          "byte_size": "1672522583",
#          "checksum": "9aeef99ecff5d9db6b95f68b84c4cf6b"
#       },
#       {
#          "id": "c350e8c0-8fcc-4fe0-bc47-51b024fb757a",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "c350e8c0-8fcc-4fe0-bc47-51b024fb757a"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:c350e8c0-8fcc-4fe0-bc47-51b024fb757a",
#          "byte_size": "217598995",
#          "checksum": "88dd488b6956cce153d1ef82e6c72793"
#       },
#       {
#          "id": "c309d2e0-0551-465a-a4e0-ca5e7a59d7f1",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "c309d2e0-0551-465a-a4e0-ca5e7a59d7f1"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:c309d2e0-0551-465a-a4e0-ca5e7a59d7f1",
#          "byte_size": "185219849",
#          "checksum": "796912f0c217f7c62951a8c6ebcba646"
#       },
#       {
#          "id": "c932cbd0-306d-4159-ad30-0cd2ad018ffc",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "c932cbd0-306d-4159-ad30-0cd2ad018ffc"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:c932cbd0-306d-4159-ad30-0cd2ad018ffc",
#          "byte_size": "4759004",
#          "checksum": "b5d73dbb30a07b6258c2ec7b6215b752"
#       },
#       {
#          "id": "cea9dd09-9672-4bf5-b093-0227db5b13f0",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "cea9dd09-9672-4bf5-b093-0227db5b13f0"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:cea9dd09-9672-4bf5-b093-0227db5b13f0",
#          "byte_size": "5853295",
#          "checksum": "660d8beeab85725b929595c74aee69f5"
#       },
#       {
#          "id": "d252a407-fb5b-40c4-83e4-aa4865adb9e2",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "d252a407-fb5b-40c4-83e4-aa4865adb9e2"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:d252a407-fb5b-40c4-83e4-aa4865adb9e2",
#          "byte_size": "5881324",
#          "checksum": "c345249cb4d442bfa3a818bc39840f58"
#       },
#       {
#          "id": "d8276edd-e179-4a3e-818c-1f071235dbbd",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "d8276edd-e179-4a3e-818c-1f071235dbbd"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:d8276edd-e179-4a3e-818c-1f071235dbbd",
#          "byte_size": "1809012149",
#          "checksum": "db63801481219c34d8b31d543f6f1377"
#       },
#       {
#          "id": "df3f15b4-15ce-4957-8c30-912eedf71e18",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "df3f15b4-15ce-4957-8c30-912eedf71e18"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:df3f15b4-15ce-4957-8c30-912eedf71e18",
#          "byte_size": "7709582",
#          "checksum": "99267ba1f499eca071c363be1f35d22b"
#       },
#       {
#          "id": "e098e982-8a8f-449b-b36b-de20b63a8dc5",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "e098e982-8a8f-449b-b36b-de20b63a8dc5"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:e098e982-8a8f-449b-b36b-de20b63a8dc5",
#          "byte_size": "5719190",
#          "checksum": "ddfa96324a1231e807c9a35477ece40d"
#       },
#       {
#          "id": "e10a4629-75c4-45c9-9ce3-00d7b0f31232",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "e10a4629-75c4-45c9-9ce3-00d7b0f31232"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:e10a4629-75c4-45c9-9ce3-00d7b0f31232",
#          "byte_size": "177562667",
#          "checksum": "ddf42adbfd8eeeb92c4acaba60222d5a"
#       },
#       {
#          "id": "e678893f-fadc-4a92-842e-e89534886b9d",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "e678893f-fadc-4a92-842e-e89534886b9d"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:e678893f-fadc-4a92-842e-e89534886b9d",
#          "byte_size": "7779691",
#          "checksum": "bf1889149a45b609e94b4c70e60326c0"
#       },
#       {
#          "id": "e68b9b17-100e-48c1-84d7-d1a5f9485c1e",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "e68b9b17-100e-48c1-84d7-d1a5f9485c1e"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.mzid.gz",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Open Standard",
#          "file_format": "mzIdentML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:e68b9b17-100e-48c1-84d7-d1a5f9485c1e",
#          "byte_size": "7633586",
#          "checksum": "b0a122f5fcf894bc5eab79bfc1b9cd26"
#       },
#       {
#          "id": "ec2b6628-0081-4609-9d84-8fe7e8fe5ee2",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "ec2b6628-0081-4609-9d84-8fe7e8fe5ee2"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.mzML.gz",
#          "data_category": "Processed Mass Spectra",
#          "data_type": "Open Standard",
#          "file_format": "mzML",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:ec2b6628-0081-4609-9d84-8fe7e8fe5ee2",
#          "byte_size": "207488107",
#          "checksum": "1626736ac46b5d91480fe6160b24f2a8"
#       },
#       {
#          "id": "eec97b50-58e7-41e9-9b53-e192632655c4",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "eec97b50-58e7-41e9-9b53-e192632655c4"
#             }
#          ],
#          "label": "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw",
#          "data_category": "Raw Mass Spectra",
#          "data_type": "Proprietary",
#          "file_format": "vendor-specific",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:eec97b50-58e7-41e9-9b53-e192632655c4",
#          "byte_size": "1773260093",
#          "checksum": "6422e8c855bacfdf80154503ce276fe1"
#       },
#       {
#          "id": "f3bb04cb-8cbd-45b6-8b2c-c3c42a56e9c2",
#          "identifier": [
#             {
#                "system": "PDC",
#                "value": "f3bb04cb-8cbd-45b6-8b2c-c3c42a56e9c2"
#             }
#          ],
#          "label": "16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.raw.cap.psm",
#          "data_category": "Peptide Spectral Matches",
#          "data_type": "Text",
#          "file_format": "tsv",
#          "associated_project": "CPTAC-2",
#          "drs_uri": "drs://dg.4DFC:f3bb04cb-8cbd-45b6-8b2c-c3c42a56e9c2",
#          "byte_size": "2967257",
#          "checksum": "ddb9975b0b00e6f10fe5bce22d0decd2"
#       }
#    ]
# }
# ________________________________________________________________________________
#                              identifier                 derived_from_specimen  \
# 0  f4af3e4d-641b-11e8-bcf1-0a2705229b82                      initial specimen
# 1  208ebc64-6425-11e8-bcf1-0a2705229b82  f4af3e4d-641b-11e8-bcf1-0a2705229b82
# 2  f6cce507-641b-11e8-bcf1-0a2705229b82                      initial specimen
# 3  08b2a2bf-6427-11e8-bcf1-0a2705229b82  f6cce507-641b-11e8-bcf1-0a2705229b82
# 4  44f5b956-642a-11e8-bcf1-0a2705229b82  f6cce507-641b-11e8-bcf1-0a2705229b82
#
#   specimen_type      source_material
# 0        sample  Solid Tissue Normal
# 1       aliquot  Solid Tissue Normal
# 2        sample        Primary Tumor
# 3       aliquot        Primary Tumor
# 4       aliquot        Primary Tumor

# %% [markdown]
# This is good. we now have the distinct aliquots that went to PNNL and VU. If things are going well we would expect the VU and PNNL files only to be associated with the specific aliquot. From what I've seen elsewhere though I'm not confident that will be the case. We have seen that files have been included not only within specimens at higher levels in the tree, but at lower or peer level specimens. That is documented in this issue.
#
# Pessimism aside let's try it! Given the known issue let's restrict ourselves to the aliquots. Given the ground truth diagram we expect
# one aliquot from the normal to have PNNL files only
# one aliquot from the tumor to have PNNL files only
# one aliquotr from the tumor to have VU files only

# %%
subject2 = r[0]['ResearchSubject'][1]
for s2 in subject2['Specimen']:        
    if s2['specimen_type'] == 'aliquot':
        for k, v in s2.items():
            if v.__class__.__name__ == 'list':
                if len(v) < 2:
                    print(k, v)
                else:
                    if k == 'File':
                        for f in v:
                            print(f['label'])
                    else:    
                        print ('{} has {} items'.format(k, len(v)))
            else:
                print ('{} : {}'.format(k, v))

        print('_'*80)
# Out:
# id : 208ebc64-6425-11e8-bcf1-0a2705229b82
# identifier [{'system': 'PDC', 'value': '208ebc64-6425-11e8-bcf1-0a2705229b82'}]
# associated_project : CPTAC-2
# age_at_collection : None
# primary_disease_type : Colon Adenocarcinoma
# anatomical_site : Not Reported
# source_material_type : Solid Tissue Normal
# specimen_type : aliquot
# derived_from_specimen : f4af3e4d-641b-11e8-bcf1-0a2705229b82
# derived_from_subject : 09CO022
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzid.gz
# ________________________________________________________________________________
# id : 08b2a2bf-6427-11e8-bcf1-0a2705229b82
# identifier [{'system': 'PDC', 'value': '08b2a2bf-6427-11e8-bcf1-0a2705229b82'}]
# associated_project : CPTAC-2
# age_at_collection : None
# primary_disease_type : Colon Adenocarcinoma
# anatomical_site : Not Reported
# source_material_type : Primary Tumor
# specimen_type : aliquot
# derived_from_specimen : f6cce507-641b-11e8-bcf1-0a2705229b82
# derived_from_subject : 09CO022
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.raw.cap.psm
# ________________________________________________________________________________
# id : 44f5b956-642a-11e8-bcf1-0a2705229b82
# identifier [{'system': 'PDC', 'value': '44f5b956-642a-11e8-bcf1-0a2705229b82'}]
# associated_project : CPTAC-2
# age_at_collection : None
# primary_disease_type : Colon Adenocarcinoma
# anatomical_site : Not Reported
# source_material_type : Primary Tumor
# specimen_type : aliquot
# derived_from_specimen : f6cce507-641b-11e8-bcf1-0a2705229b82
# derived_from_subject : 09CO022
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.raw.cap.psm
# ________________________________________________________________________________

# %% [markdown]
# Bingo! Perfect!

# %% [markdown]
# What else is returned by CDA in the single result?
#
# ### Issue 1
# The designation of the parent specimen as derived from Initial Sample breaks the tree. Both are derived from the Subject. (actually from a particular event in the Subject's history). Derived_from_specimen is misleading, it could be read that roes 0 and 7 above derive from the same sample.  Derived_from_specimen also has mixed meaning (semantics); in some cases it is a link to the parent object, in others it is a human readable description. A preferable solution would be derived_from_biomaterial where the biomaterial is a specimen or subject as appropriate. This is a common pattern; present in MAGE, FuGE, the Human Cell Atlas, and other standards and systems.
#
# ### Note
# The fidelity with which the tree is represented will become more important as the imaging data is added. If the 'ground truth' example is as shown in the diagram at top, there is a particular relationship between the image file and one of the genomic samples which does not exist for the other genomic sample. Let's say that an examination of the image let us determine '% neoplastic cellularity'; that might help us interpret the data from the closely related sample. We would need to be careful in assuming that any data derived from that image had any relevance to the second genomic sample.

# %%
for k in r[0].keys():
    print(k)
# Out:
# days_to_birth
# race
# sex
# ethnicity
# id
# ResearchSubject
# Diagnosis
# Specimen
# associated_project
# primary_disease_type
# identifier
# primary_disease_site

# %% [markdown]
# So far we just looked at Specimen.
#
# Diagnosis is as follows

# %%
r[0]['Diagnosis']
# Out:
# [{'morphology': '8140/3',
#   'tumor_stage': 'Stage IIB',
#   'tumor_grade': 'Not Reported',
#   'Treatment': [],
#   'id': '7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb',
#   'primary_diagnosis': 'Adenocarcinoma, NOS',
#   'age_at_diagnosis': None}]

# %% [markdown]
# That's useful information. Morphology is cryptic in that it provides no information about the value shown. Some, but by no means all, users would be informed enough .
#
# Perhaps there's a schema somewhere that tells us the 'value set' used for morphology, but there's nothing here to tell is what that schema is.
#
# Some would say that human readbility is not the point, this is an API off which UIs will be built. Fair enough, but there's not enough for a machine to work off either.
#
# ### Issue 2
# * Code system for morphology is not clear.
# * Link between 'morphology' and 'primary_diagnosis' is not clear.

# %% [markdown]
# From the above we note that there are ResearchSubjects within ResearchSubjects. Looking at the specimens of the first nested ResearchSubject.

# %%
specimensFromRS = r[0]['ResearchSubject'][0]['Specimen']

# %%
len(specimensFromRS)
# Out:
# 11

# %% [markdown]
# That's the same count as before. Looking at the details.

# %%
rowsFromRS = []
for s in specimensFromRS:
    rowsFromRS.append([s['identifier'][0]['value'], s['derived_from_specimen'], s['specimen_type'], s['source_material_type']])
df = pd.DataFrame(rowsFromRS)
df
# Out:
#                                        0  \
# 0   4591a53d-5668-4a70-b44b-e08a3d59267e
# 1   c53c4d60-2ddb-5da8-932e-00a86fa2347f
# 2   31075cfa-7aef-59f1-bf54-a1cddb5ee0fd
# 3   0d8adcbf-13f0-48c3-83df-3fa205b79ae8
# 4   d085ebd9-7605-54a0-abb9-10867f5fa1b1
# 5   a31724b6-e550-552b-bd61-41341c534e28
# 6   9250d96e-1cdc-4d68-8a56-f7b186a6fab5
# 7   b12c257d-7409-4858-9384-c430929a075a
# 8   702d7ba0-9558-5b2d-af4d-cd797485b8c1
# 9   f0003f0a-07ea-548e-b1f7-7e6d1b27d47a
# 10  ce309009-9257-4c13-9241-83fc629c35a0
#
#                                        1        2                     3
# 0                         Initial sample   sample         Primary Tumor
# 1   4591a53d-5668-4a70-b44b-e08a3d59267e  portion         Primary Tumor
# 2   c53c4d60-2ddb-5da8-932e-00a86fa2347f  analyte         Primary Tumor
# 3   31075cfa-7aef-59f1-bf54-a1cddb5ee0fd  aliquot         Primary Tumor
# 4   4591a53d-5668-4a70-b44b-e08a3d59267e  portion         Primary Tumor
# 5   d085ebd9-7605-54a0-abb9-10867f5fa1b1  analyte         Primary Tumor
# 6   a31724b6-e550-552b-bd61-41341c534e28  aliquot         Primary Tumor
# 7                         Initial sample   sample  Blood Derived Normal
# 8   b12c257d-7409-4858-9384-c430929a075a  portion  Blood Derived Normal
# 9   702d7ba0-9558-5b2d-af4d-cd797485b8c1  analyte  Blood Derived Normal
# 10  f0003f0a-07ea-548e-b1f7-7e6d1b27d47a  aliquot  Blood Derived Normal

# %% [markdown]
# Compare what we got for both "Research Subjects". They are the same

# %%
rowsFromRS == rowsFromRoot
# Out:
# True

# %% [markdown]
# Compare the specimens. They are also the same.

# %%
specimensFromRS == specimensFromRoot
# Out:
# True

# %% [markdown]
# In fact we can compare all of the content of the nested ResearchSubject with the content of the top level as follows

# %%
rootKeys = r[0].keys()
print(rootKeys)
print('_'*80)
researchSubjectKeys = r[0]['ResearchSubject'][0].keys()
print(researchSubjectKeys)
# get the keys that are in both the top level and within ResearchSubject
print('_'*80)
commonKeys = list(set(researchSubjectKeys) & set(rootKeys))
for k in commonKeys:
    print(k, r[0][k] == r[0]['ResearchSubject'][0][k])
# Out:
# dict_keys(['days_to_birth', 'race', 'sex', 'ethnicity', 'id', 'ResearchSubject', 'Diagnosis', 'Specimen', 'associated_project', 'primary_disease_type', 'identifier', 'primary_disease_site'])
# ________________________________________________________________________________
# dict_keys(['Diagnosis', 'Specimen', 'associated_project', 'id', 'primary_disease_type', 'identifier', 'primary_disease_site'])
# ________________________________________________________________________________
# Diagnosis True
# primary_disease_type True
# identifier True
# Specimen True
# id True
# associated_project True
# primary_disease_site True

# %% [markdown]
# This shows that the entire content of the nested ResearchSubject repeats content that is also available at the top level.
#
# ### Issue 3
# Results contain repetition which is unnecessary and complicates understanding the response. In terms of the number of lines, 20.2% of the file is repeated, but that is a poor measure of the additional complication caused.
#
# This was further explored in the SQL Exploration notebook in this repository and an underlying cause identified. This issue was created.
# https://github.com/CancerDataAggregator/cda-python/issues/16

# %% [markdown]
# ## Second Research Subject
# Looking at the file, there is a second ResearchSubject present. What is it? It has two specimens.

# %%
subject2 = r[0]['ResearchSubject'][1]
len(subject2['Specimen'])
# Out:
# 2

# %%
for subj in r[0]['ResearchSubject']:
    for k, v in subj.items():
        if v.__class__.__name__ == 'list':
            print ('{} has {} items'.format(k, len(v)))
        else:
            print ('{} : {}'.format(k, v))

    print('_'*80)
# Out:
# Diagnosis has 1 items
# Specimen has 11 items
# associated_project : CPTAC-2
# id : c5421e34-e5c7-4ba5-aed9-146a5575fd8d
# primary_disease_type : Adenomas and Adenocarcinomas
# identifier has 1 items
# primary_disease_site : Colon
# ________________________________________________________________________________
# Diagnosis has 1 items
# Specimen has 2 items
# associated_project : CPTAC-2
# id : 459e3b69-63d6-11e8-bcf1-0a2705229b82
# primary_disease_type : Colon Adenocarcinoma
# identifier has 1 items
# primary_disease_site : Colon
# ________________________________________________________________________________

# %% [markdown]
# Looking back at the original query, it asked for c5421e34-e5c7-4ba5-aed9-146a5575fd8d. That is the first of the two subjects returned. It's not clear why the second is returned.

# %%
subject1 = r[0]['ResearchSubject'][0]
subject1['Diagnosis']
# Out:
# [{'morphology': '8140/3',
#   'tumor_stage': 'Stage IIB',
#   'tumor_grade': 'Not Reported',
#   'Treatment': [],
#   'id': '7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb',
#   'primary_diagnosis': 'Adenocarcinoma, NOS',
#   'age_at_diagnosis': None}]

# %%
subject2['Diagnosis']
# Out:
# [{'morphology': '8140/3',
#   'tumor_stage': 'Stage IIB',
#   'tumor_grade': 'Not Reported',
#   'Treatment': [],
#   'id': 'ff301535-70ca-11e8-bcf1-0a2705229b82',
#   'primary_diagnosis': 'Adenocarcinoma, NOS',
#   'age_at_diagnosis': None}]

# %% [markdown]
# The diagnosis for these two subjects is identical. That's insufficient to say they are the same subject, but this seems worth pursuing.
#
# Let's look at the Specimens for this subject.

# %%
for s2 in subject2['Specimen']:
    for k, v in s2.items():
        if v.__class__.__name__ == 'list':
            if len(v) < 2:
                print(k, v)
            else:
                if k == 'File':
                    for f in v:
                        print(f['label'])
                else:    
                    print ('{} has {} items'.format(k, len(v)))
        else:
            print ('{} : {}'.format(k, v))

    print('_'*80)
# Out:
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.mzid.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f03.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.raw
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.raw.cap.psm
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.raw.cap.psm
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.raw
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f05.mzML.gz
# 13CPTAC_COprospective_P_PNNL_20170215_B4S1_f01.mzML.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f11.mzid.gz
# 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzid.gz
# derived_from_specimen : Initial specimen
# associated_project : CPTAC-2
# age_at_collection : None
# anatomical_site : Not Reported
# source_material_type : Solid Tissue Normal
# derived_from_subject : None
# specimen_type : sample
# id : f4af3e4d-641b-11e8-bcf1-0a2705229b82
# primary_disease_type : Colon Adenocarcinoma
# identifier [{'system': 'PDC', 'value': 'f4af3e4d-641b-11e8-bcf1-0a2705229b82'}]
# ________________________________________________________________________________
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.mzid.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.mzid.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f01.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f04.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzML.gz
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw.cap.psm
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f06.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.mzid.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.mzML.gz
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.mzML.gz
# 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f05.raw
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f03.raw
# 16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.raw.cap.psm
# 87CPTAC_COprospective_W_VU_20160701_09CO022_f02.raw.cap.psm
# derived_from_specimen : Initial specimen
# associated_project : CPTAC-2
# age_at_collection : None
# anatomical_site : Not Reported
# source_material_type : Primary Tumor
# derived_from_subject : None
# specimen_type : sample
# id : f6cce507-641b-11e8-bcf1-0a2705229b82
# primary_disease_type : Colon Adenocarcinoma
# identifier [{'system': 'PDC', 'value': 'f6cce507-641b-11e8-bcf1-0a2705229b82'}]
# ________________________________________________________________________________

# %% [markdown]
# Detective work lets us determine that these two specimens are the three :-) specimens in the 'ground truth'. We have to look at the file names to give us this clue, notably PNNL and VU in the file names for the tumor sample and PNNL only for the Normal sample. The ground truth tells us that the tumor went to Pacific Northwestern Laboratory (PNNL) and Vanderbilt University (VU), and the Normal blood tp PNNL.
#
# ### Issue 4
# Given that these specimens went to locations more than 2000 miles apart they must have been physically separate materials. The ground truth model shows that - with the two specimens having visibly different ids. That has been lost in the PDC/CDA representation. The second specimen represents the parent not the physically distinct samples at each site.
#
# ### Issue 5
# There should not be two subjects in the results returned from this query. This is not the same use case as 'connect the EHRs from the same patient when they visit'. These are all data from the same study, and there was only one encounter of the subject with the study. The problem here is breaking the chain/tree which shows how the samples are derived from one another.
#
# This is a known issue, referred to in the [CDA Release 1 Testing Guide](https://docs.google.com/document/d/1jzvSJu3xWv-UtoPWpZTLbxPq_wqI1vRyfNlJf1V22cU/edit). It is explored here in the context of the other issues raised so that the CDA extensions for release 1 can be evaluated, and in order to identify how the CCDH model can best represent the data.
#
# The CDA extension has allowed association between subjects to be made. The CCDH model should allow association at the specimen level as opposed to subject. See next issue.
#
# ### Issue 6
# This also misses that the proteomic and genomic data derive from the same specimen. The information as preseented shows that the Genomic and Proteomic specimens derive from the same subject but this is insufficient. The PDC sample should indicate as its parent the same parent as the genomic sample.

# %% [markdown]
# ## The same subject as part of a query on subject attributes
# Querying via the id of a specific subject as above was useful in looking at how the CDA behaves when looking at a single subject. It isolates the query from other situations.
#
# Looking at the attributes of subject 09CO022 we can run the following query which should return 09CO022 alongside subjects with the same attributes.

# %%
qc1 = Q('ResearchSubject.associated_project = "CPTAC-2"')
qc2 = Q('ResearchSubject.Diagnosis.tumor_stage = "Stage IIB"')
qc3 = Q('ResearchSubject.primary_disease_site = "Colon"')

q2 = qc1.And(qc2).And(qc3)
r2 = q2.run(limit=100) 
r2.sql
print(r2)
# Out:
# Query: SELECT * FROM gdc-bq-sample.cda_mvp.v3, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis WHERE (((_ResearchSubject.associated_project = 'CPTAC-2') AND (_Diagnosis.tumor_stage = 'Stage IIB')) AND (_ResearchSubject.primary_disease_site = 'Colon'))
# Offset: 0
# Limit: 100
# Count: 8
# More pages: No

# %% [markdown]
# This shows that we appear to have eight matches. The following explores what they are.

# %%
rn = 1
for resItem in r2:
    j = json.dumps(resItem, indent=3)
    print('Subject {}'.format(resItem['identifier']))
    for rs in resItem['ResearchSubject']:
        subj_name = rs['Specimen'][0]['derived_from_subject']
        print('nested subject: {}'.format(subj_name))
        id = rs['identifier'][0]
        print ('\t system:{} id:{}'.format(id['system'],id['value']))     
    fpath = 'query_results/subj_'+str(rn)+'.json'
    print(fpath)
    with open(fpath, 'w') as f:
        f.write(j)
    rn +=1
    print('_'*80)
# Out:
# Subject [{'system': 'GDC', 'value': '44ecd34b-aa2b-4ce1-ab23-c64aee162f69'}]
# nested subject: 15CO002
# 	 system:GDC id:44ecd34b-aa2b-4ce1-ab23-c64aee162f69
# nested subject: None
# 	 system:PDC id:d2b0df58-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_1.json
# ________________________________________________________________________________
# Subject [{'system': 'PDC', 'value': 'd2b0df58-63d6-11e8-bcf1-0a2705229b82'}]
# nested subject: 15CO002
# 	 system:GDC id:44ecd34b-aa2b-4ce1-ab23-c64aee162f69
# nested subject: None
# 	 system:PDC id:d2b0df58-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_2.json
# ________________________________________________________________________________
# Subject [{'system': 'GDC', 'value': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}]
# nested subject: 09CO022
# 	 system:GDC id:c5421e34-e5c7-4ba5-aed9-146a5575fd8d
# nested subject: None
# 	 system:PDC id:459e3b69-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_3.json
# ________________________________________________________________________________
# Subject [{'system': 'PDC', 'value': '459e3b69-63d6-11e8-bcf1-0a2705229b82'}]
# nested subject: 09CO022
# 	 system:GDC id:c5421e34-e5c7-4ba5-aed9-146a5575fd8d
# nested subject: None
# 	 system:PDC id:459e3b69-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_4.json
# ________________________________________________________________________________
# Subject [{'system': 'GDC', 'value': '997475b1-6648-494a-9322-79aa17be272e'}]
# nested subject: 05CO039
# 	 system:GDC id:997475b1-6648-494a-9322-79aa17be272e
# nested subject: None
# 	 system:PDC id:2254625e-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_5.json
# ________________________________________________________________________________
# Subject [{'system': 'PDC', 'value': '2254625e-63d6-11e8-bcf1-0a2705229b82'}]
# nested subject: 05CO039
# 	 system:GDC id:997475b1-6648-494a-9322-79aa17be272e
# nested subject: None
# 	 system:PDC id:2254625e-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_6.json
# ________________________________________________________________________________
# Subject [{'system': 'GDC', 'value': '5e55cf3e-9f95-4b8c-8212-b540da3047cb'}]
# nested subject: 05CO044
# 	 system:GDC id:5e55cf3e-9f95-4b8c-8212-b540da3047cb
# nested subject: None
# 	 system:PDC id:24cb0fcb-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_7.json
# ________________________________________________________________________________
# Subject [{'system': 'PDC', 'value': '24cb0fcb-63d6-11e8-bcf1-0a2705229b82'}]
# nested subject: 05CO044
# 	 system:GDC id:5e55cf3e-9f95-4b8c-8212-b540da3047cb
# nested subject: None
# 	 system:PDC id:24cb0fcb-63d6-11e8-bcf1-0a2705229b82
# query_results/subj_8.json
# ________________________________________________________________________________

# %% [markdown]
# In fact there are only four true subjects here. For each of those four, there are two subjects in the results. One with a GDC id and one with a PDC id. In each case, there are two subjects nested within the parent. One is a repetition of the parent, and the second is corresponding subject from the other system. Overall within the search the data is repeated three times.
#
# On reflection this is unsurprizing, it all follows as a natural consequence of what we saw above in the isolated query. The basic issues are those already listed. Beyond that, this example illustrates that the duplication and complication becomes a bigger issue when a realistic query on subject atttributes is performed.
#
# ### Issue 7
# Same subject is returned three times when queried on subject attributes.
