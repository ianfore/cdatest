# %% [markdown]
# ### Look at all PDC projects
# Beyond the 09CO022 example this noteboook looks more broadly at all the PDC studies.
#
#
# First query for all PDC projects and list their names and count of subjects

# %%
from cdapython import Q

query1 = """SELECT associated_project,count(*) subject_count
from gdc-bq-sample.integration.all_v2 AS su,
unnest(ResearchSubject) AS rs,
unnest(rs.identifier) as id
where (id.system = 'PDC')
group by associated_project """

r1 = Q.sql(query1)
r1
# Out:
# QueryID: 70e7a9d7-9bde-448c-84c8-f0129678ca4a
# Query: SELECT associated_project,count(*) subject_count
# from gdc-bq-sample.integration.all_v2 AS su,
# unnest(ResearchSubject) AS rs,
# unnest(rs.identifier) as id
# where (id.system = 'PDC')
# group by associated_project
# Offset: 0
# Count: 14
# Total Row Count: 14
# More pages: False

# %%
from cda_funcs import qResultsToDF 
qResultsToDF(r1)
# Out:
# /Users/forei/imfenvs/cda2/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                                    associated_project subject_count
# 0                                    CPTAC3-Discovery           886
# 1   Integrated Proteogenomic Characterization of H...           171
# 2   Human Early-Onset Gastric Cancer - Korea Unive...            80
# 3                                        CPTAC3-Other            27
# 4                                          PJ25730263             9
# 5                                             CPTAC-2           347
# 6                                          CPTAC-TCGA           404
# 7             Georgetown Lung Cancer Proteomics Study            11
# 8   Proteogenomic Analysis of Pediatric Brain Canc...           207
# 9   Oral Squamous Cell Carcinoma - Chang Gung Univ...            39
# 10                           Academia Sinica LUAD-100           110
# 11                                       CPTAC2-Other            34
# 12                               CPTAC2 Retrospective             2
# 13  Proteogenomic Translational Research Centers (...             4

# %% [markdown]
# ### Look at the file content in each study
# The following picks two subjects from each of the above studies as examples. It then looks at each sample for those subject and compares the file content across them (actually it checks each sample's file content against the file content of the previous sample from the same subject.

# %%
for project in r1:
    print('_'*100)
    projName = project['associated_project']
    print("Project:{}".format(projName))
    pq = Q('ResearchSubject.associated_project = "{}"'.format(projName))
    pr = pq.run(limit=2)
    for subject2 in pr[1]['ResearchSubject']:
        subid = subject2['identifier'][0]
        if subid['system'] == 'PDC':
            print('_'*50)
            print("Subject: {}:{}".format(subid['system'],subid['value']))
            print("Specimen count: {}".format(len(subject2['Specimen'])))
            lastFileList = []
            for s in subject2['Specimen']:
                print('_'*10)
                print ('Specimen {}'.format(s['id']))
                if s['derived_from_specimen'] == 'initial specimen':
                    qual = ''
                else:
                    qual = 'derived from:'
                print("Source material {}".format(s['source_material_type']))
                print ("{}: {}{}".format(s['specimen_type'], qual, s['derived_from_specimen']))
                print ("files {}".format(len(s['File'])))
                specimenFiles = []
                for f in s['File']:
                    specimenFiles.append(f['id'])
                specimenFiles.sort()
                if specimenFiles == lastFileList:
                    print("Same file content as previous specimen")
                lastFileList = specimenFiles
# Out:
# ____________________________________________________________________________________________________
# Project:CPTAC3-Discovery
# Getting results from database
#
# Total execution time: 25349 ms
# __________________________________________________
# Subject: PDC:f1edd1df-cf1e-11e9-9a07-0a80fada099c
# Specimen count: 4
# __________
# Specimen a01705f8-d0a6-11e9-9a07-0a80fada099c
# Source material Solid Tissue Normal
# sample: initial specimen
# files 165
# __________
# Specimen 5a910ac5-d0b0-11e9-9a07-0a80fada099c
# Source material Solid Tissue Normal
# aliquot: derived from:a01705f8-d0a6-11e9-9a07-0a80fada099c
# files 165
# Same file content as previous specimen
# __________
# Specimen a02ea9f3-d0a6-11e9-9a07-0a80fada099c
# Source material Primary Tumor
# sample: initial specimen
# files 165
# Same file content as previous specimen
# __________
# Specimen 5a700807-d0b0-11e9-9a07-0a80fada099c
# Source material Primary Tumor
# aliquot: derived from:a02ea9f3-d0a6-11e9-9a07-0a80fada099c
# files 165
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:Integrated Proteogenomic Characterization of HBV-related Hepatocellular carcinoma
# Getting results from database
#
# Total execution time: 2384 ms
# __________________________________________________
# Subject: PDC:7a59a31a-1168-11ea-9bfa-0a42f3c845fe
# Specimen count: 4
# __________
# Specimen 7a5b4b48-1168-11ea-9bfa-0a42f3c845fe
# Source material Primary Tumor
# sample: initial specimen
# files 281
# __________
# Specimen 7a5d6240-1168-11ea-9bfa-0a42f3c845fe
# Source material Primary Tumor
# aliquot: derived from:7a5b4b48-1168-11ea-9bfa-0a42f3c845fe
# files 281
# Same file content as previous specimen
# __________
# Specimen 7a5b4c3a-1168-11ea-9bfa-0a42f3c845fe
# Source material Solid Tissue Normal
# sample: initial specimen
# files 281
# Same file content as previous specimen
# __________
# Specimen 7a5d6460-1168-11ea-9bfa-0a42f3c845fe
# Source material Solid Tissue Normal
# aliquot: derived from:7a5b4c3a-1168-11ea-9bfa-0a42f3c845fe
# files 281
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:Human Early-Onset Gastric Cancer - Korea University
# Getting results from database
#
# Total execution time: 11692 ms
# __________________________________________________
# Subject: PDC:7a5934ca-1168-11ea-9bfa-0a42f3c845fe
# Specimen count: 4
# __________
# Specimen 7a5a3df1-1168-11ea-9bfa-0a42f3c845fe
# Source material Primary Tumor
# sample: initial specimen
# files 286
# __________
# Specimen 7a5c4c32-1168-11ea-9bfa-0a42f3c845fe
# Source material Primary Tumor
# aliquot: derived from:7a5a3df1-1168-11ea-9bfa-0a42f3c845fe
# files 286
# Same file content as previous specimen
# __________
# Specimen 7a5a3f99-1168-11ea-9bfa-0a42f3c845fe
# Source material Solid Tissue Normal
# sample: initial specimen
# files 286
# Same file content as previous specimen
# __________
# Specimen 7a5c4cf3-1168-11ea-9bfa-0a42f3c845fe
# Source material Solid Tissue Normal
# aliquot: derived from:7a5a3f99-1168-11ea-9bfa-0a42f3c845fe
# files 286
# Same file content as previous specimen
# __________________________________________________
# Subject: PDC:e8d58072-693a-11ea-b1fd-0aad30af8a83
# Specimen count: 4
# __________
# Specimen e8d6fb52-693a-11ea-b1fd-0aad30af8a83
# Source material Solid Tissue Normal
# sample: initial specimen
# files 170
# __________
# Specimen e8da8319-693a-11ea-b1fd-0aad30af8a83
# Source material Solid Tissue Normal
# aliquot: derived from:e8d6fb52-693a-11ea-b1fd-0aad30af8a83
# files 170
# Same file content as previous specimen
# __________
# Specimen e8d8dd84-693a-11ea-b1fd-0aad30af8a83
# Source material Tumor
# sample: initial specimen
# files 170
# Same file content as previous specimen
# __________
# Specimen e8db6939-693a-11ea-b1fd-0aad30af8a83
# Source material Tumor
# aliquot: derived from:e8d8dd84-693a-11ea-b1fd-0aad30af8a83
# files 170
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:CPTAC3-Other
# Getting results from database
#
# Total execution time: 9077 ms
# __________________________________________________
# Subject: PDC:854f02aa-4510-42fb-9537-28257187530f
# Specimen count: 2
# __________
# Specimen 197ef1b7-cb3a-4590-a938-a8d8d29e9b2a
# Source material Not Reported
# sample: initial specimen
# files 131
# __________
# Specimen dc298e5a-3e3a-4d5d-95a4-5e0ac33cad01
# Source material Not Reported
# aliquot: derived from:197ef1b7-cb3a-4590-a938-a8d8d29e9b2a
# files 131
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:PJ25730263
# Getting results from database
#
# Total execution time: 8811 ms
# __________________________________________________
# Subject: PDC:bf5e9985-f3a7-11e8-a44b-0a9c39d33490
# Specimen count: 4
# __________
# Specimen c7a99bd8-f3b3-11e8-a44b-0a9c39d33490
# Source material Normal
# sample: initial specimen
# files 4
# __________
# Specimen 54c30cbc-f3b7-11e8-a44b-0a9c39d33490
# Source material Normal
# aliquot: derived from:c7a99bd8-f3b3-11e8-a44b-0a9c39d33490
# files 2
# __________
# Specimen ca094336-f3b3-11e8-a44b-0a9c39d33490
# Source material Tumor
# sample: initial specimen
# files 4
# __________
# Specimen 566e0543-f3b7-11e8-a44b-0a9c39d33490
# Source material Tumor
# aliquot: derived from:ca094336-f3b3-11e8-a44b-0a9c39d33490
# files 2
# ____________________________________________________________________________________________________
# Project:CPTAC-2
# Getting results from database
#
# Total execution time: 14219 ms
# __________________________________________________
# Subject: PDC:b7dda873-63d6-11e8-bcf1-0a2705229b82
# Specimen count: 6
# __________
# Specimen f8e6e3ed-6420-11e8-bcf1-0a2705229b82
# Source material Primary Tumor
# sample: initial specimen
# files 165
# __________
# Specimen 746de5e2-6429-11e8-bcf1-0a2705229b82
# Source material Primary Tumor
# aliquot: derived from:f8e6e3ed-6420-11e8-bcf1-0a2705229b82
# files 72
# __________
# Specimen fab5cb9a-641c-11e8-bcf1-0a2705229b82
# Source material Solid Tissue Normal
# sample: initial specimen
# files 165
# __________
# Specimen 4c2b9219-6423-11e8-bcf1-0a2705229b82
# Source material Solid Tissue Normal
# aliquot: derived from:fab5cb9a-641c-11e8-bcf1-0a2705229b82
# files 70
# __________
# Specimen fcca5035-641c-11e8-bcf1-0a2705229b82
# Source material Primary Tumor
# sample: initial specimen
# files 165
# __________
# Specimen dc54ff77-6424-11e8-bcf1-0a2705229b82
# Source material Primary Tumor
# aliquot: derived from:fcca5035-641c-11e8-bcf1-0a2705229b82
# files 23
# ____________________________________________________________________________________________________
# Project:CPTAC-TCGA
# Getting results from database
#
# Total execution time: 15395 ms
# __________________________________________________
# Subject: PDC:5bd59267-63d8-11e8-bcf1-0a2705229b82
# Specimen count: 2
# __________
# Specimen a5e8f98a-641f-11e8-bcf1-0a2705229b82
# Source material Primary Tumor
# sample: initial specimen
# files 59
# __________
# Specimen 8d9e593d-6428-11e8-bcf1-0a2705229b82
# Source material Primary Tumor
# aliquot: derived from:a5e8f98a-641f-11e8-bcf1-0a2705229b82
# files 59
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:Georgetown Lung Cancer Proteomics Study
# Getting results from database
#
# Total execution time: 945 ms
# __________________________________________________
# Subject: PDC:9e8e80e5-d732-11ea-b1fd-0aad30af8a83
# Specimen count: 4
# __________
# Specimen 9e8e933e-d732-11ea-b1fd-0aad30af8a83
# Source material Primary Tumor
# sample: initial specimen
# files 48
# __________
# Specimen 9e8eb67b-d732-11ea-b1fd-0aad30af8a83
# Source material Primary Tumor
# aliquot: derived from:9e8e933e-d732-11ea-b1fd-0aad30af8a83
# files 48
# Same file content as previous specimen
# __________
# Specimen 9e8e95b1-d732-11ea-b1fd-0aad30af8a83
# Source material Solid Tissue Normal
# sample: initial specimen
# files 48
# Same file content as previous specimen
# __________
# Specimen 9e8eb77b-d732-11ea-b1fd-0aad30af8a83
# Source material Solid Tissue Normal
# aliquot: derived from:9e8e95b1-d732-11ea-b1fd-0aad30af8a83
# files 48
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:Proteogenomic Analysis of Pediatric Brain Cancer Tumors Pilot Study
# Getting results from database
# Total execution time: 8410 ms
# __________________________________________________
# Subject: PDC:d08daaa1-ff5e-11e9-9a07-0a80fada099c
# Specimen count: 2
# __________
# Specimen d08ec96b-ff5e-11e9-9a07-0a80fada099c
# Source material Primary Tumor
# sample: initial specimen
# files 56
# __________
# Specimen d09048f6-ff5e-11e9-9a07-0a80fada099c
# Source material Primary Tumor
# aliquot: derived from:d08ec96b-ff5e-11e9-9a07-0a80fada099c
# files 56
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:Oral Squamous Cell Carcinoma - Chang Gung University
# Getting results from database
#
# Total execution time: 8934 ms
# __________________________________________________
# Subject: PDC:8369a540-474e-4b9b-8f2b-f96153ac8bfe
# Specimen count: 4
# __________
# Specimen a14d3203-d84e-4b53-8a69-9c779f82e82f
# Source material Primary Tumor
# sample: initial specimen
# files 86
# __________
# Specimen dd9c3983-f923-4b0f-a84f-c815d048c62c
# Source material Primary Tumor
# aliquot: derived from:a14d3203-d84e-4b53-8a69-9c779f82e82f
# files 86
# Same file content as previous specimen
# __________
# Specimen c999b871-d3bd-4a58-8070-c92c2ed48621
# Source material Solid Tissue Normal
# sample: initial specimen
# files 86
# Same file content as previous specimen
# __________
# Specimen 1df6c75c-c2bf-449d-bdf7-28c534a3cbb6
# Source material Solid Tissue Normal
# aliquot: derived from:c999b871-d3bd-4a58-8070-c92c2ed48621
# files 86
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:Academia Sinica LUAD-100
# Getting results from database
#
# Total execution time: 1089 ms
# __________________________________________________
# Subject: PDC:24b38b8f-8beb-11ea-b1fd-0aad30af8a83
# Specimen count: 4
# __________
# Specimen 24b46f20-8beb-11ea-b1fd-0aad30af8a83
# Source material Normal Adjacent Tissue
# sample: initial specimen
# files 96
# __________
# Specimen 24b5cd4e-8beb-11ea-b1fd-0aad30af8a83
# Source material Normal Adjacent Tissue
# aliquot: derived from:24b46f20-8beb-11ea-b1fd-0aad30af8a83
# files 96
# Same file content as previous specimen
# __________
# Specimen 24b47135-8beb-11ea-b1fd-0aad30af8a83
# Source material Tumor
# sample: initial specimen
# files 96
# Same file content as previous specimen
# __________
# Specimen 24b5cfb7-8beb-11ea-b1fd-0aad30af8a83
# Source material Tumor
# aliquot: derived from:24b47135-8beb-11ea-b1fd-0aad30af8a83
# files 96
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:CPTAC2-Other
# Getting results from database
#
# Total execution time: 9180 ms
# __________________________________________________
# Subject: PDC:9e7efd1e-83a8-4700-8c8c-26f91061687b
# Specimen count: 10
# __________
# Specimen 48b60b87-0c14-4a7d-af0c-7e81cceb6c7d
# Source material Xenograft Tissue
# sample: initial specimen
# files 38
# __________
# Specimen f26401d5-1504-4b87-becd-7499368d2545
# Source material Xenograft Tissue
# aliquot: derived from:48b60b87-0c14-4a7d-af0c-7e81cceb6c7d
# files 38
# Same file content as previous specimen
# __________
# Specimen d0ad281e-dc25-471a-a7a6-62fd011c5ca0
# Source material Xenograft Tissue
# sample: initial specimen
# files 38
# Same file content as previous specimen
# __________
# Specimen f635aa68-f634-44aa-ac8e-bcc8f7f9446c
# Source material Xenograft Tissue
# aliquot: derived from:d0ad281e-dc25-471a-a7a6-62fd011c5ca0
# files 38
# Same file content as previous specimen
# __________
# Specimen d0fd185b-50a8-46b7-96ed-a26b27b0b69e
# Source material Xenograft Tissue
# sample: initial specimen
# files 38
# Same file content as previous specimen
# __________
# Specimen de2e3922-8ae5-416c-a019-dc43d9bd9982
# Source material Xenograft Tissue
# aliquot: derived from:d0fd185b-50a8-46b7-96ed-a26b27b0b69e
# files 38
# Same file content as previous specimen
# __________
# Specimen e70c8e59-22cb-4aca-ae34-46fa23aa60c2
# Source material Xenograft Tissue
# sample: initial specimen
# files 38
# Same file content as previous specimen
# __________
# Specimen 41c56e7d-a4a0-42b2-9437-308c6d0edac5
# Source material Xenograft Tissue
# aliquot: derived from:e70c8e59-22cb-4aca-ae34-46fa23aa60c2
# files 38
# Same file content as previous specimen
# __________
# Specimen fbd77c01-4742-49d9-bb2b-a8b66dd42fa6
# Source material Xenograft Tissue
# sample: initial specimen
# files 38
# Same file content as previous specimen
# __________
# Specimen 212aba15-0d70-4951-9fa2-eee81ab865f4
# Source material Xenograft Tissue
# aliquot: derived from:fbd77c01-4742-49d9-bb2b-a8b66dd42fa6
# files 38
# Same file content as previous specimen
# ____________________________________________________________________________________________________
# Project:CPTAC2 Retrospective
# Getting results from database
#
# Total execution time: 12939 ms
# __________________________________________________
# Subject: PDC:c3c8dc70-898b-469c-919d-2ea39c0d71db
# Specimen count: 17
# __________
# Specimen 5b1b1297-8e83-46c3-b4af-87de6f859816
# Source material Xenograft Tissue
# sample: initial specimen
# files 2946
# __________
# Specimen a272c07b-f673-4806-b6d0-d9cde5ab2a1f
# Source material Xenograft Tissue
# aliquot: derived from:5b1b1297-8e83-46c3-b4af-87de6f859816
# files 1240
# __________
# Specimen 92175281-fa41-43c8-b87c-df1d3d51f878
# Source material Xenograft Tissue
# sample: initial specimen
# files 2946
# __________
# Specimen 050212db-b023-4335-a520-d8bfaf61e621
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 150
# __________
# Specimen 195614b7-341d-4474-88b4-2c16d15bad73
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 477
# __________
# Specimen 2b4f15e8-1e39-42e5-9c21-d2c1db580a49
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 150
# __________
# Specimen 40357ee1-5790-448f-a699-eaa8a80d869f
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 151
# __________
# Specimen 485e1fbb-02c1-4677-9bac-4bc14a11c467
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 152
# __________
# Specimen 5992a694-2d06-4060-9f89-7a66306ae6f3
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 119
# __________
# Specimen d4a31f9d-2322-433a-89a9-d8700c69e38f
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 152
# __________
# Specimen d6520c82-ad21-4c1c-a55a-b6cbe7b919af
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 149
# __________
# Specimen e492a101-8d54-4560-8ee5-fb0eb14abd8d
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 150
# __________
# Specimen e6970633-a430-493e-a10c-db57d0bb9410
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 151
# __________
# Specimen eb8c56e7-2b8e-40b5-9255-e2f7973c0779
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 298
# __________
# Specimen edb5fe07-2d4b-4722-8205-590c13eb19ac
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 60
# __________
# Specimen edbfd4e1-08aa-45bc-8a72-9977e6b7da32
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 149
# __________
# Specimen edf849d0-5a9b-479e-85d1-e4ba836bcdc7
# Source material Xenograft Tissue
# aliquot: derived from:92175281-fa41-43c8-b87c-df1d3d51f878
# files 150
# ____________________________________________________________________________________________________
# Project:Proteogenomic Translational Research Centers (PTRC)
# Getting results from database
#
# Total execution time: 8894 ms
# __________________________________________________
# Subject: PDC:dc69117a-ea67-4beb-91d5-301c8ef2c7db
# Specimen count: 2
# __________
# Specimen 4281fa73-61a8-4c2a-86f1-ebc931e81502
# Source material Not Reported
# sample: initial specimen
# files 385
# __________
# Specimen 32625657-f893-466b-969f-849c5aa6985a
# Source material Not Reported
# aliquot: derived from:4281fa73-61a8-4c2a-86f1-ebc931e81502
# files 385
# Same file content as previous specimen

# %% [markdown]
# That demonstrates that for most of the projects the files associated with tumor and normal specimens are the same set of files.
#
# Take Subject 7a5931dd-1168-11ea-9bfa-0a42f3c845fe from the "Integrated Proteogenomic Characterization of HBV-related Hepatocellular carcinoma" study.
#
# There are 4 specimens for that subject; an initial sample of normal and of tumor, and an 'aliquot' of each.
# The 287 file ids for each of those four samples are identical. We know that the aliquot level files are repeated at the sample level. However, that the tumor and normal specimens both have the same set of files looks worth exploring.
#
# This is covered in the notebook "Compare files via PDC API" which uses the PDC API to obtain additional information about files and relationships not necessarily visible through CDA.
