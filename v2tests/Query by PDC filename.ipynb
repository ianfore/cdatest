# %% [markdown]
# ## Query by PDC filename
# This notebook started out to discover if proteomic files that appeared to be missing were in fact present, but had become orphaned from their parent specimen.
#
# In doing so another issue was encountered.

# %%
from cdapython import Q, columns, unique_terms

# %% [markdown]
# These were the names of the missing files (see the thread in [cda-python/issues/99](https://github.com/CancerDataAggregator/cda-python/issues/99))

# %%
missing_files = ['16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw.cap.psm',
'16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw',
'13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.mzML.gz',
'13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw']

# %%
def find_file(file_label):
    print("Searching for file {}".format(file_label))
    q1 = Q('ResearchSubject.Specimen.File.label = "{}"'.format(file_label))
    r = q1.run(limit=1000) 
    print("Found that file in {} 'Subjects'".format(r.count))
    print('_'*80)
    return r
    
for f in missing_files:
    find_file(f)
# Out:
# Searching for file 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw.cap.psm
# Getting results from database
#
# Total execution time: 918 ms
# Found that file in 0 'Subjects'
# ________________________________________________________________________________
# Searching for file 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw
# Getting results from database
#
# Total execution time: 842 ms
# Found that file in 0 'Subjects'
# ________________________________________________________________________________
# Searching for file 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.mzML.gz
# Getting results from database
#
# Total execution time: 880 ms
# Found that file in 0 'Subjects'
# ________________________________________________________________________________
# Searching for file 13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw
# Getting results from database
#
# Total execution time: 1019 ms
# Found that file in 0 'Subjects'
# ________________________________________________________________________________

# %% [markdown]
# Let's just check that our function works by asking it to look at a file we know exists

# %%
cases = find_file('16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm')
# Out:
# Searching for file 16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm
# Getting results from database
#
# Total execution time: 6423 ms
# Found that file in 30 'Subjects'
# ________________________________________________________________________________

# %% [markdown]
# Yes it exists, our function works!
#
# The count of subjects reflects the multiplexing, but 30 seems large.
#
# What have we got?

# %%
for c in cases:
    print(c['id'])
# Out:
# 11CO039
# 11CO039
# 11CO039
# 11CO039
# 09CO022
# 09CO022
# 09CO022
# 05CO039
# 05CO039
# 05CO039
# 05CO039
# 11CO010
# 11CO010
# 11CO010
# 21CO006
# 21CO006
# 21CO006
# 11CO045
# 11CO045
# 11CO045
# 11CO005
# 11CO005
# 11CO005
# 11CO005
# ColonRef
# ColonRef
# 11CO072
# 11CO072
# 11CO072
# 11CO072

# %% [markdown]
# Some repetition there. Digging a little deeper, see below, confirms that there genuine duplicates.

# %%
for c in cases:
    print(c['id'])
    for ci in c['identifier']:
            print(ci)
    for s in c['ResearchSubject']:
        for si in s['identifier']:
            print(si)
# Out:
# 11CO039
# {'system': 'GDC', 'value': '11CO039'}
# {'system': 'PDC', 'value': '11CO039'}
# {'system': 'GDC', 'value': 'efa6ad77-da3d-4763-9662-47a5ab3b695e'}
# {'system': 'PDC', 'value': 'a0e04ed9-63d6-11e8-bcf1-0a2705229b82'}
# 11CO039
# {'system': 'GDC', 'value': '11CO039'}
# {'system': 'PDC', 'value': '11CO039'}
# {'system': 'GDC', 'value': 'efa6ad77-da3d-4763-9662-47a5ab3b695e'}
# {'system': 'PDC', 'value': 'a0e04ed9-63d6-11e8-bcf1-0a2705229b82'}
# 11CO039
# {'system': 'GDC', 'value': '11CO039'}
# {'system': 'PDC', 'value': '11CO039'}
# {'system': 'GDC', 'value': 'efa6ad77-da3d-4763-9662-47a5ab3b695e'}
# {'system': 'PDC', 'value': 'a0e04ed9-63d6-11e8-bcf1-0a2705229b82'}
# 11CO039
# {'system': 'GDC', 'value': '11CO039'}
# {'system': 'PDC', 'value': '11CO039'}
# {'system': 'GDC', 'value': 'efa6ad77-da3d-4763-9662-47a5ab3b695e'}
# {'system': 'PDC', 'value': 'a0e04ed9-63d6-11e8-bcf1-0a2705229b82'}
# 09CO022
# {'system': 'GDC', 'value': '09CO022'}
# {'system': 'PDC', 'value': '09CO022'}
# {'system': 'GDC', 'value': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}
# {'system': 'PDC', 'value': '459e3b69-63d6-11e8-bcf1-0a2705229b82'}
# 09CO022
# {'system': 'GDC', 'value': '09CO022'}
# {'system': 'PDC', 'value': '09CO022'}
# {'system': 'GDC', 'value': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}
# {'system': 'PDC', 'value': '459e3b69-63d6-11e8-bcf1-0a2705229b82'}
# 09CO022
# {'system': 'GDC', 'value': '09CO022'}
# {'system': 'PDC', 'value': '09CO022'}
# {'system': 'GDC', 'value': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}
# {'system': 'PDC', 'value': '459e3b69-63d6-11e8-bcf1-0a2705229b82'}
# 05CO039
# {'system': 'GDC', 'value': '05CO039'}
# {'system': 'PDC', 'value': '05CO039'}
# {'system': 'GDC', 'value': '997475b1-6648-494a-9322-79aa17be272e'}
# {'system': 'PDC', 'value': '2254625e-63d6-11e8-bcf1-0a2705229b82'}
# 05CO039
# {'system': 'GDC', 'value': '05CO039'}
# {'system': 'PDC', 'value': '05CO039'}
# {'system': 'GDC', 'value': '997475b1-6648-494a-9322-79aa17be272e'}
# {'system': 'PDC', 'value': '2254625e-63d6-11e8-bcf1-0a2705229b82'}
# 05CO039
# {'system': 'GDC', 'value': '05CO039'}
# {'system': 'PDC', 'value': '05CO039'}
# {'system': 'GDC', 'value': '997475b1-6648-494a-9322-79aa17be272e'}
# {'system': 'PDC', 'value': '2254625e-63d6-11e8-bcf1-0a2705229b82'}
# 05CO039
# {'system': 'GDC', 'value': '05CO039'}
# {'system': 'PDC', 'value': '05CO039'}
# {'system': 'GDC', 'value': '997475b1-6648-494a-9322-79aa17be272e'}
# {'system': 'PDC', 'value': '2254625e-63d6-11e8-bcf1-0a2705229b82'}
# 11CO010
# {'system': 'GDC', 'value': '11CO010'}
# {'system': 'PDC', 'value': '11CO010'}
# {'system': 'GDC', 'value': '02089be7-4152-4ee0-a3a5-2624c5dee644'}
# {'system': 'PDC', 'value': '8fb486ea-63d6-11e8-bcf1-0a2705229b82'}
# 11CO010
# {'system': 'GDC', 'value': '11CO010'}
# {'system': 'PDC', 'value': '11CO010'}
# {'system': 'GDC', 'value': '02089be7-4152-4ee0-a3a5-2624c5dee644'}
# {'system': 'PDC', 'value': '8fb486ea-63d6-11e8-bcf1-0a2705229b82'}
# 11CO010
# {'system': 'GDC', 'value': '11CO010'}
# {'system': 'PDC', 'value': '11CO010'}
# {'system': 'GDC', 'value': '02089be7-4152-4ee0-a3a5-2624c5dee644'}
# {'system': 'PDC', 'value': '8fb486ea-63d6-11e8-bcf1-0a2705229b82'}
# 21CO006
# {'system': 'GDC', 'value': '21CO006'}
# {'system': 'PDC', 'value': '21CO006'}
# {'system': 'GDC', 'value': 'a801ee0a-d0a1-47e0-b9d1-6dbe3c026474'}
# {'system': 'PDC', 'value': '239c3712-63d7-11e8-bcf1-0a2705229b82'}
# 21CO006
# {'system': 'GDC', 'value': '21CO006'}
# {'system': 'PDC', 'value': '21CO006'}
# {'system': 'GDC', 'value': 'a801ee0a-d0a1-47e0-b9d1-6dbe3c026474'}
# {'system': 'PDC', 'value': '239c3712-63d7-11e8-bcf1-0a2705229b82'}
# 21CO006
# {'system': 'GDC', 'value': '21CO006'}
# {'system': 'PDC', 'value': '21CO006'}
# {'system': 'GDC', 'value': 'a801ee0a-d0a1-47e0-b9d1-6dbe3c026474'}
# {'system': 'PDC', 'value': '239c3712-63d7-11e8-bcf1-0a2705229b82'}
# 11CO045
# {'system': 'GDC', 'value': '11CO045'}
# {'system': 'PDC', 'value': '11CO045'}
# {'system': 'GDC', 'value': '7c9be5dd-8ab4-4160-873c-65fb9c9100b4'}
# {'system': 'PDC', 'value': 'a5d790a6-63d6-11e8-bcf1-0a2705229b82'}
# 11CO045
# {'system': 'GDC', 'value': '11CO045'}
# {'system': 'PDC', 'value': '11CO045'}
# {'system': 'GDC', 'value': '7c9be5dd-8ab4-4160-873c-65fb9c9100b4'}
# {'system': 'PDC', 'value': 'a5d790a6-63d6-11e8-bcf1-0a2705229b82'}
# 11CO045
# {'system': 'GDC', 'value': '11CO045'}
# {'system': 'PDC', 'value': '11CO045'}
# {'system': 'GDC', 'value': '7c9be5dd-8ab4-4160-873c-65fb9c9100b4'}
# {'system': 'PDC', 'value': 'a5d790a6-63d6-11e8-bcf1-0a2705229b82'}
# 11CO005
# {'system': 'GDC', 'value': '11CO005'}
# {'system': 'PDC', 'value': '11CO005'}
# {'system': 'GDC', 'value': 'b8448568-a404-4563-85ca-d655cadbf07d'}
# {'system': 'PDC', 'value': '8b89647a-63d6-11e8-bcf1-0a2705229b82'}
# 11CO005
# {'system': 'GDC', 'value': '11CO005'}
# {'system': 'PDC', 'value': '11CO005'}
# {'system': 'GDC', 'value': 'b8448568-a404-4563-85ca-d655cadbf07d'}
# {'system': 'PDC', 'value': '8b89647a-63d6-11e8-bcf1-0a2705229b82'}
# 11CO005
# {'system': 'GDC', 'value': '11CO005'}
# {'system': 'PDC', 'value': '11CO005'}
# {'system': 'GDC', 'value': 'b8448568-a404-4563-85ca-d655cadbf07d'}
# {'system': 'PDC', 'value': '8b89647a-63d6-11e8-bcf1-0a2705229b82'}
# 11CO005
# {'system': 'GDC', 'value': '11CO005'}
# {'system': 'PDC', 'value': '11CO005'}
# {'system': 'GDC', 'value': 'b8448568-a404-4563-85ca-d655cadbf07d'}
# {'system': 'PDC', 'value': '8b89647a-63d6-11e8-bcf1-0a2705229b82'}
# ColonRef
# {'system': 'PDC', 'value': 'ColonRef'}
# {'system': 'PDC', 'value': '6a478d6a-ec51-11e9-81b4-2a2ae2dbcce4'}
# ColonRef
# {'system': 'PDC', 'value': 'ColonRef'}
# {'system': 'PDC', 'value': '6a478d6a-ec51-11e9-81b4-2a2ae2dbcce4'}
# 11CO072
# {'system': 'GDC', 'value': '11CO072'}
# {'system': 'PDC', 'value': '11CO072'}
# {'system': 'GDC', 'value': '2d978192-eaa8-4868-b646-13a2567978d9'}
# {'system': 'PDC', 'value': 'b7dda873-63d6-11e8-bcf1-0a2705229b82'}
# 11CO072
# {'system': 'GDC', 'value': '11CO072'}
# {'system': 'PDC', 'value': '11CO072'}
# {'system': 'GDC', 'value': '2d978192-eaa8-4868-b646-13a2567978d9'}
# {'system': 'PDC', 'value': 'b7dda873-63d6-11e8-bcf1-0a2705229b82'}
# 11CO072
# {'system': 'GDC', 'value': '11CO072'}
# {'system': 'PDC', 'value': '11CO072'}
# {'system': 'GDC', 'value': '2d978192-eaa8-4868-b646-13a2567978d9'}
# {'system': 'PDC', 'value': 'b7dda873-63d6-11e8-bcf1-0a2705229b82'}
# 11CO072
# {'system': 'GDC', 'value': '11CO072'}
# {'system': 'PDC', 'value': '11CO072'}
# {'system': 'GDC', 'value': '2d978192-eaa8-4868-b646-13a2567978d9'}
# {'system': 'PDC', 'value': 'b7dda873-63d6-11e8-bcf1-0a2705229b82'}

# %% [markdown]
# There's likely something going on with the SQL that CDA is generating.

# %%
q1 = Q('ResearchSubject.Specimen.File.label = "16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm"')
q1.run(limit=1000)
# Out:
# Getting results from database
#
# Total execution time: 7681 ms
# QueryID: 300bb67c-97d9-44c5-b71b-67e39407d94e
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File) AS _File WHERE (_File.label = '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm')
# Offset: 0
# Count: 30
# Total Row Count: 30
# More pages: False

# %% [markdown]
# That SQL seems reasonable.
#
# It's more likely that this is a product of the denormalization of File that we've already encountered. The unnests in the SQL generated produces a table with one row per specimen. Because more than one specimen in the same subject has the file we are looking for we get multiple matches.
#
# We can test this out by running an edited version of the SQL that lists some the specimen attributes.

# %%
testsql = '''
SELECT all_v2.id case_id,  _Specimen.specimen_type, _Specimen.id specimen_id,
_Specimen.derived_from_specimen, _Specimen.source_material_type
FROM gdc-bq-sample.integration.all_v2 AS all_v2, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Specimen) AS _Specimen, 
UNNEST(_Specimen.File) AS _File 
WHERE (_File.label = '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm')
'''

from cda_funcs import qResultsToDF
t1 = Q.sql(testsql)
qResultsToDF(t1)
# Out:
#      case_id specimen_type                           specimen_id  \
# 0    11CO045        sample  c7f28a6b-641c-11e8-bcf1-0a2705229b82
# 1    11CO045       aliquot  10430efa-642a-11e8-bcf1-0a2705229b82
# 2    11CO045        sample  c9b7d7b8-641c-11e8-bcf1-0a2705229b82
# 3    05CO039        sample  8d514dac-641b-11e8-bcf1-0a2705229b82
# 4    05CO039       aliquot  de1a20d8-6429-11e8-bcf1-0a2705229b82
# 5    05CO039        sample  8f51c47c-641b-11e8-bcf1-0a2705229b82
# 6    05CO039        sample  da08db4a-6420-11e8-bcf1-0a2705229b82
# 7    11CO010        sample  7dfa9110-641c-11e8-bcf1-0a2705229b82
# 8    11CO010       aliquot  9039ae28-6429-11e8-bcf1-0a2705229b82
# 9    11CO010        sample  7f8b1e31-641c-11e8-bcf1-0a2705229b82
# 10  ColonRef        sample  6a47a138-ec51-11e9-81b4-2a2ae2dbcce4
# 11  ColonRef       aliquot  6a47b1dc-ec51-11e9-81b4-2a2ae2dbcce4
# 12   21CO006        sample  db1d7011-641d-11e8-bcf1-0a2705229b82
# 13   21CO006       aliquot  c010f10f-6424-11e8-bcf1-0a2705229b82
# 14   21CO006        sample  dcce7b36-641d-11e8-bcf1-0a2705229b82
# 15   11CO039        sample  b80c665e-641c-11e8-bcf1-0a2705229b82
# 16   11CO039        sample  ba017407-641c-11e8-bcf1-0a2705229b82
# 17   11CO039       aliquot  2b38e317-642a-11e8-bcf1-0a2705229b82
# 18   11CO039        sample  bba19a8b-641c-11e8-bcf1-0a2705229b82
# 19   11CO072        sample  f8e6e3ed-6420-11e8-bcf1-0a2705229b82
# 20   11CO072        sample  fab5cb9a-641c-11e8-bcf1-0a2705229b82
# 21   11CO072       aliquot  4c2b9219-6423-11e8-bcf1-0a2705229b82
# 22   11CO072        sample  fcca5035-641c-11e8-bcf1-0a2705229b82
# 23   11CO005        sample  6f64d51a-641c-11e8-bcf1-0a2705229b82
# 24   11CO005       aliquot  4ed7f52d-6423-11e8-bcf1-0a2705229b82
# 25   11CO005        sample  71189ae6-641c-11e8-bcf1-0a2705229b82
# 26   11CO005       aliquot  192bd904-642a-11e8-bcf1-0a2705229b82
# 27   09CO022        sample  f4af3e4d-641b-11e8-bcf1-0a2705229b82
# 28   09CO022        sample  f6cce507-641b-11e8-bcf1-0a2705229b82
# 29   09CO022       aliquot  44f5b956-642a-11e8-bcf1-0a2705229b82
#
#                    derived_from_specimen source_material_type
# 0                       initial specimen  Solid Tissue Normal
# 1   c7f28a6b-641c-11e8-bcf1-0a2705229b82  Solid Tissue Normal
# 2                       initial specimen        Primary Tumor
# 3                       initial specimen  Solid Tissue Normal
# 4   8d514dac-641b-11e8-bcf1-0a2705229b82  Solid Tissue Normal
# 5                       initial specimen        Primary Tumor
# 6                       initial specimen        Primary Tumor
# 7                       initial specimen        Primary Tumor
# 8   7dfa9110-641c-11e8-bcf1-0a2705229b82        Primary Tumor
# 9                       initial specimen  Solid Tissue Normal
# 10                      initial specimen         Not Reported
# 11  6a47a138-ec51-11e9-81b4-2a2ae2dbcce4         Not Reported
# 12                      initial specimen  Solid Tissue Normal
# 13  db1d7011-641d-11e8-bcf1-0a2705229b82  Solid Tissue Normal
# 14                      initial specimen        Primary Tumor
# 15                      initial specimen  Solid Tissue Normal
# 16                      initial specimen        Primary Tumor
# 17  ba017407-641c-11e8-bcf1-0a2705229b82        Primary Tumor
# 18                      initial specimen        Primary Tumor
# 19                      initial specimen        Primary Tumor
# 20                      initial specimen  Solid Tissue Normal
# 21  fab5cb9a-641c-11e8-bcf1-0a2705229b82  Solid Tissue Normal
# 22                      initial specimen        Primary Tumor
# 23                      initial specimen  Solid Tissue Normal
# 24  6f64d51a-641c-11e8-bcf1-0a2705229b82  Solid Tissue Normal
# 25                      initial specimen        Primary Tumor
# 26  71189ae6-641c-11e8-bcf1-0a2705229b82        Primary Tumor
# 27                      initial specimen  Solid Tissue Normal
# 28                      initial specimen        Primary Tumor
# 29  f6cce507-641b-11e8-bcf1-0a2705229b82        Primary Tumor

# %% [markdown]
# This shows that the files are attached to many specimens besides the specific specimen (aliquot) from which they were derived.
#
# It seems this can be likely be explained by underlying causes encountered in two other issues:
# - Cause: denormalization of File to the specimens from which they were derived
#   - appears in [cda-python/issues/97](https://github.com/CancerDataAggregator/cda-python/issues/97)
# - Cause: copying across of File to siblings of parents (aunts and uncles?)
#   - appears in [cda-python/issues/99](https://github.com/CancerDataAggregator/cda-python/issues/99)
#
# There are a couple of reasons why the issue identified in this notebook warrants its own issue [cda-python/issues/106](https://github.com/CancerDataAggregator/cda-python/issues/106).
#
# - Even if the two underlying causes above are addressed there are cases (e.g. proteomics multiplexing) where there will genuinely be two specimens within the same subject.
# - How the underyling issue shows up though is sufficiently different that fies to those issues should be tested via this notebook.
#
# ## The genuine multiple sample-file test case
# The following file from the Georgetown Lung Cancer Proteomics Study is a suitable test case for the scenario where a Subject genuinely has a file with a direct association to two of the Subject's specimens.

# %%
gt_cases = find_file('Ctrl_10-set_3-label_116-frac_1-F4.wiff')
# Out:
# Searching for file Ctrl_10-set_3-label_116-frac_1-F4.wiff
# Getting results from database
#
# Total execution time: 1612 ms
# Found that file in 14 'Subjects'
# ________________________________________________________________________________

# %%
for c in gt_cases:
    print(c['id'])
# Out:
# ICBI-000009
# ICBI-000009
# ICBI-000009
# ICBI-000009
# ReferenceMix
# ReferenceMix
# ICBI-000008
# ICBI-000008
# ICBI-000008
# ICBI-000008
# ICBI-000007
# ICBI-000007
# ICBI-000007
# ICBI-000007

# %% [markdown]
# Of course there are really only 4 subjects for reasons described above. (Actually there are really only three subjects. ReferenceMix isn't a subject as such - but we'll leave that aside for now).
#
# Next we look at the specimen details to confirm the desirable differences (for test purposes) in this case.

# %%
testsql2 = '''
SELECT all_v2.id case_id,  _Specimen.specimen_type, _Specimen.id specimen_id,
_Specimen.derived_from_specimen, _Specimen.source_material_type
FROM gdc-bq-sample.integration.all_v2 AS all_v2, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Specimen) AS _Specimen, 
UNNEST(_Specimen.File) AS _File 
WHERE (_File.label = 'Ctrl_10-set_3-label_116-frac_1-F4.wiff')
'''

t2 = Q.sql(testsql2)
qResultsToDF(t2)
# Out:
#          case_id specimen_type                           specimen_id  \
# 0    ICBI-000009        sample  9e8eade1-d732-11ea-b1fd-0aad30af8a83
# 1    ICBI-000009       aliquot  9e8ec9ad-d732-11ea-b1fd-0aad30af8a83
# 2    ICBI-000009        sample  9e8eafdd-d732-11ea-b1fd-0aad30af8a83
# 3    ICBI-000009       aliquot  9e8ecb2f-d732-11ea-b1fd-0aad30af8a83
# 4    ICBI-000008        sample  9e8eaab4-d732-11ea-b1fd-0aad30af8a83
# 5    ICBI-000008       aliquot  9e8ec6bb-d732-11ea-b1fd-0aad30af8a83
# 6    ICBI-000008        sample  9e8eacb2-d732-11ea-b1fd-0aad30af8a83
# 7    ICBI-000008       aliquot  9e8ec7b8-d732-11ea-b1fd-0aad30af8a83
# 8   ReferenceMix        sample  9e8eb490-d732-11ea-b1fd-0aad30af8a83
# 9   ReferenceMix       aliquot  9e8ecf0b-d732-11ea-b1fd-0aad30af8a83
# 10   ICBI-000007        sample  9e8ea791-d732-11ea-b1fd-0aad30af8a83
# 11   ICBI-000007       aliquot  9e8ec4e2-d732-11ea-b1fd-0aad30af8a83
# 12   ICBI-000007        sample  9e8ea97c-d732-11ea-b1fd-0aad30af8a83
# 13   ICBI-000007       aliquot  9e8ec5e3-d732-11ea-b1fd-0aad30af8a83
#
#                    derived_from_specimen source_material_type
# 0                       initial specimen        Primary Tumor
# 1   9e8eade1-d732-11ea-b1fd-0aad30af8a83        Primary Tumor
# 2                       initial specimen  Solid Tissue Normal
# 3   9e8eafdd-d732-11ea-b1fd-0aad30af8a83  Solid Tissue Normal
# 4                       initial specimen        Primary Tumor
# 5   9e8eaab4-d732-11ea-b1fd-0aad30af8a83        Primary Tumor
# 6                       initial specimen  Solid Tissue Normal
# 7   9e8eacb2-d732-11ea-b1fd-0aad30af8a83  Solid Tissue Normal
# 8                       initial specimen         Not Reported
# 9   9e8eb490-d732-11ea-b1fd-0aad30af8a83         Not Reported
# 10                      initial specimen        Primary Tumor
# 11  9e8ea791-d732-11ea-b1fd-0aad30af8a83        Primary Tumor
# 12                      initial specimen  Solid Tissue Normal
# 13  9e8ea97c-d732-11ea-b1fd-0aad30af8a83  Solid Tissue Normal

# %% [markdown]
# The file contains data for a plex which contains both tumor and normal material from the some subject. So the associations shown above of the file with both the tumor aliquot and the normal aliquot are genuine.
#
# Ahead of the denormalization being removed by the CDA team we can simulate that is been done by filtering the specimen_type to aliquot only.

# %%
testsql3 = '''
SELECT all_v2.*
FROM gdc-bq-sample.integration.all_v2 AS all_v2, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Specimen) AS _Specimen, 
UNNEST(_Specimen.File) AS _File 
WHERE (_File.label = 'Ctrl_10-set_3-label_116-frac_1-F4.wiff')
and specimen_type = 'aliquot'
'''

t3 = Q.sql(testsql3)
for c in t3:
    print (c['id'])
# Out:
# ICBI-000009
# ICBI-000009
# ReferenceMix
# ICBI-000008
# ICBI-000008
# ICBI-000007
# ICBI-000007

# %% [markdown]
# That query demonstrates that the CDA generated query will still generate duplicates of these Subjects.
#
# The desired result could be produced with generated SQL as follows.

# %%
testsql4 = ''' SELECT a_v2.* FROM gdc-bq-sample.integration.all_v2 AS a_v2
where a_v2.id in 
( SELECT all_v2.id case_id
FROM gdc-bq-sample.integration.all_v2 AS all_v2, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Specimen) AS _Specimen, 
UNNEST(_Specimen.File) AS _File 
WHERE (_File.label = 'Ctrl_10-set_3-label_116-frac_1-F4.wiff')
)
'''

t4 = Q.sql(testsql4)
for c in t4:
    print (c['id'])
# Out:
# ICBI-000007
# ICBI-000009
# ICBI-000008
# ReferenceMix
